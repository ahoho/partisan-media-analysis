# %%
import cPickle as pickle

from stream import SentenceStream #from the prior post

sql_url = 'postgres://postgres:**PASSWORD**@localhost/articles'

# query yields same text as last time (now includes alignment data)
query = """
        SELECT side, article_text
        FROM articles a
        LEFT JOIN alignment s
        ON split_part(a.post_id, '_', 1) = s.fb_id
        WHERE num_words > 100 and not
              (lower(article_text) like '%%daily caller news foundation%%' and
               base_url != 'dailycaller.com') and not
               lower(article_text) like '%%copyright 20__ the associated press%%'
        ORDER BY side
        """

# pull in the noun n-grams
with open('../intermediate/noun_ngrams_all.pkl', 'rb') as infile:
    noun_ngrams = pickle.load(infile)

# limit to those that appear with some frequency
noun_ngrams = [n for n in noun_ngrams if noun_ngrams[n] > 100]
    
# the n-grams we've located will now be identified in the stream of text
# using the MWETokenizer from nltk
# since I'm using a Google Compute Engine I have RAM to spare
# and will gluttonously store it all in memory
sentences = list(SentenceStream(sqldb=sql_url, query=query,
                                ngrams=noun_ngrams, idcol='side'))

# %%
from gensim.models import Word2Vec
model = Word2Vec([x[1] for x in sentences],
                 min_count=50, iter=5, sg=1, hs=1, workers=10, size=500)

# %%
model.save('../intermediate/word2vec.pkl')

# %%
model_left = Word2Vec([x[1] for x in sentences if x[0] == 'left'],
                      min_count=50, iter=5, sg=1, hs=1, workers=10, size=500)
model_left.save('../intermediate/word2vec_left.pkl')
model_right = Word2Vec([x[1] for x in sentences if x[0] == 'right'],
                       min_count=50, iter=5, sg=1, hs=1, workers=10, size=500)
model_right.save('../intermediate/word2vec_right.pkl')

# %% [markdown]
# ## Some initial explorations
#
# Before we get into anything serious, we can begin by doing a little playing around with our models. One of the most basic things we can do with word embeddings is to find word vectors that are "close" to others, as defined by their cosine similarity.
#
# I thought it would be interesting to see what words are considered similar in one model, but not the other. This isn't especially sophisticated, but it's intuitive.

# %%
import pandas as pd

def partition_similar_terms(term, model_a, model_b, pool_n=100, n=10,
                            a_lab='left', b_lab='right'):
    """
    For the `pool_n` terms most similar to `term`
    in `model_a` and `model_b`, return
    A - B
    B - A
    A & B
    """
    labs = {'a':a_lab, 'b':b_lab}
    
    terms_a = [t for t, s in model_a.most_similar(term, topn=pool_n)]
    terms_b = [t for t, s in model_b.most_similar(term, topn=pool_n)]
    
    a_not_b = [t for t in terms_a if t not in terms_b][:n]
    b_not_a = [t for t in terms_b if t not in terms_a][:n]
    a_and_b = [t for t in terms_a if t in terms_b][:n]
    
    return pd.DataFrame({'{a} not {b}'.format(**labs): a_not_b,
                         '{b} not {a}'.format(**labs): b_not_a,
                         '{a} and {b}'.format(**labs): a_and_b })

# %%
# what does it mean to be "shady" on the right, that is different from what it means on the left, and vice versa?
partition_similar_terms('shady', model_left, model_right)
# Out:
#        left and right left not right       right not left
# 0        questionable   dirty_tricks   influence-peddling
# 1            dealings         clever             scandals
# 2              sleazy           scam   clinton_foundation
# 3            unsavory         frauds                seedy
# 4  financial_dealings      astroturf          connections
# 5             sketchy   disreputable               sordid
# 6        unscrupulous          slimy     foreign_entities
# 7          fraudulent   self-dealing  clinton_foundations
# 8  business_practices       unseemly              illicit
# 9   business_dealings           fake         profiteering

# %% [markdown]
# Fairly interesting stuff! The right focuses on the Clinton Foundation and its influence, as expected, and the left appears to make more on the unseemliness of (presumably) Trump's business practices. Let's try something else:

# %%
partition_similar_terms('radical', model_left, model_right)
# Out:
#    left and right    left not right       right not left
# 0       extremist         far-right     islamic_ideology
# 1          fringe  anti-imperialist        anti-american
# 2     progressive          populist   muslim_brotherhood
# 3        militant         socialist             salafist
# 4   revolutionary      conservatism     extremist_groups
# 5  fundamentalist         hard-line             deobandi
# 6      extremists       doctrinaire            islamists
# 7         leftist        mainstream  liberation_theology
# 8        radicals              wing            wahhabist
# 9     reactionary    fundamentalism         totalitarian

# %% [markdown]
# The right uses "radical" to refer to muslim groups almost exclusively.

# %%
partition_similar_terms('alt-right', model_left, model_right)
# Out:
#        left and right     left not right               right not left
# 0  white_nationalists          breitbart                   nevertrump
# 1         nationalist  white_nationalism                        bigot
# 2         supremacist      daily_stormer          nevertrump_movement
# 3           neo-nazis         stormfront                         pepe
# 4            neo-nazi           vdarecom                     movement
# 5  white_supremacists     breitbart_news     donald_trumps_supporters
# 6        anti-semitic  white-supremacist                     feminism
# 7                 alt             bannon                conservatives
# 8        anti-semites       steve_bannon                      leftist
# 9           far-right       jared_taylor  black_lives_matter_movement

# %%
partition_similar_terms(['feminism', 'feminist', 'feminists'], model_left, model_right)
# Out:
#       left and right        left not right           right not left
# 0  feminist_movement          sex-positive  social_justice_warriors
# 1     gloria_steinem            motherhood         radical_feminist
# 2     intersectional                 women                  leftist
# 3          womanhood  reproductive_justice        radical_feminists
# 4      womens_rights              traister                    lefty
# 5              queer         freethenipple                   dunham
# 6           liberals            femininity                     lena
# 7            liberal       body_positivity                 far-left
# 8         patriarchy           bernie_bros                      sjw
# 9       progressives           anti-racist           lgbt_activists

# %% [markdown]
# # TESTING GROUNDS

# %%
# Out:
# {'__ignoreds': ['syn0norm', 'cum_table'],
#  '__numpys': ['syn1neg', 'syn0', 'syn1'],
#  '__recursive_saveloads': [],
#  '__scipys': [],
#  'alpha': 0.025,
#  'batch_words': 10000,
#  'cbow_mean': 1,
#  'corpus_count': 5376975,
#  'cum_table': array([  30014158,   48446814,   65668194, ..., 2147474761, 2147479204,
#         2147483647], dtype=uint32),
#  'hashfxn': <function hash>,
#  'hs': 1,
#  'index2word': [u'the',
#   u'to',
#   u'of',
#   u'and',
#   u'a',
#   u'in',
#   u'that',
#   u'is',
#   u'for',
#   u'on',
#   u'it',
#   u'with',
#   u'was',
#   u'as',
#   u'i',
#   u'he',
#   u'this',
#   u'are',
#   u'have',
#   u'be',
#   u'not',
#   u'by',
#   u'at',
#   u'you',
#   u'but',
#   u'his',
#   u'from',
#   u'they',
#   u'has',
#   u'we',
#   u'an',
#   u's',
#   u'who',
#   u'about',
#   u'their',
#   u'or',
#   u'said',
#   u'its',
#   u'people',
#   u'her',
#   u'more',
#   u'one',
#   u'she',
#   u'were',
#   u'what',
#   u'all',
#   u'when',
#   u'will',
#   u'would',
#   u'if',
#   u'so',
#   u'out',
#   u'been',
#   u'like',
#   u'had',
#   u'can',
#   u'which',
#   u'do',
#   u'there',
#   u'up',
#   u'just',
#   u'us',
#   u'our',
#   u'than',
#   u'also',
#   u'no',
#   u'trump',
#   u'my',
#   u'after',
#   u'other',
#   u'because',
#   u'them',
#   u'some',
#   u'how',
#   u'time',
#   u'into',
#   u'even',
#   u'now',
#   u'over',
#   u'your',
#   u'him',
#   u'only',
#   u'these',
#   u'most',
#   u'new',
#   u'many',
#   u'could',
#   u'get',
#   u'me',
#   u'know',
#   u'those',
#   u'nt',
#   u'while',
#   u'being',
#   u'first',
#   u'state',
#   u'any',
#   u'make',
#   u'did',
#   u'think',
#   u'way',
#   u'where',
#   u'going',
#   u'then',
#   u'should',
#   u'women',
#   u'against',
#   u'much',
#   u'very',
#   u'say',
#   u'well',
#   u'right',
#   u'year',
#   u'dont',
#   u'back',
#   u'percent',
#   u'last',
#   u'black',
#   u'before',
#   u'may',
#   u'told',
#   u'two',
#   u'want',
#   u'see',
#   u'made',
#   u'still',
#   u'world',
#   u'according',
#   u'take',
#   u'says',
#   u'here',
#   u'down',
#   u'go',
#   u'during',
#   u'country',
#   u'president',
#   u'why',
#   u'work',
#   u'really',
#   u'years',
#   u'own',
#   u'such',
#   u'campaign',
#   u'through',
#   u'american',
#   u'day',
#   u'does',
#   u'thats',
#   u'same',
#   u'since',
#   u'need',
#   u'another',
#   u'off',
#   u'never',
#   u'both',
#   u'good',
#   u'support',
#   u'every',
#   u'clinton',
#   u'around',
#   u'too',
#   u'life',
#   u'between',
#   u'donald_trump',
#   u'law',
#   u'come',
#   u'something',
#   u'public',
#   u'part',
#   u'things',
#   u'called',
#   u'man',
#   u'government',
#   u'under',
#   u'use',
#   u'police',
#   u'might',
#   u'story',
#   u'im',
#   u'political',
#   u'fact',
#   u'money',
#   u'america',
#   u'million',
#   u'got',
#   u'long',
#   u'case',
#   u'white',
#   u'family',
#   u'children',
#   u'show',
#   u'including',
#   u'2016',
#   u'found',
#   u'week',
#   u'help',
#   u'look',
#   u'put',
#   u'united_states',
#   u'states',
#   u'without',
#   u'used',
#   u'actually',
#   u'though',
#   u'saying',
#   u'news',
#   u'today',
#   u'end',
#   u'hes',
#   u'group',
#   u'lot',
#   u'didnt',
#   u'video',
#   u'republicans',
#   u'sanders',
#   u'home',
#   u'far',
#   u'few',
#   u'asked',
#   u'thing',
#   u'again',
#   u'report',
#   u'less',
#   u'better',
#   u'little',
#   u'yet',
#   u'power',
#   u'already',
#   u'americans',
#   u'men',
#   u'whether',
#   u'point',
#   u'2015',
#   u'believe',
#   u'republican',
#   u'become',
#   u'least',
#   u'came',
#   u'woman',
#   u'however',
#   u'vote',
#   u'history',
#   u'times',
#   u'away',
#   u'doing',
#   u'doesnt',
#   u'big',
#   u'national',
#   u'wrote',
#   u'enough',
#   u'change',
#   u'often',
#   u'source',
#   u'love',
#   u'former',
#   u'likely',
#   u'each',
#   u'went',
#   u'city',
#   u'making',
#   u'war',
#   u'trumps',
#   u'issue',
#   u're',
#   u'best',
#   u'find',
#   u'left',
#   u'bill',
#   u'among',
#   u'real',
#   u'three',
#   u'having',
#   u'once',
#   u'took',
#   u'theres',
#   u'night',
#   u'kind',
#   u'keep',
#   u'ever',
#   u'media',
#   u'always',
#   u'great',
#   u'trying',
#   u'advertisement',
#   u'school',
#   u'students',
#   u'party',
#   u'person',
#   u'feel',
#   u'let',
#   u'different',
#   u'hillary_clinton',
#   u'next',
#   u'house',
#   u'nothing',
#   u'across',
#   u'company',
#   u'must',
#   u'am',
#   u'system',
#   u'problem',
#   u'give',
#   u'comes',
#   u'youre',
#   u'someone',
#   u'until',
#   u'cant',
#   u'place',
#   u'course',
#   u'number',
#   u'theyre',
#   u'others',
#   u'question',
#   u'important',
#   u'call',
#   u'reported',
#   u'policy',
#   u'statement',
#   u'obama',
#   u'getting',
#   u'working',
#   u'water',
#   u'live',
#   u'instead',
#   u'set',
#   u'seen',
#   u'tell',
#   u'clear',
#   u'pay',
#   u'anything',
#   u'business',
#   u'able',
#   u'voters',
#   u'stop',
#   u'done',
#   u'1',
#   u'photo',
#   u'community',
#   u'climate_change',
#   u'watch',
#   u'face',
#   u'talk',
#   u'10',
#   u'given',
#   u'mean',
#   u'makes',
#   u'almost',
#   u'name',
#   u'young',
#   u'read',
#   u'university',
#   u'issues',
#   u'means',
#   u'hard',
#   u'past',
#   u'using',
#   u'days',
#   u'office',
#   u'energy',
#   u'together',
#   u'reports',
#   u'idea',
#   u'local',
#   u'job',
#   u'isnt',
#   u'thought',
#   u'released',
#   u'debate',
#   u'killed',
#   u'himself',
#   u'court',
#   u'order',
#   u'recently',
#   u'major',
#   u'nation',
#   u'act',
#   u'future',
#   u'taking',
#   u'2014',
#   u'decision',
#   u'later',
#   u'death',
#   u'month',
#   u'plan',
#   u'democrats',
#   u'members',
#   u'congress',
#   u'known',
#   u'food',
#   u'sure',
#   u'continue',
#   u'2',
#   u'north',
#   u'wanted',
#   u'election',
#   u'candidate',
#   u'words',
#   u'lives',
#   u'everyone',
#   u'themselves',
#   u'matter',
#   u'seems',
#   u'center',
#   u'rather',
#   u'race',
#   u'run',
#   u'free',
#   u'kids',
#   u'study',
#   u'everything',
#   u'recent',
#   u'several',
#   u'book',
#   u'taken',
#   u'fight',
#   u'despite',
#   u'shows',
#   u'began',
#   u'conservative',
#   u'true',
#   u'tuesday',
#   u'florida',
#   u'along',
#   u'coming',
#   u'friends',
#   u'interview',
#   u'behind',
#   u'especially',
#   u'win',
#   u'top',
#   u'new_york',
#   u'started',
#   u'program',
#   u'speech',
#   u'lead',
#   u'anyone',
#   u'twitter',
#   u'information',
#   u'bad',
#   u'based',
#   u'global',
#   u'response',
#   u'gay',
#   u'military',
#   u'simply',
#   u'start',
#   u'reason',
#   u'workers',
#   u'nearly',
#   u'within',
#   u'20',
#   u'process',
#   u'full',
#   u'ago',
#   u'health',
#   u'example',
#   u'deal',
#   u'happened',
#   u'groups',
#   u'looking',
#   u'earlier',
#   u'move',
#   u'officials',
#   u'care',
#   u'm',
#   u'second',
#   u'monday',
#   u'shot',
#   u'early',
#   u'movement',
#   u'attack',
#   u'wrong',
#   u'talking',
#   u'education',
#   u'probably',
#   u'possible',
#   u'small',
#   u'federal',
#   u'parents',
#   u'understand',
#   u'four',
#   u'texas',
#   u'following',
#   u'below',
#   u'politics',
#   u'laws',
#   u'democratic',
#   u'violence',
#   u'either',
#   u'wants',
#   u'mother',
#   u'outside',
#   u'wasnt',
#   u'lost',
#   u'research',
#   u'candidates',
#   u'whose',
#   u'needs',
#   u'added',
#   u'open',
#   u'child',
#   u'high',
#   u'leave',
#   u'turn',
#   u'moment',
#   u'general',
#   u'california',
#   u'evidence',
#   u'4',
#   u'15',
#   u'old',
#   u'became',
#   u'amy',
#   u'economic',
#   u'yes',
#   u'try',
#   u'head',
#   u'president_obama',
#   u'announced',
#   u'3',
#   u'families',
#   u'else',
#   u'jobs',
#   u'legal',
#   u'wednesday',
#   u'calling',
#   u'saw',
#   u'action',
#   u'gop',
#   u'climate',
#   u'2012',
#   u'experience',
#   u'bring',
#   u'current',
#   u'posted',
#   u'shes',
#   u'line',
#   u'hope',
#   u'living',
#   u'thursday',
#   u'although',
#   u'close',
#   u'primary',
#   u'held',
#   u'supporters',
#   u'maybe',
#   u'ive',
#   u'running',
#   u'5',
#   u've',
#   u'countries',
#   u'ask',
#   u'sense',
#   u'half',
#   u'department',
#   u'morning',
#   u'access',
#   u'cruz',
#   u'control',
#   u'ways',
#   u'data',
#   u'god',
#   u'team',
#   u'email',
#   u'large',
#   u'stand',
#   u'five',
#   u'leaders',
#   u'2013',
#   u'gave',
#   u'play',
#   u'side',
#   u'schools',
#   u'facebook',
#   u'record',
#   u'companies',
#   u'officers',
#   u'role',
#   u'justice',
#   u'goodman',
#   u'rights',
#   u'itself',
#   u'claims',
#   u'sex',
#   u'friday',
#   u'claim',
#   u'billion',
#   u'project',
#   u'whole',
#   u'heard',
#   u'industry',
#   u'millions',
#   u'led',
#   u'related',
#   u'questions',
#   u'further',
#   u'message',
#   u'senate',
#   u'economy',
#   u'similar',
#   u'father',
#   u'policies',
#   u'happen',
#   u'continued',
#   u'event',
#   u'tried',
#   u'poor',
#   u'perhaps',
#   u'entire',
#   u'goes',
#   u'international',
#   u'cases',
#   u'society',
#   u'spent',
#   u'provide',
#   u'thousands',
#   u'follow',
#   u'via',
#   u'result',
#   u'protect',
#   u'turned',
#   u'single',
#   u'film',
#   u'shooting',
#   u'published',
#   u'strong',
#   u'create',
#   u'seem',
#   u'longer',
#   u'oil',
#   u'knew',
#   u'felt',
#   u'image',
#   u'comments',
#   u'toward',
#   u'received',
#   u'decided',
#   u'game',
#   u'hit',
#   u'prison',
#   u'paid',
#   u'worked',
#   u'article',
#   u'finally',
#   u'social',
#   u'involved',
#   u'communities',
#   u'organization',
#   u'relationship',
#   u'problems',
#   u'list',
#   u'series',
#   u'son',
#   u'human',
#   u'gun',
#   u'post',
#   u'pretty',
#   u'land',
#   u'personal',
#   u'new_york_times',
#   u'brought',
#   u'washington',
#   u'exactly',
#   u'building',
#   u'judge',
#   u'hear',
#   u'share',
#   u'color',
#   u'allow',
#   u'hold',
#   u'truth',
#   u'12',
#   u'democracy',
#   u'fear',
#   u'racist',
#   u'whats',
#   u'cost',
#   u'quite',
#   u'allowed',
#   u'30',
#   u'body',
#   u'created',
#   u'late',
#   u'hand',
#   u'speak',
#   u'rest',
#   u'sometimes',
#   u'filed',
#   u'weve',
#   u'gets',
#   u'won',
#   u'officer',
#   u'attacks',
#   u'cause',
#   u'efforts',
#   u'position',
#   u'particularly',
#   u'wont',
#   u'november',
#   u'august',
#   u'noted',
#   u'certainly',
#   u'mind',
#   u'needed',
#   u'passed',
#   u'cnn',
#   u'word',
#   u'sunday',
#   u'bernie_sanders',
#   u'supreme_court',
#   u'form',
#   u'images',
#   u'currently',
#   u'speaking',
#   u'level',
#   u'guy',
#   u'meeting',
#   u'college',
#   u'include',
#   u'church',
#   u'serious',
#   u'situation',
#   u'culture',
#   u'plans',
#   u'couple',
#   u'forward',
#   u'address',
#   u'age',
#   u'music',
#   u'april',
#   u'citizens',
#   u'reality',
#   u'director',
#   u'sent',
#   u'stay',
#   u'potential',
#   u'leading',
#   u'beyond',
#   u'fire',
#   u'due',
#   u'area',
#   u'calls',
#   u'attention',
#   u'risk',
#   u'remember',
#   u'answer',
#   u'abortion',
#   u'hands',
#   u'isis',
#   u'march',
#   u'online',
#   u'50',
#   u'fox_news',
#   u'100',
#   u'certain',
#   u'release',
#   u'died',
#   u'alone',
#   u'increase',
#   u'view',
#   u'hillary',
#   u'https',
#   u'brown',
#   u'above',
#   u'force',
#   u'white_house',
#   u'chance',
#   u'claimed',
#   u'rules',
#   u'sort',
#   u'stories',
#   u'october',
#   u'soon',
#   u'press',
#   u'growing',
#   u'cut',
#   u'john',
#   u'victims',
#   u'effort',
#   u'terms',
#   u'attorney',
#   u'average',
#   u'official',
#   u'hours',
#   u'investigation',
#   u'south',
#   u'majority',
#   u'car',
#   u'ones',
#   u'telling',
#   u'meet',
#   u'inside',
#   u'wife',
#   u'failed',
#   u'david',
#   u'science',
#   u'arrested',
#   u'security',
#   u'explained',
#   u'front',
#   u'difficult',
#   u'west',
#   u'impact',
#   u'private',
#   u'crime',
#   u'spoke',
#   u'opportunity',
#   u'giving',
#   u'board',
#   u'helped',
#   u'arent',
#   u'clearly',
#   u'transgender',
#   u'choice',
#   u'bush',
#   u'conversation',
#   u'd',
#   u'11',
#   u'september',
#   u'dead',
#   u'freedom',
#   u'lgbt',
#   u'letter',
#   u'25',
#   u'ground',
#   u'student',
#   u'friend',
#   u'shares',
#   u'safe',
#   u'girls',
#   u'6',
#   u'marriage',
#   u'looks',
#   u'female',
#   u'focus',
#   u'asking',
#   u'dangerous',
#   u'sign',
#   u'thinking',
#   u'takes',
#   u'nations',
#   u'latest',
#   u'natural',
#   u'lack',
#   u'gone',
#   u'county',
#   u'points',
#   u'muslims',
#   u'actions',
#   u'met',
#   u'months',
#   u'iraq',
#   u'worse',
#   u'residents',
#   u'funding',
#   u'population',
#   u'knows',
#   u'air',
#   u'fighting',
#   u'fall',
#   u'expected',
#   u'governor',
#   u'near',
#   u'consider',
#   u'throughout',
#   u'showed',
#   u'popular',
#   u'donald',
#   u'legislation',
#   u'website',
#   u'room',
#   u'christian',
#   u'key',
#   u'largest',
#   u'piece',
#   u'voting',
#   u'mr',
#   u'leader',
#   u'build',
#   u'2008',
#   u'14',
#   u'particular',
#   u'site',
#   u'works',
#   u'religious',
#   u'short',
#   u'guns',
#   u'employees',
#   u'13',
#   u'activists',
#   u'union',
#   u'cities',
#   u'powerful',
#   u'politicians',
#   u'corporate',
#   u'upon',
#   u'quickly',
#   u'market',
#   u'threat',
#   u'lets',
#   u'decades',
#   u'completely',
#   u'forced',
#   u'easy',
#   u'meanwhile',
#   u'per',
#   u'services',
#   u'significant',
#   u'events',
#   u'programs',
#   u'incident',
#   u'7',
#   u'cover',
#   u'interest',
#   u'8',
#   u'service',
#   u'syria',
#   u'protest',
#   u'hundreds',
#   u'saturday',
#   u'changes',
#   u'common',
#   u'ca',
#   u'summer',
#   u'changed',
#   u'light',
#   u'killing',
#   u'rise',
#   u'available',
#   u'rally',
#   u'special',
#   u'third',
#   u'huge',
#   u'described',
#   u'michael',
#   u'kill',
#   u'worth',
#   u'heart',
#   u'member',
#   u'network',
#   u'racism',
#   u'writes',
#   u'financial',
#   u'daughter',
#   u'effect',
#   u'appeared',
#   u'included',
#   u'staff',
#   u'hair',
#   u'check',
#   u'individuals',
#   u'continues',
#   u'bit',
#   u'myself',
#   u'host',
#   u'whom',
#   u'offer',
#   u'16',
#   u'husband',
#   u'born',
#   u'2011',
#   u'development',
#   u'social_media',
#   u'indeed',
#   u'18',
#   u'ban',
#   u'wouldnt',
#   u'environment',
#   u'biggest',
#   u'raised',
#   u'whatever',
#   u'republican_party',
#   u'male',
#   u'writing',
#   u'rubio',
#   u'comment',
#   u'ryan',
#   u'behavior',
#   u'davis',
#   u'charges',
#   u'happy',
#   u'immediately',
#   u'total',
#   u'voice',
#   u'considered',
#   u'planned_parenthood',
#   u'hate',
#   u'apparently',
#   u'season',
#   u'secretary',
#   u'accused',
#   u'drug',
#   u'internet',
#   u'senator',
#   u'named',
#   u'ability',
#   u'individual',
#   u'charged',
#   u'low',
#   u'seeing',
#   ...],
#  'iter': 5,
#  'layer1_size': 500,
#  'max_vocab_size': None,
#  'min_alpha': 0.0001,
#  'min_alpha_yet_reached': 0.025,
#  'min_count': 50,
#  'negative': 5,
#  'null_word': 0,
#  'random': <mtrand.RandomState at 0x7f5ec82505f0>,
#  'raw_vocab': defaultdict(int, {}),
#  'sample': 0.001,
#  'seed': 1,
#  'sg': 1,
#  'sorted_vocab': 1,
#  'syn0': array([[ 0.04412198,  0.04126843,  0.03222797, ..., -0.03126742,
#          -0.02378272,  0.014687  ],
#         [-0.09569652, -0.13499482,  0.08647764, ...,  0.01186108,
#           0.08204734,  0.09780358],
#         [-0.05253841, -0.06765065, -0.00391576, ...,  0.02967696,
#          -0.06038539,  0.04016097],
#         ...,
#         [-0.4179889 , -0.12189628, -0.0081309 , ..., -0.23566812,
#           0.29712912,  0.34125271],
#         [ 0.14888288, -0.06434711, -0.41098171, ..., -0.21999934,
#          -0.22550026,  0.4358716 ],
#         [-0.07957209,  0.00675696,  0.08101031, ...,  0.02065842,
#          -0.03209347,  0.20302969]], dtype=float32),
#  'syn0_lockf': array([ 1.,  1.,  1., ...,  1.,  1.,  1.], dtype=float32),
#  'syn0norm': array([[ 0.02609223,  0.02440474,  0.01905852, ..., -0.01849048,
#          -0.01406429,  0.00868539],
#         [-0.04985407, -0.07032692,  0.0450514 , ...,  0.00617915,
#           0.0427434 ,  0.05095177],
#         [-0.02800147, -0.03605586, -0.00208699, ...,  0.01581697,
#          -0.03218368,  0.02140464],
#         ...,
#         [-0.1015855 , -0.02962494, -0.00197608, ..., -0.05727536,
#           0.07221247,  0.082936  ],
#         [ 0.03674534, -0.01588132, -0.10143317, ..., -0.05429738,
#          -0.05565504,  0.10757617],
#         [-0.01682475,  0.00142869,  0.01712885, ...,  0.00436802,
#          -0.00678585,  0.04292866]], dtype=float32),
#  'syn1': array([[ 0.22276571,  0.07350817, -0.17732705, ...,  0.09142705,
#          -0.08951948, -0.04631097],
#         [-0.30368847,  0.10727187,  0.02126308, ..., -0.13368958,
#           0.15011187, -0.07951784],
#         [ 0.08677649,  0.09422456, -0.04056401, ...,  0.24203561,
#           0.02261668, -0.05776676],
#         ...,
#         [ 0.02023255, -0.04727736, -0.00396319, ...,  0.00662886,
#           0.00993939,  0.02156939],
#         [ 0.00480661,  0.00371206,  0.05936233, ..., -0.05617194,
#          -0.00326604, -0.05528926],
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        ,  0.        ]], dtype=float32),
#  'syn1neg': array([[-0.18167958, -0.16059749,  0.00830156, ..., -0.02148832,
#          -0.03013442, -0.25584295],
#         [-0.122453  , -0.01054856, -0.15081567, ...,  0.00322603,
#          -0.08479241, -0.14267312],
#         [ 0.07849932,  0.01407009, -0.01874538, ..., -0.11341409,
#          -0.03810177, -0.40452364],
#         ...,
#         [-0.40986404, -0.13849951,  0.28541565, ...,  0.05367824,
#           0.33099002, -0.25190777],
#         [ 0.21065758, -0.30532396, -0.15501451, ..., -0.13355212,
#           0.20186479, -0.11127635],
#         [-0.05584595,  0.15033823, -0.21627206, ..., -0.05126814,
#           0.27653417, -0.24248914]], dtype=float32),
#  'total_train_time': 2855.10529589653,
#  'train_count': 1,
#  'vector_size': 500,
#  'vocab': {u'fawn': <gensim.models.word2vec.Vocab at 0x7f5ec7165350>,
#   u'deferment': <gensim.models.word2vec.Vocab at 0x7f5ec71653d0>,
#   u'facebook_post': <gensim.models.word2vec.Vocab at 0x7f5ec7165450>,
#   u'circuitry': <gensim.models.word2vec.Vocab at 0x7f5ec7165490>,
#   u'spiders': <gensim.models.word2vec.Vocab at 0x7f5ec7165510>,
#   u'hanging': <gensim.models.word2vec.Vocab at 0x7f5ec7170b10>,
#   u'woody': <gensim.models.word2vec.Vocab at 0x7f5ec71655d0>,
#   u'trawling': <gensim.models.word2vec.Vocab at 0x7f5ec7165610>,
#   u'gop_presidential_nominee': <gensim.models.word2vec.Vocab at 0x7f5ec7165690>,
#   u'comically': <gensim.models.word2vec.Vocab at 0x7f5ec71656d0>,
#   u'localized': <gensim.models.word2vec.Vocab at 0x7f5ec7165710>,
#   u'higher_minimum_wage': <gensim.models.word2vec.Vocab at 0x7f5ec7165750>,
#   u'disobeying': <gensim.models.word2vec.Vocab at 0x7f5ec7165790>,
#   u'saylor': <gensim.models.word2vec.Vocab at 0x7f5ec7165810>,
#   u'children_ages': <gensim.models.word2vec.Vocab at 0x7f5ec7165890>,
#   u'lenca': <gensim.models.word2vec.Vocab at 0x7f5ec7165950>,
#   u'sinjar': <gensim.models.word2vec.Vocab at 0x7f5ec5778290>,
#   u'scold': <gensim.models.word2vec.Vocab at 0x7f5ec7165a10>,
#   u'yusaf': <gensim.models.word2vec.Vocab at 0x7f5ec7165a90>,
#   u'originality': <gensim.models.word2vec.Vocab at 0x7f5ec7165b10>,
#   u'tony_blair': <gensim.models.word2vec.Vocab at 0x7f5ec7165b90>,
#   u'rickman': <gensim.models.word2vec.Vocab at 0x7f5ec7165bd0>,
#   u'patriarchy': <gensim.models.word2vec.Vocab at 0x7f5ec68ae610>,
#   u'mateens': <gensim.models.word2vec.Vocab at 0x7f5ec7165c10>,
#   u'june_22': <gensim.models.word2vec.Vocab at 0x7f5ec7165c50>,
#   u'june_23': <gensim.models.word2vec.Vocab at 0x7f5ec7165c90>,
#   u'june_20': <gensim.models.word2vec.Vocab at 0x7f5ec7165cd0>,
#   u'june_21': <gensim.models.word2vec.Vocab at 0x7f5ec7165d10>,
#   u'june_26': <gensim.models.word2vec.Vocab at 0x7f5ec7165d90>,
#   u'june_27': <gensim.models.word2vec.Vocab at 0x7f5ec7165dd0>,
#   u'june_24': <gensim.models.word2vec.Vocab at 0x7f5ec7165e50>,
#   u'june_25': <gensim.models.word2vec.Vocab at 0x7f5ec7165e90>,
#   u'june_28': <gensim.models.word2vec.Vocab at 0x7f5ec7165ed0>,
#   u'june_29': <gensim.models.word2vec.Vocab at 0x7f5ec7165f10>,
#   u'fourteenth_amendment': <gensim.models.word2vec.Vocab at 0x7f5ec7165f50>,
#   u'houston_equal_rights_ordinance': <gensim.models.word2vec.Vocab at 0x7f5ec7165f90>,
#   u'stipulate': <gensim.models.word2vec.Vocab at 0x7f5ec7170050>,
#   u'pigment': <gensim.models.word2vec.Vocab at 0x7f5ec71700d0>,
#   u'sexual_harassment_allegations': <gensim.models.word2vec.Vocab at 0x7f5ec7170150>,
#   u'appropriation': <gensim.models.word2vec.Vocab at 0x7f5ec71701d0>,
#   u'taj': <gensim.models.word2vec.Vocab at 0x7f5ec3411c90>,
#   u'misunderstands': <gensim.models.word2vec.Vocab at 0x7f5ec57a29d0>,
#   u'broward': <gensim.models.word2vec.Vocab at 0x7f5ec7170290>,
#   u'screaming': <gensim.models.word2vec.Vocab at 0x7f5ec719ad90>,
#   u'four': <gensim.models.word2vec.Vocab at 0x7f5ec5778350>,
#   u'wooded': <gensim.models.word2vec.Vocab at 0x7f5ec7170390>,
#   u'receiving': <gensim.models.word2vec.Vocab at 0x7f5ec7170410>,
#   u'liaisons': <gensim.models.word2vec.Vocab at 0x7f5ec7170450>,
#   u'grueling': <gensim.models.word2vec.Vocab at 0x7f5ec71704d0>,
#   u'broiler': <gensim.models.word2vec.Vocab at 0x7f5ec7170510>,
#   u'wooden': <gensim.models.word2vec.Vocab at 0x7f5ec7170590>,
#   u'wednesday': <gensim.models.word2vec.Vocab at 0x7f5ec71705d0>,
#   u'tambin': <gensim.models.word2vec.Vocab at 0x7f5ec7170610>,
#   u'woods': <gensim.models.word2vec.Vocab at 0x7f5ec71706d0>,
#   u'crotch': <gensim.models.word2vec.Vocab at 0x7f5ec7170710>,
#   u'gas_companies': <gensim.models.word2vec.Vocab at 0x7f5ec7170750>,
#   u'deferments': <gensim.models.word2vec.Vocab at 0x7f5ec71707d0>,
#   u'positive_reviews': <gensim.models.word2vec.Vocab at 0x7f5ec7170850>,
#   u'outsports': <gensim.models.word2vec.Vocab at 0x7f5ec71708d0>,
#   u'alfredo': <gensim.models.word2vec.Vocab at 0x7f5ec3e0e310>,
#   u'guardsmen': <gensim.models.word2vec.Vocab at 0x7f5ec7170950>,
#   u'reutersipsos': <gensim.models.word2vec.Vocab at 0x7f5ec71709d0>,
#   u'genesee_county': <gensim.models.word2vec.Vocab at 0x7f5ec7170a50>,
#   u'inevitably': <gensim.models.word2vec.Vocab at 0x7f5ec5fe1250>,
#   u'francesco': <gensim.models.word2vec.Vocab at 0x7f5ec5f29c10>,
#   u'scrapes': <gensim.models.word2vec.Vocab at 0x7f5ec7170b50>,
#   u'force-fed': <gensim.models.word2vec.Vocab at 0x7f5ec7170bd0>,
#   u'270': <gensim.models.word2vec.Vocab at 0x7f5ec7170c50>,
#   u'271': <gensim.models.word2vec.Vocab at 0x7f5ec7170c90>,
#   u'272': <gensim.models.word2vec.Vocab at 0x7f5ec7170d10>,
#   u'273': <gensim.models.word2vec.Vocab at 0x7f5ec7170d90>,
#   u'274': <gensim.models.word2vec.Vocab at 0x7f5ec7170e10>,
#   u'275': <gensim.models.word2vec.Vocab at 0x7f5ec7170e90>,
#   u'276': <gensim.models.word2vec.Vocab at 0x7f5ec7170ed0>,
#   u'277': <gensim.models.word2vec.Vocab at 0x7f5ec7170f50>,
#   u'278': <gensim.models.word2vec.Vocab at 0x7f5ec7170fd0>,
#   u'279': <gensim.models.word2vec.Vocab at 0x7f5ec717a090>,
#   u'scraped': <gensim.models.word2vec.Vocab at 0x7f5ec717a110>,
#   u'glossip': <gensim.models.word2vec.Vocab at 0x7f5ec717a190>,
#   u'errors': <gensim.models.word2vec.Vocab at 0x7f5ec717a1d0>,
#   u'lead_author': <gensim.models.word2vec.Vocab at 0x7f5ec717a210>,
#   u'self-reliant': <gensim.models.word2vec.Vocab at 0x7f5ec717a250>,
#   u'cooking': <gensim.models.word2vec.Vocab at 0x7f5ec714d690>,
#   u'4': <gensim.models.word2vec.Vocab at 0x7f5ec5bb47d0>,
#   u'opportunists': <gensim.models.word2vec.Vocab at 0x7f5ec3536ad0>,
#   u'hateful_eight': <gensim.models.word2vec.Vocab at 0x7f5ec717a310>,
#   u'warmongering': <gensim.models.word2vec.Vocab at 0x7f5ec717a350>,
#   u'high-dollar': <gensim.models.word2vec.Vocab at 0x7f5ec717a3d0>,
#   u'designing': <gensim.models.word2vec.Vocab at 0x7f5ec717a450>,
#   u'televangelists': <gensim.models.word2vec.Vocab at 0x7f5ec717a490>,
#   u'day-to-day_lives': <gensim.models.word2vec.Vocab at 0x7f5ec717a510>,
#   u'succumb': <gensim.models.word2vec.Vocab at 0x7f5ec717a590>,
#   u'shocks': <gensim.models.word2vec.Vocab at 0x7f5ec717a5d0>,
#   u'crouch': <gensim.models.word2vec.Vocab at 0x7f5ec717a610>,
#   u'misdemeanor_charges': <gensim.models.word2vec.Vocab at 0x7f5ec717a690>,
#   u'brainwashed': <gensim.models.word2vec.Vocab at 0x7f5ec717a750>,
#   u'affiliates': <gensim.models.word2vec.Vocab at 0x7f5ec717a790>,
#   u'systemic_racism': <gensim.models.word2vec.Vocab at 0x7f5ec717a890>,
#   u'china': <gensim.models.word2vec.Vocab at 0x7f5ec717a8d0>,
#   u'shandling': <gensim.models.word2vec.Vocab at 0x7f5ec717a990>,
#   u'deep_cuts': <gensim.models.word2vec.Vocab at 0x7f5ec717aa10>,
#   u'less_than_5_percent': <gensim.models.word2vec.Vocab at 0x7f5ec717aa90>,
#   u'melinda_gates_foundation': <gensim.models.word2vec.Vocab at 0x7f5ec717ab10>,
#   u'benghazi_attack': <gensim.models.word2vec.Vocab at 0x7f5ec717ab90>,
#   u'reggae': <gensim.models.word2vec.Vocab at 0x7f5ec56ba210>,
#   u'ba_odah': <gensim.models.word2vec.Vocab at 0x7f5ec717abd0>,
#   u'uplifting': <gensim.models.word2vec.Vocab at 0x7f5ec717ac50>,
#   u'telling_reporters': <gensim.models.word2vec.Vocab at 0x7f5ec717ac90>,
#   u'slaveholders': <gensim.models.word2vec.Vocab at 0x7f5ec717acd0>,
#   u'deferring': <gensim.models.word2vec.Vocab at 0x7f5ec717ad50>,
#   u'controversy': <gensim.models.word2vec.Vocab at 0x7f5ec717ae50>,
#   u'previous_debates': <gensim.models.word2vec.Vocab at 0x7f5ec717ae90>,
#   u'heart_rate': <gensim.models.word2vec.Vocab at 0x7f5ec717af10>,
#   u'kidd': <gensim.models.word2vec.Vocab at 0x7f5ec717af50>,
#   u'creating_jobs': <gensim.models.word2vec.Vocab at 0x7f5ec717af90>,
#   u'natures': <gensim.models.word2vec.Vocab at 0x7f5ec717afd0>,
#   u'neurologist': <gensim.models.word2vec.Vocab at 0x7f5ec7182050>,
#   u'spotty': <gensim.models.word2vec.Vocab at 0x7f5ec71820d0>,
#   u'climber': <gensim.models.word2vec.Vocab at 0x7f5ec7182190>,
#   u'rebel': <gensim.models.word2vec.Vocab at 0x7f5ec7182210>,
#   u'appropriately': <gensim.models.word2vec.Vocab at 0x7f5ec7182250>,
#   u'topography': <gensim.models.word2vec.Vocab at 0x7f5ec7182290>,
#   u'hate_groups': <gensim.models.word2vec.Vocab at 0x7f5ec7182310>,
#   u'projection': <gensim.models.word2vec.Vocab at 0x7f5ec7182350>,
#   u'wikimedia': <gensim.models.word2vec.Vocab at 0x7f5ec7182410>,
#   u'mclaurin': <gensim.models.word2vec.Vocab at 0x7f5ec7182450>,
#   u'lawsuit_alleges': <gensim.models.word2vec.Vocab at 0x7f5ec71824d0>,
#   u'stern': <gensim.models.word2vec.Vocab at 0x7f5ec7182550>,
#   u'pew_study': <gensim.models.word2vec.Vocab at 0x7f5ec7182650>,
#   u'dna': <gensim.models.word2vec.Vocab at 0x7f5ec71826d0>,
#   u'dnc': <gensim.models.word2vec.Vocab at 0x7f5ec7182710>,
#   u'catchy': <gensim.models.word2vec.Vocab at 0x7f5ec7182750>,
#   u'insecurity': <gensim.models.word2vec.Vocab at 0x7f5ec7182790>,
#   u'trade_associations': <gensim.models.word2vec.Vocab at 0x7f5ec71827d0>,
#   u'high_degree': <gensim.models.word2vec.Vocab at 0x7f5ec7182850>,
#   u'cannibal': <gensim.models.word2vec.Vocab at 0x7f5ec71828d0>,
#   u'inevitable': <gensim.models.word2vec.Vocab at 0x7f5ec5fe1510>,
#   u'incomplete': <gensim.models.word2vec.Vocab at 0x7f5ec3f190d0>,
#   u'ramstein': <gensim.models.word2vec.Vocab at 0x7f5ec7182990>,
#   u'music': <gensim.models.word2vec.Vocab at 0x7f5ec7182a10>,
#   u'therefore': <gensim.models.word2vec.Vocab at 0x7f5ec7182a50>,
#   u'distortions': <gensim.models.word2vec.Vocab at 0x7f5ec7182a90>,
#   u'grahams': <gensim.models.word2vec.Vocab at 0x7f5ec7182b50>,
#   u'futurefreebandz': <gensim.models.word2vec.Vocab at 0x7f5ec7182b90>,
#   u'sermons': <gensim.models.word2vec.Vocab at 0x7f5ec7182c10>,
#   u'populations': <gensim.models.word2vec.Vocab at 0x7f5ec7182c50>,
#   u'anti-gun': <gensim.models.word2vec.Vocab at 0x7f5ec7182c90>,
#   u'crooner': <gensim.models.word2vec.Vocab at 0x7f5ec5778790>,
#   u'house_benghazi_committee': <gensim.models.word2vec.Vocab at 0x7f5ec7182d10>,
#   u'meteorologist': <gensim.models.word2vec.Vocab at 0x7f5ec7182d90>,
#   u'hermann': <gensim.models.word2vec.Vocab at 0x7f5ec7182dd0>,
#   u'scottie_nell_hughes': <gensim.models.word2vec.Vocab at 0x7f5ec7182e50>,
#   u'expeditionary': <gensim.models.word2vec.Vocab at 0x7f5ec7182ed0>,
#   u'harmless': <gensim.models.word2vec.Vocab at 0x7f5ec3467650>,
#   u'officer-involved_shootings': <gensim.models.word2vec.Vocab at 0x7f5ec4323b50>,
#   u'unpack': <gensim.models.word2vec.Vocab at 0x7f5ec718e0d0>,
#   u'blustering': <gensim.models.word2vec.Vocab at 0x7f5ec70c5690>,
#   u'intake': <gensim.models.word2vec.Vocab at 0x7f5ec718e150>,
#   u'corporate_media': <gensim.models.word2vec.Vocab at 0x7f5ec718e190>,
#   u'locked': <gensim.models.word2vec.Vocab at 0x7f5ec718e1d0>,
#   u'kampala': <gensim.models.word2vec.Vocab at 0x7f5ec718e210>,
#   u'locker': <gensim.models.word2vec.Vocab at 0x7f5ec718e290>,
#   u'halloween_costume': <gensim.models.word2vec.Vocab at 0x7f5ec718e2d0>,
#   u'soundbite': <gensim.models.word2vec.Vocab at 0x7f5ec718e350>,
#   u'certain_aspects': <gensim.models.word2vec.Vocab at 0x7f5ec718e3d0>,
#   u'twelve_years': <gensim.models.word2vec.Vocab at 0x7f5ec718e450>,
#   u'mark_cuban': <gensim.models.word2vec.Vocab at 0x7f5ec718e4d0>,
#   u'stock_options': <gensim.models.word2vec.Vocab at 0x7f5ec718e510>,
#   u'wang': <gensim.models.word2vec.Vocab at 0x7f5ec718e590>,
#   u'wand': <gensim.models.word2vec.Vocab at 0x7f5ec718e5d0>,
#   u'hyatt': <gensim.models.word2vec.Vocab at 0x7f5ec718e650>,
#   u'grass-fed': <gensim.models.word2vec.Vocab at 0x7f5ec718e690>,
#   u'civil_rights_laws': <gensim.models.word2vec.Vocab at 0x7f5ec718e6d0>,
#   u'disparagement': <gensim.models.word2vec.Vocab at 0x7f5ec718e710>,
#   u'titanium': <gensim.models.word2vec.Vocab at 0x7f5ec718e7d0>,
#   u'white_counterparts': <gensim.models.word2vec.Vocab at 0x7f5ec6aa6a50>,
#   u'clarence_thomas': <gensim.models.word2vec.Vocab at 0x7f5ec718e8d0>,
#   u'want': <gensim.models.word2vec.Vocab at 0x7f5ec718e910>,
#   u'pinto': <gensim.models.word2vec.Vocab at 0x7f5ec718e950>,
#   u'absolute': <gensim.models.word2vec.Vocab at 0x7f5ec718e9d0>,
#   u'well-armed': <gensim.models.word2vec.Vocab at 0x7f5ec718ea10>,
#   u'mcmuffin': <gensim.models.word2vec.Vocab at 0x7f5ec718ead0>,
#   u'button-down': <gensim.models.word2vec.Vocab at 0x7f5ec718eb50>,
#   u'beyer': <gensim.models.word2vec.Vocab at 0x7f5ec718ebd0>,
#   u'travel': <gensim.models.word2vec.Vocab at 0x7f5ec718ec50>,
#   u'copious': <gensim.models.word2vec.Vocab at 0x7f5ec718ec90>,
#   u'hough': <gensim.models.word2vec.Vocab at 0x7f5ec5778a10>,
#   u'tennis_star': <gensim.models.word2vec.Vocab at 0x7f5ec718ed90>,
#   u'dared': <gensim.models.word2vec.Vocab at 0x7f5ec3440050>,
#   u'math_teacher': <gensim.models.word2vec.Vocab at 0x7f5ec718ee10>,
#   u'canaries': <gensim.models.word2vec.Vocab at 0x7f5ec718ee90>,
#   u'cadence': <gensim.models.word2vec.Vocab at 0x7f5ec718ef10>,
#   u'pearl_harbor': <gensim.models.word2vec.Vocab at 0x7f5ec718ef50>,
#   u'civilian_deaths': <gensim.models.word2vec.Vocab at 0x7f5ec718ef90>,
#   u'assimilated': <gensim.models.word2vec.Vocab at 0x7f5ec718efd0>,
#   u'highsmith': <gensim.models.word2vec.Vocab at 0x7f5ec719a090>,
#   u'buy-in': <gensim.models.word2vec.Vocab at 0x7f5ec4323f50>,
#   u'dinosaurs': <gensim.models.word2vec.Vocab at 0x7f5ec719a1d0>,
#   u'modest': <gensim.models.word2vec.Vocab at 0x7f5ec719a210>,
#   u'social_mobility': <gensim.models.word2vec.Vocab at 0x7f5ec719a250>,
#   u'public_persona': <gensim.models.word2vec.Vocab at 0x7f5ec719a2d0>,
#   u'pickup_trucks': <gensim.models.word2vec.Vocab at 0x7f5ec719a350>,
#   u'off-label': <gensim.models.word2vec.Vocab at 0x7f5ec719a3d0>,
#   u'militant_groups': <gensim.models.word2vec.Vocab at 0x7f5ec719a490>,
#   u'colorfully': <gensim.models.word2vec.Vocab at 0x7f5ec719a510>,
#   u'old_adage': <gensim.models.word2vec.Vocab at 0x7f5ec719a590>,
#   u'harvests': <gensim.models.word2vec.Vocab at 0x7f5ec42f1590>,
#   u'fat_cats': <gensim.models.word2vec.Vocab at 0x7f5ec432b050>,
#   u'sickening': <gensim.models.word2vec.Vocab at 0x7f5ec719a610>,
#   u'tulip': <gensim.models.word2vec.Vocab at 0x7f5ec719a650>,
#   u'18th': <gensim.models.word2vec.Vocab at 0x7f5ec719a6d0>,
#   u'purdue_university': <gensim.models.word2vec.Vocab at 0x7f5ec719a710>,
#   u'devastating_impact': <gensim.models.word2vec.Vocab at 0x7f5ec719a790>,
#   u'farmlands': <gensim.models.word2vec.Vocab at 0x7f5ec719a7d0>,
#   u'nonsensical': <gensim.models.word2vec.Vocab at 0x7f5ec719a850>,
#   u'jason_van_dyke': <gensim.models.word2vec.Vocab at 0x7f5ec719a890>,
#   u'evangelical_community': <gensim.models.word2vec.Vocab at 0x7f5ec5fe1a10>,
#   u'pittenger': <gensim.models.word2vec.Vocab at 0x7f5ec719a910>,
#   u'welcomed': <gensim.models.word2vec.Vocab at 0x7f5ec719a990>,
#   u'concurrence': <gensim.models.word2vec.Vocab at 0x7f5ec719a9d0>,
#   u'unrealistic_expectations': <gensim.models.word2vec.Vocab at 0x7f5ec719aa50>,
#   u'partnered': <gensim.models.word2vec.Vocab at 0x7f5ec719aad0>,
#   u'sidekicks': <gensim.models.word2vec.Vocab at 0x7f5ec719ab10>,
#   u'rewarded': <gensim.models.word2vec.Vocab at 0x7f5ec719ab90>,
#   u'activating': <gensim.models.word2vec.Vocab at 0x7f5ec719abd0>,
#   u'angeles-based': <gensim.models.word2vec.Vocab at 0x7f5ec33ec890>,
#   u'welcomes': <gensim.models.word2vec.Vocab at 0x7f5ec719ac50>,
#   u'fir': <gensim.models.word2vec.Vocab at 0x7f5ec719ac90>,
#   u'fit': <gensim.models.word2vec.Vocab at 0x7f5ec719ad10>,
#   u'benign': <gensim.models.word2vec.Vocab at 0x7f5ec432b290>,
#   u'lifeline': <gensim.models.word2vec.Vocab at 0x7f5ec719ad50>,
#   u'bringing': <gensim.models.word2vec.Vocab at 0x7f5ec71702d0>,
#   u'fix': <gensim.models.word2vec.Vocab at 0x7f5ec719add0>,
#   u'discourse': <gensim.models.word2vec.Vocab at 0x7f5ec432b2d0>,
#   u'folate': <gensim.models.word2vec.Vocab at 0x7f5ec719ae90>,
#   u'fig': <gensim.models.word2vec.Vocab at 0x7f5ec719af10>,
#   u'wales': <gensim.models.word2vec.Vocab at 0x7f5ec6c27a90>,
#   u'today_president_obama': <gensim.models.word2vec.Vocab at 0x7f5ec6724910>,
#   u'fin': <gensim.models.word2vec.Vocab at 0x7f5ec7123050>,
#   u'million_barrels': <gensim.models.word2vec.Vocab at 0x7f5ec7123090>,
#   u'zucker': <gensim.models.word2vec.Vocab at 0x7f5ec71230d0>,
#   u'shenkman': <gensim.models.word2vec.Vocab at 0x7f5ec7123190>,
#   u'songwriter': <gensim.models.word2vec.Vocab at 0x7f5ec71231d0>,
#   u'vouchers': <gensim.models.word2vec.Vocab at 0x7f5ec7123210>,
#   u'memorialize': <gensim.models.word2vec.Vocab at 0x7f5ec6edaa10>,
#   u'effects': <gensim.models.word2vec.Vocab at 0x7f5ec7123350>,
#   u'uttering': <gensim.models.word2vec.Vocab at 0x7f5ec5778f50>,
#   u'multidimensional': <gensim.models.word2vec.Vocab at 0x7f5ec7123410>,
#   u'sixteen': <gensim.models.word2vec.Vocab at 0x7f5ec7123490>,
#   u'undeveloped': <gensim.models.word2vec.Vocab at 0x7f5ec71234d0>,
#   u'housing_authority': <gensim.models.word2vec.Vocab at 0x7f5ec7123550>,
#   u'castigating': <gensim.models.word2vec.Vocab at 0x7f5ec7123590>,
#   u'direct_connection': <gensim.models.word2vec.Vocab at 0x7f5ec7123610>,
#   u'junk_food': <gensim.models.word2vec.Vocab at 0x7f5ec7123690>,
#   u'disconnection': <gensim.models.word2vec.Vocab at 0x7f5ec71236d0>,
#   u'self-titled': <gensim.models.word2vec.Vocab at 0x7f5ec7123750>,
#   u'ingrid': <gensim.models.word2vec.Vocab at 0x7f5ec71237d0>,
#   u'recent_case': <gensim.models.word2vec.Vocab at 0x7f5ec7123850>,
#   u'burial': <gensim.models.word2vec.Vocab at 0x7f5ec71238d0>,
#   u'telescope': <gensim.models.word2vec.Vocab at 0x7f5ec7123910>,
#   u'outfront': <gensim.models.word2vec.Vocab at 0x7f5ec7123950>,
#   u'drug-resistant': <gensim.models.word2vec.Vocab at 0x7f5ec71239d0>,
#   u'allah': <gensim.models.word2vec.Vocab at 0x7f5ec7123a50>,
#   u'allan': <gensim.models.word2vec.Vocab at 0x7f5ec7123a90>,
#   u'parasites': <gensim.models.word2vec.Vocab at 0x7f5ec7123ad0>,
#   u'think_tanks': <gensim.models.word2vec.Vocab at 0x7f5ec7123b10>,
#   u'quora': <gensim.models.word2vec.Vocab at 0x7f5ec43bcb10>,
#   u'390': <gensim.models.word2vec.Vocab at 0x7f5ec6ffc850>,
#   u'intimate_details': <gensim.models.word2vec.Vocab at 0x7f5ec7123b90>,
#   u'nfl_game': <gensim.models.word2vec.Vocab at 0x7f5ec7123c10>,
#   u'395': <gensim.models.word2vec.Vocab at 0x7f5ec7123c90>,
#   u'allay': <gensim.models.word2vec.Vocab at 0x7f5ec7123d10>,
#   u'tricked': <gensim.models.word2vec.Vocab at 0x7f5ec37e3350>,
#   u'operation_rescue': <gensim.models.word2vec.Vocab at 0x7f5ec7123dd0>,
#   u'jeffrey_lord': <gensim.models.word2vec.Vocab at 0x7f5ec7123e10>,
#   u'forwarding': <gensim.models.word2vec.Vocab at 0x7f5ec7123e50>,
#   u'touts': <gensim.models.word2vec.Vocab at 0x7f5ec7123f50>,
#   u'oprah': <gensim.models.word2vec.Vocab at 0x7f5ec7123f90>,
#   u'smirk': <gensim.models.word2vec.Vocab at 0x7f5ec7123fd0>,
#   u'brutish': <gensim.models.word2vec.Vocab at 0x7f5ec5782290>,
#   u'mason': <gensim.models.word2vec.Vocab at 0x7f5ec712f110>,
#   u'mazur': <gensim.models.word2vec.Vocab at 0x7f5ec712f150>,
#   u'morgan_freeman': <gensim.models.word2vec.Vocab at 0x7f5ec712f1d0>,
#   u'encourage': <gensim.models.word2vec.Vocab at 0x7f5ec712f250>,
#   u'charles_krauthammer': <gensim.models.word2vec.Vocab at 0x7f5ec712f290>,
#   u'adapt': <gensim.models.word2vec.Vocab at 0x7f5ec712f2d0>,
#   u'swiftmud': <gensim.models.word2vec.Vocab at 0x7f5ec712f310>,
#   u'national_security_officials': <gensim.models.word2vec.Vocab at 0x7f5ec712f390>,
#   u'smithfield': <gensim.models.word2vec.Vocab at 0x7f5ec712f410>,
#   u'tennessean': <gensim.models.word2vec.Vocab at 0x7f5ec712f490>,
#   u'misrepresentations': <gensim.models.word2vec.Vocab at 0x7f5ec712f4d0>,
#   u'abbott': <gensim.models.word2vec.Vocab at 0x7f5ec712f550>,
#   u'stamping': <gensim.models.word2vec.Vocab at 0x7f5ec712f590>,
#   u'chicago_tribune_reports': <gensim.models.word2vec.Vocab at 0x7f5ec712f610>,
#   u'strata': <gensim.models.word2vec.Vocab at 0x7f5ec712f690>,
#   u'pumpkins': <gensim.models.word2vec.Vocab at 0x7f5ec712f710>,
#   u'corrects': <gensim.models.word2vec.Vocab at 0x7f5ec712f750>,
#   u'stereotypical': <gensim.models.word2vec.Vocab at 0x7f5ec712f7d0>,
#   u'berwick': <gensim.models.word2vec.Vocab at 0x7f5ec712f810>,
#   u'creative_director': <gensim.models.word2vec.Vocab at 0x7f5ec712f890>,
#   u'gameplay': <gensim.models.word2vec.Vocab at 0x7f5ec712f8d0>,
#   u'universally': <gensim.models.word2vec.Vocab at 0x7f5ec712f950>,
#   u'chlorine': <gensim.models.word2vec.Vocab at 0x7f5ec712f990>,
#   u'silent': <gensim.models.word2vec.Vocab at 0x7f5ec5feb150>,
#   u'competes': <gensim.models.word2vec.Vocab at 0x7f5ec712fa50>,
#   u'mixed_bag': <gensim.models.word2vec.Vocab at 0x7f5ec712fad0>,
#   u'criminologists': <gensim.models.word2vec.Vocab at 0x7f5ec712fb50>,
#   u'rutenberg': <gensim.models.word2vec.Vocab at 0x7f5ec712fbd0>,
#   u'ministries': <gensim.models.word2vec.Vocab at 0x7f5ec712fc50>,
#   u'disturbed': <gensim.models.word2vec.Vocab at 0x7f5ec712fc90>,
#   u'competed': <gensim.models.word2vec.Vocab at 0x7f5ec712fcd0>,
#   u'mendacity': <gensim.models.word2vec.Vocab at 0x7f5ec712fd10>,
#   u'chronic': <gensim.models.word2vec.Vocab at 0x7f5ec3623f10>,
#   u'non-violent': <gensim.models.word2vec.Vocab at 0x7f5ec712fe10>,
#   u'dayton_ohio': <gensim.models.word2vec.Vocab at 0x7f5ec712fe50>,
#   u'breed': <gensim.models.word2vec.Vocab at 0x7f5ec5feb290>,
#   u'disfigured': <gensim.models.word2vec.Vocab at 0x7f5ec712ff10>,
#   u'emaciated': <gensim.models.word2vec.Vocab at 0x7f5ec34e96d0>,
#   u'maladies': <gensim.models.word2vec.Vocab at 0x7f5ec712ff90>,
#   u'erykahbadoula': <gensim.models.word2vec.Vocab at 0x7f5ec7138050>,
#   u'kfc': <gensim.models.word2vec.Vocab at 0x7f5ec71380d0>,
#   u'chevron': <gensim.models.word2vec.Vocab at 0x7f5ec7138110>,
#   u'bill_moyers': <gensim.models.word2vec.Vocab at 0x7f5ec7138150>,
#   u'seizures': <gensim.models.word2vec.Vocab at 0x7f5ec7138190>,
#   u'olds': <gensim.models.word2vec.Vocab at 0x7f5ec71381d0>,
#   u'renovated': <gensim.models.word2vec.Vocab at 0x7f5ec7138250>,
#   u'service': <gensim.models.word2vec.Vocab at 0x7f5ec71382d0>,
#   u'forrester': <gensim.models.word2vec.Vocab at 0x7f5ec7138310>,
#   u'reuben': <gensim.models.word2vec.Vocab at 0x7f5ec71383d0>,
#   u'pregnant_woman': <gensim.models.word2vec.Vocab at 0x7f5ec7138450>,
#   u'needed': <gensim.models.word2vec.Vocab at 0x7f5ec7138490>,
#   u'mind-boggling': <gensim.models.word2vec.Vocab at 0x7f5ec71384d0>,
#   u'master': <gensim.models.word2vec.Vocab at 0x7f5ec7138510>,
#   u'told_newsone': <gensim.models.word2vec.Vocab at 0x7f5ec7138550>,
#   u'genesis': <gensim.models.word2vec.Vocab at 0x7f5ec7138590>,
#   u'caitlyn': <gensim.models.word2vec.Vocab at 0x7f5ec71385d0>,
#   u'rewards': <gensim.models.word2vec.Vocab at 0x7f5ec6f6f550>,
#   u'meltdowns': <gensim.models.word2vec.Vocab at 0x7f5ec7138690>,
#   u'morning-after': <gensim.models.word2vec.Vocab at 0x7f5ec7138710>,
#   u'motionless': <gensim.models.word2vec.Vocab at 0x7f5ec432bc50>,
#   u'mutilated': <gensim.models.word2vec.Vocab at 0x7f5ec7138810>,
#   u'whores': <gensim.models.word2vec.Vocab at 0x7f5ec7138910>,
#   u'backstage': <gensim.models.word2vec.Vocab at 0x7f5ec3f9c290>,
#   u'positively': <gensim.models.word2vec.Vocab at 0x7f5ec71389d0>,
#   u'feasibility': <gensim.models.word2vec.Vocab at 0x7f5ec7138a90>,
#   u'ahmed': <gensim.models.word2vec.Vocab at 0x7f5ec7138ad0>,
#   u'35-year-old': <gensim.models.word2vec.Vocab at 0x7f5ec7138b10>,
#   u'saeed': <gensim.models.word2vec.Vocab at 0x7f5ec7138b50>,
#   u'double-standard': <gensim.models.word2vec.Vocab at 0x7f5ec7138bd0>,
#   u'super_bowl_50': <gensim.models.word2vec.Vocab at 0x7f5ec7138c50>,
#   u'bob_mcdonnell': <gensim.models.word2vec.Vocab at 0x7f5ec3d13410>,
#   u'handcuffs': <gensim.models.word2vec.Vocab at 0x7f5ec7138c90>,
#   u'idly': <gensim.models.word2vec.Vocab at 0x7f5ec7138cd0>,
#   u'iogcc': <gensim.models.word2vec.Vocab at 0x7f5ec7138d10>,
#   u'idle': <gensim.models.word2vec.Vocab at 0x7f5ec7138d90>,
#   u'exclaimed': <gensim.models.word2vec.Vocab at 0x7f5ec7138dd0>,
#   u'friend': <gensim.models.word2vec.Vocab at 0x7f5ec5feb510>,
#   u'shampoos': <gensim.models.word2vec.Vocab at 0x7f5ec7138e50>,
#   u'feeling': <gensim.models.word2vec.Vocab at 0x7f5ec7138ed0>,
#   u'yeezys': <gensim.models.word2vec.Vocab at 0x7f5ec7138f10>,
#   u'big_ag': <gensim.models.word2vec.Vocab at 0x7f5ec7138f90>,
#   u'longs': <gensim.models.word2vec.Vocab at 0x7f5ec7143050>,
#   u'nola': <gensim.models.word2vec.Vocab at 0x7f5ec432bdd0>,
#   u'sustaining': <gensim.models.word2vec.Vocab at 0x7f5ec7143150>,
#   u'spectrum': <gensim.models.word2vec.Vocab at 0x7f5ec4904690>,
#   u'generalistic': <gensim.models.word2vec.Vocab at 0x7f5ec71432d0>,
#   u'consenting': <gensim.models.word2vec.Vocab at 0x7f5ec7143350>,
#   u'gun_range': <gensim.models.word2vec.Vocab at 0x7f5ec6f23790>,
#   u'arousal': <gensim.models.word2vec.Vocab at 0x7f5ec7143450>,
#   u'thaw': <gensim.models.word2vec.Vocab at 0x7f5ec3b45e50>,
#   u'urinate': <gensim.models.word2vec.Vocab at 0x7f5ec7143510>,
#   u'sexual_encounters': <gensim.models.word2vec.Vocab at 0x7f5ec682f110>,
#   u'dozen': <gensim.models.word2vec.Vocab at 0x7f5ec71435d0>,
#   u'foundational': <gensim.models.word2vec.Vocab at 0x7f5ec7143610>,
#   u'affairs': <gensim.models.word2vec.Vocab at 0x7f5ec7143650>,
#   u'wholesome': <gensim.models.word2vec.Vocab at 0x7f5ec7143690>,
#   u'mostly': <gensim.models.word2vec.Vocab at 0x7f5ec71436d0>,
#   u'portillo': <gensim.models.word2vec.Vocab at 0x7f5ec432bed0>,
#   u'paramedics': <gensim.models.word2vec.Vocab at 0x7f5ec71437d0>,
#   u'uncouth': <gensim.models.word2vec.Vocab at 0x7f5ec681b150>,
#   u'julys': <gensim.models.word2vec.Vocab at 0x7f5ec3ec0dd0>,
#   u'child_care': <gensim.models.word2vec.Vocab at 0x7f5ec7143890>,
#   u'snitch': <gensim.models.word2vec.Vocab at 0x7f5ec55fd750>,
#   u'tomdispatchcom': <gensim.models.word2vec.Vocab at 0x7f5ec71438d0>,
#   u'kremlin': <gensim.models.word2vec.Vocab at 0x7f5ec7143910>,
#   u'concedes': <gensim.models.word2vec.Vocab at 0x7f5ec7143950>,
#   u'45th': <gensim.models.word2vec.Vocab at 0x7f5ec7143990>,
#   u'canadian_prime_minister_justin': <gensim.models.word2vec.Vocab at 0x7f5ec71439d0>,
#   u'withdraw': <gensim.models.word2vec.Vocab at 0x7f5ec6236bd0>,
#   u'jammed': <gensim.models.word2vec.Vocab at 0x7f5ec40e4650>,
#   u'sugarcane': <gensim.models.word2vec.Vocab at 0x7f5ec7143a90>,
#   u'four_police_officers': <gensim.models.word2vec.Vocab at 0x7f5ec7143b10>,
#   u'limitless': <gensim.models.word2vec.Vocab at 0x7f5ec7143b90>,
#   u'diminishing': <gensim.models.word2vec.Vocab at 0x7f5ec7143bd0>,
#   u'vexing': <gensim.models.word2vec.Vocab at 0x7f5ec7143c10>,
#   u'cinematic': <gensim.models.word2vec.Vocab at 0x7f5ec7143c90>,
#   u'resonates': <gensim.models.word2vec.Vocab at 0x7f5ec6267e90>,
#   u'metrics': <gensim.models.word2vec.Vocab at 0x7f5ec7143d10>,
#   u'motivational_speaker': <gensim.models.word2vec.Vocab at 0x7f5ec6ec8990>,
#   u'sept_7': <gensim.models.word2vec.Vocab at 0x7f5ec7143d90>,
#   u'icloud': <gensim.models.word2vec.Vocab at 0x7f5ec7143e10>,
#   u'conceded': <gensim.models.word2vec.Vocab at 0x7f5ec7143e90>,
#   u'resonated': <gensim.models.word2vec.Vocab at 0x7f5ec7143ed0>,
#   u'sept_8': <gensim.models.word2vec.Vocab at 0x7f5ec7143f10>,
#   u'expound': <gensim.models.word2vec.Vocab at 0x7f5ec7143f90>,
#   u'climate_change_denier': <gensim.models.word2vec.Vocab at 0x7f5ec714d050>,
#   u'singer': <gensim.models.word2vec.Vocab at 0x7f5ec714d0d0>,
#   u'majd': <gensim.models.word2vec.Vocab at 0x7f5ec714d110>,
#   u'confederation': <gensim.models.word2vec.Vocab at 0x7f5ec4939e90>,
#   u'purges': <gensim.models.word2vec.Vocab at 0x7f5ec714d190>,
#   u'cell_phones': <gensim.models.word2vec.Vocab at 0x7f5ec714d210>,
#   u'new_york_observer': <gensim.models.word2vec.Vocab at 0x7f5ec714d250>,
#   u'committing_crimes': <gensim.models.word2vec.Vocab at 0x7f5ec714d2d0>,
#   u'multiracial': <gensim.models.word2vec.Vocab at 0x7f5ec714d350>,
#   u'leinonen': <gensim.models.word2vec.Vocab at 0x7f5ec714d390>,
#   u'teco': <gensim.models.word2vec.Vocab at 0x7f5ec714d410>,
#   u'tech': <gensim.models.word2vec.Vocab at 0x7f5ec714d490>,
#   u'fugitives': <gensim.models.word2vec.Vocab at 0x7f5ec714d4d0>,
#   u'hiatt': <gensim.models.word2vec.Vocab at 0x7f5ec714d550>,
#   u'told_tpm': <gensim.models.word2vec.Vocab at 0x7f5ec714d5d0>,
#   u'scream': <gensim.models.word2vec.Vocab at 0x7f5ec714d610>,
#   u'saying': <gensim.models.word2vec.Vocab at 0x7f5ec714d650>,
#   u'great_plains': <gensim.models.word2vec.Vocab at 0x7f5ec714d6d0>,
#   u'identity_theft': <gensim.models.word2vec.Vocab at 0x7f5ec714d750>,
#   u'dickey': <gensim.models.word2vec.Vocab at 0x7f5ec714d790>,
#   u'teresa': <gensim.models.word2vec.Vocab at 0x7f5ec714d850>,
#   u'padded': <gensim.models.word2vec.Vocab at 0x7f5ec714d910>,
#   u'tehran': <gensim.models.word2vec.Vocab at 0x7f5ec3b4e190>,
#   u'fennel': <gensim.models.word2vec.Vocab at 0x7f5ec714da10>,
#   u'tempted': <gensim.models.word2vec.Vocab at 0x7f5ec714dad0>,
#   u'cheaply': <gensim.models.word2vec.Vocab at 0x7f5ec714db10>,
#   u'trunews': <gensim.models.word2vec.Vocab at 0x7f5ec714db50>,
#   u'hounded': <gensim.models.word2vec.Vocab at 0x7f5ec714dbd0>,
#   u'ldf': <gensim.models.word2vec.Vocab at 0x7f5ec4334250>,
#   u'apace': <gensim.models.word2vec.Vocab at 0x7f5ec714dc90>,
#   u'clicked': <gensim.models.word2vec.Vocab at 0x7f5ec714dd10>,
#   u'charges': <gensim.models.word2vec.Vocab at 0x7f5ec3b04b10>,
#   u'mass_murderers': <gensim.models.word2vec.Vocab at 0x7f5ec714dd50>,
#   u'rico': <gensim.models.word2vec.Vocab at 0x7f5ec714de50>,
#   u'lube': <gensim.models.word2vec.Vocab at 0x7f5ec714de90>,
#   u'statehouse': <gensim.models.word2vec.Vocab at 0x7f5ec714ded0>,
#   u'bliss': <gensim.models.word2vec.Vocab at 0x7f5ec714df10>,
#   u'rick': <gensim.models.word2vec.Vocab at 0x7f5ec714df50>,
#   u'rich': <gensim.models.word2vec.Vocab at 0x7f5ec714df90>,
#   u'self-driving_cars': <gensim.models.word2vec.Vocab at 0x7f5ec714dfd0>,
#   u'jamyla': <gensim.models.word2vec.Vocab at 0x7f5ec3f230d0>,
#   u'plate': <gensim.models.word2vec.Vocab at 0x7f5ec71580d0>,
#   u'energy_mix': <gensim.models.word2vec.Vocab at 0x7f5ec7158110>,
#   u'harsh_criticism': <gensim.models.word2vec.Vocab at 0x7f5ec7158190>,
#   u'sheriffs_deputy': <gensim.models.word2vec.Vocab at 0x7f5ec7158210>,
#   u'plato': <gensim.models.word2vec.Vocab at 0x7f5ec7158250>,
#   u'jcets': <gensim.models.word2vec.Vocab at 0x7f5ec71582d0>,
#   u'fablife': <gensim.models.word2vec.Vocab at 0x7f5ec7158390>,
#   u'altogether': <gensim.models.word2vec.Vocab at 0x7f5ec7158410>,
#   u'chyron': <gensim.models.word2vec.Vocab at 0x7f5ec7158450>,
#   u'non-hispanic_whites': <gensim.models.word2vec.Vocab at 0x7f5ec43342d0>,
#   u'suicide_attacks': <gensim.models.word2vec.Vocab at 0x7f5ec7158550>,
#   u'droning': <gensim.models.word2vec.Vocab at 0x7f5ec71585d0>,
#   u'jaguar': <gensim.models.word2vec.Vocab at 0x7f5ec71586d0>,
#   u'rectal': <gensim.models.word2vec.Vocab at 0x7f5ec7158750>,
#   u'nicely': <gensim.models.word2vec.Vocab at 0x7f5ec71587d0>,
#   u'accordance': <gensim.models.word2vec.Vocab at 0x7f5ec3b4e4d0>,
#   u'pretzel': <gensim.models.word2vec.Vocab at 0x7f5ec7158810>,
#   u'gop_candidate': <gensim.models.word2vec.Vocab at 0x7f5ec7158890>,
#   u'judge_aaron_persky': <gensim.models.word2vec.Vocab at 0x7f5ec71588d0>,
#   u'eyelids': <gensim.models.word2vec.Vocab at 0x7f5ec7158950>,
#   u'santorums': <gensim.models.word2vec.Vocab at 0x7f5ec68bf3d0>,
#   u'congressional_action': <gensim.models.word2vec.Vocab at 0x7f5ec7158a50>,
#   u'peekskill': <gensim.models.word2vec.Vocab at 0x7f5ec7158ad0>,
#   u'boarded': <gensim.models.word2vec.Vocab at 0x7f5ec7158b50>,
#   u'cull': <gensim.models.word2vec.Vocab at 0x7f5ec6fe7490>,
#   u'programmatic': <gensim.models.word2vec.Vocab at 0x7f5ec7158bd0>,
#   u'heirloom': <gensim.models.word2vec.Vocab at 0x7f5ec7158c50>,
#   u'clarified': <gensim.models.word2vec.Vocab at 0x7f5ec7158cd0>,
#   u'sensitivity': <gensim.models.word2vec.Vocab at 0x7f5ec7158d10>,
#   u'similar_vein': <gensim.models.word2vec.Vocab at 0x7f5ec3a31110>,
#   u'three-bedroom': <gensim.models.word2vec.Vocab at 0x7f5ec7158d90>,
#   u'jabara': <gensim.models.word2vec.Vocab at 0x7f5ec7158e10>,
#   u'erika': <gensim.models.word2vec.Vocab at 0x7f5ec7158e50>,
#   u'tyndall': <gensim.models.word2vec.Vocab at 0x7f5ec7158e90>,
#   u'youtube_videos': <gensim.models.word2vec.Vocab at 0x7f5ec6ec8950>,
# ...
#   u'coordinators': <gensim.models.word2vec.Vocab at 0x7f5ec5796110>,
#   u'altitude': <gensim.models.word2vec.Vocab at 0x7f5ec70a6610>,
#   u'diocese': <gensim.models.word2vec.Vocab at 0x7f5ec70a6650>,
#   u'international_rescue_committee': <gensim.models.word2vec.Vocab at 0x7f5ec70a6690>,
#   u'vandana': <gensim.models.word2vec.Vocab at 0x7f5ec70a6710>,
#   u'tame': <gensim.models.word2vec.Vocab at 0x7f5ec70a6750>,
#   u'16000': <gensim.models.word2vec.Vocab at 0x7f5ec70a6790>,
#   u'grasping': <gensim.models.word2vec.Vocab at 0x7f5ec6ce6c50>,
#   u'despises': <gensim.models.word2vec.Vocab at 0x7f5ec70a6850>,
#   u'pressing_issues': <gensim.models.word2vec.Vocab at 0x7f5ec70a68d0>,
#   u'greatness': <gensim.models.word2vec.Vocab at 0x7f5ec70a6950>,
#   u'rapes': <gensim.models.word2vec.Vocab at 0x7f5ec70a6990>,
#   u'tamp': <gensim.models.word2vec.Vocab at 0x7f5ec70a69d0>,
#   u'grooms': <gensim.models.word2vec.Vocab at 0x7f5ec70a6a50>,
#   u'national_rifle_associations': <gensim.models.word2vec.Vocab at 0x7f5ec70a6ad0>,
#   u'conant': <gensim.models.word2vec.Vocab at 0x7f5ec6ebc110>,
#   u'entire_generation': <gensim.models.word2vec.Vocab at 0x7f5ec70a6bd0>,
#   u'verde': <gensim.models.word2vec.Vocab at 0x7f5ec70a6c90>,
#   u'debit_card': <gensim.models.word2vec.Vocab at 0x7f5ec70a6d10>,
#   u'tax_plan': <gensim.models.word2vec.Vocab at 0x7f5ec70a6dd0>,
#   u'morally': <gensim.models.word2vec.Vocab at 0x7f5ec6024190>,
#   u'safeguard': <gensim.models.word2vec.Vocab at 0x7f5ec70a6e50>,
#   u'incinerator': <gensim.models.word2vec.Vocab at 0x7f5ec70a6e90>,
#   u'duel': <gensim.models.word2vec.Vocab at 0x7f5ec70a6ed0>,
#   u'humbled': <gensim.models.word2vec.Vocab at 0x7f5ec70a6f90>,
#   u'flawlessly': <gensim.models.word2vec.Vocab at 0x7f5ec70a6fd0>,
#   u'masquerading': <gensim.models.word2vec.Vocab at 0x7f5ec64de9d0>,
#   u'arrays': <gensim.models.word2vec.Vocab at 0x7f5ec70b10d0>,
#   u'medical_progress': <gensim.models.word2vec.Vocab at 0x7f5ec6d029d0>,
#   u'aetnas': <gensim.models.word2vec.Vocab at 0x7f5ec70b11d0>,
#   u'smashes': <gensim.models.word2vec.Vocab at 0x7f5ec70b1250>,
#   u'1600s': <gensim.models.word2vec.Vocab at 0x7f5ec70b12d0>,
#   u'global_scale': <gensim.models.word2vec.Vocab at 0x7f5ec70b1350>,
#   u'open-air': <gensim.models.word2vec.Vocab at 0x7f5ec70b1390>,
#   u'complications': <gensim.models.word2vec.Vocab at 0x7f5ec70b1410>,
#   u'pesos': <gensim.models.word2vec.Vocab at 0x7f5ec70b1450>,
#   u'smashed': <gensim.models.word2vec.Vocab at 0x7f5ec70b14d0>,
#   u'duet': <gensim.models.word2vec.Vocab at 0x7f5ec70b1510>,
#   u'dues': <gensim.models.word2vec.Vocab at 0x7f5ec70b1550>,
#   u'passenger': <gensim.models.word2vec.Vocab at 0x7f5ec6d16350>,
#   u'disgrace': <gensim.models.word2vec.Vocab at 0x7f5ec70b1610>,
#   u'jan_19': <gensim.models.word2vec.Vocab at 0x7f5ec433d990>,
#   u'barrymore': <gensim.models.word2vec.Vocab at 0x7f5ec70b16d0>,
#   u'64000': <gensim.models.word2vec.Vocab at 0x7f5ec70b1750>,
#   u'minaj': <gensim.models.word2vec.Vocab at 0x7f5ec70b17d0>,
#   u'jan_18': <gensim.models.word2vec.Vocab at 0x7f5ec433da10>,
#   u'nobel_peace_prize': <gensim.models.word2vec.Vocab at 0x7f5ec70b1850>,
#   u'carpet-bombing': <gensim.models.word2vec.Vocab at 0x7f5ec3427750>,
#   u'falafel': <gensim.models.word2vec.Vocab at 0x7f5ec433da90>,
#   u'sexual_assault_victims': <gensim.models.word2vec.Vocab at 0x7f5ec70b1950>,
#   u'decapitation': <gensim.models.word2vec.Vocab at 0x7f5ec70b19d0>,
#   u'paperwork': <gensim.models.word2vec.Vocab at 0x7f5ec57964d0>,
#   u'sex_acts': <gensim.models.word2vec.Vocab at 0x7f5ec70b1ad0>,
#   u'hedge_fund_managers': <gensim.models.word2vec.Vocab at 0x7f5ec70b1b50>,
#   u'president_obamas_decision': <gensim.models.word2vec.Vocab at 0x7f5ec70b1b90>,
#   u'hijabs': <gensim.models.word2vec.Vocab at 0x7f5ec70b1c10>,
#   u'slurring': <gensim.models.word2vec.Vocab at 0x7f5ec70b1c90>,
#   u'eventual': <gensim.models.word2vec.Vocab at 0x7f5ec6cab410>,
#   u'korryn_gaines': <gensim.models.word2vec.Vocab at 0x7f5ec42155d0>,
#   u'dowling': <gensim.models.word2vec.Vocab at 0x7f5ec70b1e10>,
#   u'cambodia': <gensim.models.word2vec.Vocab at 0x7f5ec70b1e90>,
#   u'pasadena': <gensim.models.word2vec.Vocab at 0x7f5ec70b1f50>,
#   u'role': <gensim.models.word2vec.Vocab at 0x7f5ec70b1f90>,
#   u'minefield': <gensim.models.word2vec.Vocab at 0x7f5ec5b97310>,
#   u'sunset': <gensim.models.word2vec.Vocab at 0x7f5ec5ffe190>,
#   u'transgender': <gensim.models.word2vec.Vocab at 0x7f5ec70bb110>,
#   u'bossie': <gensim.models.word2vec.Vocab at 0x7f5ec70bb150>,
#   u'self-doubt': <gensim.models.word2vec.Vocab at 0x7f5ec70bb190>,
#   u'all-consuming': <gensim.models.word2vec.Vocab at 0x7f5ec70bb210>,
#   u'intend': <gensim.models.word2vec.Vocab at 0x7f5ec70bb290>,
#   u'older_sister': <gensim.models.word2vec.Vocab at 0x7f5ec70bb2d0>,
#   u'palms': <gensim.models.word2vec.Vocab at 0x7f5ec70bb310>,
#   u'outage': <gensim.models.word2vec.Vocab at 0x7f5ec70bb3d0>,
#   u'devos': <gensim.models.word2vec.Vocab at 0x7f5ec70bb450>,
#   u'yahoo': <gensim.models.word2vec.Vocab at 0x7f5ec70bb4d0>,
#   u'conservatively': <gensim.models.word2vec.Vocab at 0x7f5ec70bb510>,
#   u'black_actors': <gensim.models.word2vec.Vocab at 0x7f5ec70bb590>,
#   u'devon': <gensim.models.word2vec.Vocab at 0x7f5ec70bb5d0>,
#   u'intent': <gensim.models.word2vec.Vocab at 0x7f5ec6cbdf10>,
#   u'kitson': <gensim.models.word2vec.Vocab at 0x7f5ec70bb690>,
#   u'smelling': <gensim.models.word2vec.Vocab at 0x7f5ec70bb710>,
#   u'variable': <gensim.models.word2vec.Vocab at 0x7f5ec70bb750>,
#   u'per_unit': <gensim.models.word2vec.Vocab at 0x7f5ec70bb790>,
#   u'hawkes': <gensim.models.word2vec.Vocab at 0x7f5ec6674f90>,
#   u'explosions': <gensim.models.word2vec.Vocab at 0x7f5ec70bb890>,
#   u'loren': <gensim.models.word2vec.Vocab at 0x7f5ec70bb8d0>,
#   u'shootout': <gensim.models.word2vec.Vocab at 0x7f5ec70bb990>,
#   u'mandates': <gensim.models.word2vec.Vocab at 0x7f5ec38f9bd0>,
#   u'steve_jobs': <gensim.models.word2vec.Vocab at 0x7f5ec70bb9d0>,
#   u'omran': <gensim.models.word2vec.Vocab at 0x7f5ec70bba10>,
#   u'ordination': <gensim.models.word2vec.Vocab at 0x7f5ec3b57bd0>,
#   u'dressing_rooms': <gensim.models.word2vec.Vocab at 0x7f5ec70bbad0>,
#   u'regional_medical_center': <gensim.models.word2vec.Vocab at 0x7f5ec70bbb50>,
#   u'nuclear_weapons': <gensim.models.word2vec.Vocab at 0x7f5ec70bbbd0>,
#   u'grammy_awards': <gensim.models.word2vec.Vocab at 0x7f5ec70bbc10>,
#   u'first_graders': <gensim.models.word2vec.Vocab at 0x7f5ec70bbc50>,
#   u'erred': <gensim.models.word2vec.Vocab at 0x7f5ec3b57c90>,
#   u'womens_bathroom': <gensim.models.word2vec.Vocab at 0x7f5ec70bbcd0>,
#   u'gown': <gensim.models.word2vec.Vocab at 0x7f5ec70bbdd0>,
#   u'childs': <gensim.models.word2vec.Vocab at 0x7f5ec70bbe10>,
#   u'cincinnati': <gensim.models.word2vec.Vocab at 0x7f5ec70bbe50>,
#   u'chain': <gensim.models.word2vec.Vocab at 0x7f5ec70bbe90>,
#   u'whoever': <gensim.models.word2vec.Vocab at 0x7f5ec70bbed0>,
#   u'broad_coalition': <gensim.models.word2vec.Vocab at 0x7f5ec70bbf10>,
#   u'people': <gensim.models.word2vec.Vocab at 0x7f5ec47afad0>,
#   u'egypts': <gensim.models.word2vec.Vocab at 0x7f5ec70bbf90>,
#   u'bandits': <gensim.models.word2vec.Vocab at 0x7f5ec70bbfd0>,
#   u'mcghee': <gensim.models.word2vec.Vocab at 0x7f5ec6c72390>,
#   u'chair': <gensim.models.word2vec.Vocab at 0x7f5ec70c5110>,
#   u'chait': <gensim.models.word2vec.Vocab at 0x7f5ec70c5150>,
#   u'nonproliferation': <gensim.models.word2vec.Vocab at 0x7f5ec70c51d0>,
#   u'tilt': <gensim.models.word2vec.Vocab at 0x7f5ec5d07650>,
#   u'ballet': <gensim.models.word2vec.Vocab at 0x7f5ec70c5250>,
#   u'amplification': <gensim.models.word2vec.Vocab at 0x7f5ec70c5290>,
#   u'grapples': <gensim.models.word2vec.Vocab at 0x7f5ec70c5310>,
#   u'hutchins': <gensim.models.word2vec.Vocab at 0x7f5ec70c5390>,
#   u'freelance': <gensim.models.word2vec.Vocab at 0x7f5ec70c5410>,
#   u'megawatts': <gensim.models.word2vec.Vocab at 0x7f5ec70c5450>,
#   u'crates': <gensim.models.word2vec.Vocab at 0x7f5ec70c5490>,
#   u'crater': <gensim.models.word2vec.Vocab at 0x7f5ec70c5510>,
#   u'grappled': <gensim.models.word2vec.Vocab at 0x7f5ec70c5550>,
#   u'brotherly_love': <gensim.models.word2vec.Vocab at 0x7f5ec4954790>,
#   u'standing_ovation': <gensim.models.word2vec.Vocab at 0x7f5ec70c5650>,
#   u'macho': <gensim.models.word2vec.Vocab at 0x7f5ec6c87150>,
#   u'oversight': <gensim.models.word2vec.Vocab at 0x7f5ec70c5710>,
#   u'medical_association': <gensim.models.word2vec.Vocab at 0x7f5ec70c5750>,
#   u'tenacious': <gensim.models.word2vec.Vocab at 0x7f5ec70c57d0>,
#   u'over-the-top': <gensim.models.word2vec.Vocab at 0x7f5ec70c5850>,
#   u'downloading': <gensim.models.word2vec.Vocab at 0x7f5ec70c5890>,
#   u'paychecks': <gensim.models.word2vec.Vocab at 0x7f5ec70c5910>,
#   u'married_couples': <gensim.models.word2vec.Vocab at 0x7f5ec70c5950>,
#   u'jerk': <gensim.models.word2vec.Vocab at 0x7f5ec70c5990>,
#   u'saldana': <gensim.models.word2vec.Vocab at 0x7f5ec70c59d0>,
#   u'pro-sanders': <gensim.models.word2vec.Vocab at 0x7f5ec70c5a10>,
#   u'budget_reconciliation': <gensim.models.word2vec.Vocab at 0x7f5ec70c5a90>,
#   u'choice': <gensim.models.word2vec.Vocab at 0x7f5ec70c5b90>,
#   u'embark': <gensim.models.word2vec.Vocab at 0x7f5ec70c5bd0>,
#   u'gloomy': <gensim.models.word2vec.Vocab at 0x7f5ec70c5c10>,
#   u'ghostbusters': <gensim.models.word2vec.Vocab at 0x7f5ec70c5c50>,
#   u'stays': <gensim.models.word2vec.Vocab at 0x7f5ec70c5c90>,
#   u'exact': <gensim.models.word2vec.Vocab at 0x7f5ec70c5d50>,
#   u'inglis': <gensim.models.word2vec.Vocab at 0x7f5ec4344290>,
#   u'minute': <gensim.models.word2vec.Vocab at 0x7f5ec70c5e10>,
#   u'catalonia': <gensim.models.word2vec.Vocab at 0x7f5ec70c5e50>,
#   u'mounting_evidence': <gensim.models.word2vec.Vocab at 0x7f5ec70c5ed0>,
#   u'blank_check': <gensim.models.word2vec.Vocab at 0x7f5ec70c5f50>,
#   u'reining': <gensim.models.word2vec.Vocab at 0x7f5ec70c5fd0>,
#   u'downtown_tampa': <gensim.models.word2vec.Vocab at 0x7f5ec70d0050>,
#   u'minnie': <gensim.models.word2vec.Vocab at 0x7f5ec70d0090>,
#   u'skewed': <gensim.models.word2vec.Vocab at 0x7f5ec70d00d0>,
#   u'fresh_prince': <gensim.models.word2vec.Vocab at 0x7f5ec70d0110>,
#   u'cooke': <gensim.models.word2vec.Vocab at 0x7f5ec70d0150>,
#   u'defaults': <gensim.models.word2vec.Vocab at 0x7f5ec70d0190>,
#   u'skewer': <gensim.models.word2vec.Vocab at 0x7f5ec70d01d0>,
#   u'xenophobe': <gensim.models.word2vec.Vocab at 0x7f5ec70d0250>,
#   u'lapierre': <gensim.models.word2vec.Vocab at 0x7f5ec70d02d0>,
#   u'financial_disclosure': <gensim.models.word2vec.Vocab at 0x7f5ec70d0310>,
#   u'trails': <gensim.models.word2vec.Vocab at 0x7f5ec70d0350>,
#   u'kimkardashian': <gensim.models.word2vec.Vocab at 0x7f5ec70d0390>,
#   u'politicususa': <gensim.models.word2vec.Vocab at 0x7f5ec70d03d0>,
#   u'lengthened': <gensim.models.word2vec.Vocab at 0x7f5ec70d0450>,
#   u'presidential_candidates': <gensim.models.word2vec.Vocab at 0x7f5ec3adf090>,
#   u'heavyweight': <gensim.models.word2vec.Vocab at 0x7f5ec70d0550>,
#   u'andy_cohen': <gensim.models.word2vec.Vocab at 0x7f5ec70d05d0>,
#   u'shirts': <gensim.models.word2vec.Vocab at 0x7f5ec70d0650>,
#   u'food-insecure': <gensim.models.word2vec.Vocab at 0x7f5ec70d0690>,
#   u'jameis': <gensim.models.word2vec.Vocab at 0x7f5ec70d0710>,
#   u'incrementally': <gensim.models.word2vec.Vocab at 0x7f5ec70d0750>,
#   u'federal_prosecutors': <gensim.models.word2vec.Vocab at 0x7f5ec70d07d0>,
#   u'plan_b': <gensim.models.word2vec.Vocab at 0x7f5ec70d0810>,
#   u'headset': <gensim.models.word2vec.Vocab at 0x7f5ec70d0850>,
#   u'burch': <gensim.models.word2vec.Vocab at 0x7f5ec70d0910>,
#   u'300': <gensim.models.word2vec.Vocab at 0x7f5ec43446d0>,
#   u'large_margin': <gensim.models.word2vec.Vocab at 0x7f5ec70d09d0>,
#   u'kourtneykardash': <gensim.models.word2vec.Vocab at 0x7f5ec36c2bd0>,
#   u'bettie_jones': <gensim.models.word2vec.Vocab at 0x7f5ec70d0a50>,
#   u'newnownext': <gensim.models.word2vec.Vocab at 0x7f5ec70d0ad0>,
#   u'celebrates': <gensim.models.word2vec.Vocab at 0x7f5ec70d0b50>,
#   u'unintentionally': <gensim.models.word2vec.Vocab at 0x7f5ec70d0b90>,
#   u'drafted': <gensim.models.word2vec.Vocab at 0x7f5ec70d0bd0>,
#   u'303': <gensim.models.word2vec.Vocab at 0x7f5ec57165d0>,
#   u'climbs': <gensim.models.word2vec.Vocab at 0x7f5ec70d0c50>,
#   u'honour': <gensim.models.word2vec.Vocab at 0x7f5ec70d0cd0>,
#   u'chattanooga_tennessee': <gensim.models.word2vec.Vocab at 0x7f5ec70d0d50>,
#   u'sen_paul': <gensim.models.word2vec.Vocab at 0x7f5ec339cdd0>,
#   u'vanderbilt': <gensim.models.word2vec.Vocab at 0x7f5ec70d0dd0>,
#   u'international_human_rights': <gensim.models.word2vec.Vocab at 0x7f5ec70d0e50>,
#   u'gladys': <gensim.models.word2vec.Vocab at 0x7f5ec70d0e90>,
#   u'gay-straight_alliance': <gensim.models.word2vec.Vocab at 0x7f5ec70d0ed0>,
#   u'school_shootings': <gensim.models.word2vec.Vocab at 0x7f5ec70d0f50>,
#   u'dwindling': <gensim.models.word2vec.Vocab at 0x7f5ec70d0f90>,
#   u'benson': <gensim.models.word2vec.Vocab at 0x7f5ec70d0fd0>,
#   u'presidential_nominee_hillary_clinton': <gensim.models.word2vec.Vocab at 0x7f5ec4344a90>,
#   u'enroll': <gensim.models.word2vec.Vocab at 0x7f5ec70da090>,
#   u'revenues': <gensim.models.word2vec.Vocab at 0x7f5ec5796b50>,
#   u'laurel': <gensim.models.word2vec.Vocab at 0x7f5ec398c950>,
#   u'cable_news': <gensim.models.word2vec.Vocab at 0x7f5ec70da150>,
#   u'dusty': <gensim.models.word2vec.Vocab at 0x7f5ec70da190>,
#   u'impacted': <gensim.models.word2vec.Vocab at 0x7f5ec70da1d0>,
#   u'straw_poll': <gensim.models.word2vec.Vocab at 0x7f5ec70da210>,
#   u'weather_events': <gensim.models.word2vec.Vocab at 0x7f5ec70da290>,
#   u'cusack': <gensim.models.word2vec.Vocab at 0x7f5ec70da390>,
#   u'accomplished': <gensim.models.word2vec.Vocab at 0x7f5ec70da410>,
#   u'sprouted': <gensim.models.word2vec.Vocab at 0x7f5ec70da450>,
#   u'proponent': <gensim.models.word2vec.Vocab at 0x7f5ec46e1890>,
#   u'burning_fossil_fuels': <gensim.models.word2vec.Vocab at 0x7f5ec70da4d0>,
#   u'voter_identification': <gensim.models.word2vec.Vocab at 0x7f5ec70da510>,
#   u'ill-fated': <gensim.models.word2vec.Vocab at 0x7f5ec70da590>,
#   u'12-month': <gensim.models.word2vec.Vocab at 0x7f5ec70da5d0>,
#   u'influx': <gensim.models.word2vec.Vocab at 0x7f5ec70da650>,
#   u'violent_attacks': <gensim.models.word2vec.Vocab at 0x7f5ec70da690>,
#   u'mystics': <gensim.models.word2vec.Vocab at 0x7f5ec453e950>,
#   u'raise': <gensim.models.word2vec.Vocab at 0x7f5ec3737150>,
#   u'proportion': <gensim.models.word2vec.Vocab at 0x7f5ec70da6d0>,
#   u'cacophony': <gensim.models.word2vec.Vocab at 0x7f5ec70da750>,
#   u'neonicotinoids': <gensim.models.word2vec.Vocab at 0x7f5ec70da7d0>,
#   u'skits': <gensim.models.word2vec.Vocab at 0x7f5ec3adf410>,
#   u'concrete_evidence': <gensim.models.word2vec.Vocab at 0x7f5ec3ad7ad0>,
#   u'voting_booth': <gensim.models.word2vec.Vocab at 0x7f5ec70da890>,
#   u'ex-wives': <gensim.models.word2vec.Vocab at 0x7f5ec70da8d0>,
#   u'solar_panels': <gensim.models.word2vec.Vocab at 0x7f5ec70da950>,
#   u'religious_nonprofits': <gensim.models.word2vec.Vocab at 0x7f5ec70da990>,
#   u'2015-2016': <gensim.models.word2vec.Vocab at 0x7f5ec70daa10>,
#   u'darnell': <gensim.models.word2vec.Vocab at 0x7f5ec70daa90>,
#   u'undergone': <gensim.models.word2vec.Vocab at 0x7f5ec70daad0>,
#   u'working': <gensim.models.word2vec.Vocab at 0x7f5ec70dab10>,
#   u'perished': <gensim.models.word2vec.Vocab at 0x7f5ec70dab50>,
#   u'oldham': <gensim.models.word2vec.Vocab at 0x7f5ec6c16a90>,
#   u'race_relations': <gensim.models.word2vec.Vocab at 0x7f5ec70dac10>,
#   u'blackwater': <gensim.models.word2vec.Vocab at 0x7f5ec70dac50>,
#   u'27000': <gensim.models.word2vec.Vocab at 0x7f5ec70dacd0>,
#   u'electricity_rates': <gensim.models.word2vec.Vocab at 0x7f5ec70dad10>,
#   u'opposed': <gensim.models.word2vec.Vocab at 0x7f5ec70dad90>,
#   u'unjust': <gensim.models.word2vec.Vocab at 0x7f5ec70dadd0>,
#   u'isolated_incident': <gensim.models.word2vec.Vocab at 0x7f5ec70dae10>,
#   u'moi': <gensim.models.word2vec.Vocab at 0x7f5ec3811d50>,
#   u'federal_loans': <gensim.models.word2vec.Vocab at 0x7f5ec70dae50>,
#   u'compelling_interest': <gensim.models.word2vec.Vocab at 0x7f5ec70daed0>,
#   u'rousing_speech': <gensim.models.word2vec.Vocab at 0x7f5ec70daf50>,
#   ...},
#  'window': 5,
#  'workers': 10}

# %%
model.most_similar(['clinton', 'shady'], ['trump'])
model.most_similar(['trump', 'shady'], ['clinton'])

model.most_similar(['clinton', 'controversial'], ['trump'])
model.most_similar(['trump', 'controversial'], ['clinton'])

model.most_similar(['liberal', 'feminist'], ['conservative'])

model.most_similar(['liberal', 'radical'], ['conservative'])

model.most_similar(['liberal', 'alt-right'], ['conservative'])
model.most_similar(['conservative', 'alt-right'], ['liberal'])

model.most_similar(['conservative', 'demagogue'], ['liberal'])

model.most_similar(['trump', 'violence'], ['clinton'])
model.most_similar(['clinton', 'violence'], ['trump'])

model.most_similar(['trump', 'crime'], ['clinton'])
model.most_similar(['clinton', 'crime'], ['trump'])
# Out:
# [(u'islamic_state', 0.6242399215698242),
#  (u'islamic_state_group', 0.5898193120956421),
#  (u'isil', 0.5716771483421326),
#  (u'islamic_state_isis', 0.5501219034194946),
#  (u'daesh', 0.5432126522064209),
#  (u'terror_group', 0.49710047245025635),
#  (u'isiss', 0.48887044191360474),
#  (u'terrorist_group', 0.48086708784103394),
#  (u'islamic_states', 0.4808511734008789),
#  (u'jihadists', 0.46260446310043335)]

# %%
# trained_model.most_similar_cosmul(positive=['baghdad', 'england'], negative=['london'])
from gensim.models import Word2Vec
model_left = Word2Vec.load('../intermediate/word2vec_left.pkl')
model_right = Word2Vec.load('../intermediate/word2vec_right.pkl')
model = Word2Vec.load('../intermediate/word2vec_all.pkl')

# %%
model_left.save_word2vec_format('../intermediate/word2vec_portable_left.bin',
                                fvocab='../intermediate/word2vec_vocab_left.bin', binary=True)
model_right.save_word2vec_format('../intermediate/word2vec_portable_right.bin',
                                 fvocab='../intermediate/word2vec_vocab_right.bin', binary=True)

# %%
model_left.most_similar('urban')
model_right.most_similar('urban')
# Out:
# [(u'housing', 0.4908299744129181),
#  (u'hud', 0.45650115609169006),
#  (u'inner_city', 0.44377341866493225),
#  (u'julian_castro', 0.44084376096725464),
#  (u'neighborhoods', 0.43410342931747437),
#  (u'inner-city', 0.43364620208740234),
#  (u'affluent', 0.4262969493865967),
#  (u'high-crime', 0.4080944061279297),
#  (u'low-income', 0.40600207448005676),
#  (u'ghettos', 0.3926388621330261),
#  (u'rural', 0.3868141174316406),
#  (u'development', 0.386753648519516),
#  (u'suburban', 0.3820151090621948),
#  (u'areas', 0.3819997310638428),
#  (u'suburbs', 0.3768220543861389)]

# %%
def find_disjoint_terms(term, keep_model, reject_model, pool_n=100, n=10):
    """
    Find similar terms in one model that are not present in a second
    """
    in_terms = [t for t, s in in_model.most_similar(term, topn=pool_n)]
    out_terms = [t for t, s in out_model.most_similar(term, topn=pool_n)]
    
    return [t for t in in_terms if t not in out_terms][:n]

# %%
find_partisan_similarity('immigration', model_right, model_left, n=25)
# Out:
# [u'immigrations',
#  u'border_enforcement',
#  u'mass_immigration',
#  u'restrictionist',
#  u'detainers',
#  u'ice',
#  u'anti-illegal',
#  u'assimilation',
#  u'issuances',
#  u'detainer',
#  u'entitlements',
#  u'deport_illegal_immigrants',
#  u'h1-b',
#  u'guest-worker',
#  u'chris_crane',
#  u'immigration_system',
#  u'criminal_illegal_immigrants',
#  u'touchback',
#  u'numbersusa',
#  u'visas',
#  u'senate_subcommittee',
#  u'us_immigration_policy',
#  u'h1b',
#  u'mass_migration',
#  u'open-borders']

# %%
import numpy as np
from fuzzywuzzy import process, fuzz
from six import string_types

class ExtendedWord2Vec(Word2Vec):
    """
    Add some desired functionality to Word2Vec
    """
    def __getitem__(self, words):
        """
        For our purposes, averaging the vectors of multiple
        words is most useful (as opposed to returning an ndarray
        of shape (len(words), self.vector_size) )
        """
        vecs = super(ExtendedWord2Vec, self).__getitem__(words)
        
        if vecs.size > self.vector_size:
            vecs = np.mean(vecs, axis=0)
            
        return vecs
        
    def likely_synonyms(self, words, threshold=75, sample_from_topn=10):
        """
        Return words that are similar both in context and spelling
        """
        similar_words = [word for word, score in
                         self.most_similar(words, topn=sample_from_topn)]
        
        if isinstance(words, string_types):
            words = [words]
        
        return set([sim_word for word in words
                             for sim_word, score in process.extract(word, similar_words)
                    if score > threshold])
            
model_leftext = model_left
model_leftext.__class__ = ExtendedWord2Vec

model_rightext = model_right
model_rightext.__class__ = ExtendedWord2Vec

modelext = model
modelext.__class__ = ExtendedWord2Vec

# %%
clinton_terms = [u'clintons',
                 u'democratic_nominee_hillary_clinton',
                 u'hillary_clinton',
                 u'hillary_clintons',
                 u'hillary_rodham_clinton',
                 u'hillarys',
                 u'mrs_clinton',
                 u'hrc']

trump_terms = [u'trumps',
               u'donald_trump',
               u'mr_trump',
               u'real_estate_mogul',
               u'donalds',
               u'gop_front-runner_donald_trump',
               u'republican_nominee_donald_trump']

left_terms = ['liberal', 'left-wing', 'progressive', 'center-left', 'leftist',
              'liberals', 'democrat', 'democratic', 'democrats',
              'left-leaning', 'far-left', 'leftwing']

right_terms = ['conservative', 'right-wing', 'conservatives', 'right-leaning',
              'far-right', 'republican', 'republicans']

candidate_vec = modelext[clinton_terms] - modelext[trump_terms]

russia_terms = ['putin', 'russia', 'russian', 'vladimir_putin',
                'moscows', 'moscow', 'kremlin', 'russian_president_vladimir',
                'president_vladimir_putin', 'vladimir_putins', 'russias', 'putins', 'russians',
                'russian_government', 'leftwing']

# %%
partisan_rejector = (model_leftext['liberal'] - model_leftext['conservative']) - 
                    (model_leftext['democrat'] - model_leftext['republican'])
model_leftext_nonpart = [model_leftext[v] - partisan_rejector for v in model_leftext_
# Out:
# array([-0.20462778,  0.16366085, -0.00548428,  0.14233346, -0.32446277,
#         0.03609439, -0.04971508, -0.23342769, -0.14397219, -0.11840305,
#        -0.13927713,  0.0510698 , -0.24667627,  0.06406192, -0.04721181,
#         0.02854012,  0.0997995 ,  0.01129037, -0.02115975, -0.00543809,
#         0.10735297, -0.14480504, -0.00292246, -0.07363608, -0.01873149,
#        -0.17365167, -0.06916165,  0.30533025,  0.02238379,  0.17596652,
#        -0.13528068, -0.24979006,  0.03903581,  0.076314  , -0.26145479,
#        -0.01821651,  0.11010098, -0.2024342 , -0.04129888, -0.00520282,
#        -0.02740867,  0.24004759, -0.01050987,  0.03867228,  0.11851116,
#         0.19107898, -0.01806241, -0.16182363,  0.02297141,  0.16541953,
#        -0.04577152, -0.22203198, -0.02401115,  0.32177806,  0.15446866,
#        -0.01838038,  0.00294004, -0.26690271, -0.17676209,  0.32002151,
#         0.11630105, -0.01903433,  0.0049375 ,  0.20263997, -0.06431071,
#        -0.24258183, -0.1079428 ,  0.17044337,  0.09561429,  0.01463284,
#        -0.07221413, -0.09678755, -0.11245869,  0.01601428,  0.20105997,
#        -0.03404241,  0.00523063,  0.0145249 ,  0.20991264,  0.02827222,
#         0.20641296, -0.11468776, -0.02006506, -0.09580383,  0.01020393,
#        -0.1076278 ,  0.16692843, -0.06143849, -0.08399336,  0.01651322,
#         0.12101755, -0.05561261, -0.01294587,  0.06660575,  0.1214425 ,
#        -0.03868828, -0.0492934 ,  0.10715222, -0.07066436,  0.11753213,
#        -0.00833088,  0.07366653, -0.02918921,  0.04572824, -0.06739291,
#        -0.01877093, -0.03270373,  0.02262367, -0.12424149, -0.19538176,
#        -0.08859571, -0.17400073,  0.06825446,  0.03459062, -0.27306396,
#         0.06192937, -0.37124649, -0.10577571,  0.32053205, -0.02373221,
#         0.1854306 ,  0.07047378,  0.1373176 ,  0.03966184,  0.01851795,
#         0.03232357,  0.16203174,  0.15811034,  0.1473784 ,  0.18390653,
#         0.25219381,  0.23655702, -0.00479078,  0.03358058, -0.10191441,
#         0.16189243,  0.18808506, -0.04470316, -0.05181359, -0.03088078,
#         0.10970523,  0.00410069, -0.2320859 , -0.07466967, -0.05501558,
#         0.00455948, -0.00893536,  0.19103503,  0.05554037, -0.0650848 ,
#        -0.09703731,  0.06793574, -0.02703756,  0.18886192, -0.20059673,
#         0.11989702,  0.12502478, -0.11533272,  0.09513778,  0.04275609,
#         0.23139118, -0.01795078,  0.07019432, -0.00732415,  0.05365442,
#        -0.14644125, -0.04744578,  0.22446546, -0.01778285,  0.02476586,
#        -0.05334714,  0.12542529, -0.07124613, -0.22886266, -0.11234409,
#         0.08982411, -0.0550527 ,  0.0645139 ,  0.05183217, -0.08304324,
#        -0.12736544,  0.203269  , -0.00237595, -0.29521218,  0.09006728,
#         0.02885132, -0.04072465, -0.12261264,  0.08869602, -0.32531196,
#        -0.09306283, -0.02308968, -0.20183134,  0.22660446,  0.16832957,
#        -0.10017775, -0.0607499 , -0.0649895 , -0.1054779 ,  0.12679295,
#        -0.02792379,  0.09324376,  0.21954112, -0.13698643, -0.00426902,
#         0.05883365, -0.04457437,  0.24378076, -0.28977284, -0.20748019,
#         0.02393329,  0.06009321, -0.01682134, -0.28698483,  0.04508379,
#        -0.09702695, -0.00348882, -0.04514853,  0.07314995,  0.02026067,
#         0.01838561,  0.23884507, -0.04214556, -0.0128229 ,  0.01767383,
#         0.07409489,  0.04112224, -0.03204605,  0.03301481, -0.05719416,
#        -0.03056544,  0.03364759,  0.0413695 ,  0.13509132,  0.03440082,
#         0.02869498,  0.08777104, -0.19541553, -0.02125005, -0.08779378,
#         0.10150598, -0.01393018, -0.25930482,  0.21016856,  0.22556718,
#         0.14743704, -0.05197253,  0.01403316, -0.04760211, -0.07664479,
#        -0.02162171, -0.26259401, -0.10663694, -0.07432547, -0.01472508,
#         0.01444524, -0.06024176, -0.0806947 ,  0.01979533,  0.01988988,
#         0.14783543, -0.08608451, -0.1548012 , -0.06129558,  0.10609739,
#         0.07348392, -0.10166142, -0.19807933,  0.02593492,  0.31645969,
#         0.14970461,  0.00772597, -0.02227862,  0.10922302, -0.1689655 ,
#        -0.08209013, -0.20172043, -0.05644356,  0.25810364, -0.22392635,
#        -0.11552951, -0.12561782,  0.11359356,  0.15761682,  0.07635705,
#        -0.05760445,  0.02291571, -0.05644105,  0.02339538, -0.02025001,
#         0.04291205,  0.21151242,  0.26504165, -0.12125934,  0.1666881 ,
#        -0.15814967, -0.15849696,  0.04486468,  0.31889617,  0.15782605,
#        -0.01634098,  0.19496164, -0.01166959, -0.1490435 , -0.0288466 ,
#        -0.01920855,  0.0336324 ,  0.07115968, -0.01243845,  0.02229166,
#        -0.05952767,  0.01639551,  0.16561499,  0.12750059, -0.00948543,
#         0.02280568,  0.10739928,  0.21773787,  0.15192953, -0.07095812,
#        -0.12598294, -0.02162734,  0.43433416,  0.09351507,  0.11450236,
#         0.15390907, -0.02776934, -0.15124451,  0.00233544, -0.0669154 ,
#         0.05435084,  0.13531068, -0.13725112,  0.05166166,  0.03042266,
#        -0.12271137, -0.01176339, -0.0313691 ,  0.03877955,  0.10425847,
#         0.24809882,  0.06207414, -0.11645739,  0.006418  ,  0.12067085,
#         0.08569481, -0.10401031,  0.04832882,  0.054651  , -0.14105834,
#         0.0428953 , -0.38935602, -0.12734734, -0.03274605,  0.13741404,
#        -0.16972072,  0.11412948,  0.03594574, -0.07283664, -0.11388107,
#         0.18369988,  0.18089809, -0.20497915,  0.04920918, -0.04886948,
#         0.02552412,  0.01588024,  0.13612352,  0.04398376,  0.15667814,
#        -0.24588418,  0.25829011,  0.22805953, -0.13367563, -0.00673187,
#         0.2950086 , -0.0234686 , -0.0020369 ,  0.09701182, -0.06134003,
#        -0.03267261, -0.04849537, -0.03437421,  0.00318789,  0.1192733 ,
#         0.04653254,  0.18764371, -0.0997913 ,  0.16690415, -0.2292199 ,
#         0.12395612, -0.22188275,  0.07501268, -0.1319208 , -0.06462175,
#        -0.15686664, -0.11532658,  0.08501229, -0.13119313, -0.14066453,
#         0.09283206, -0.04699852,  0.17569719, -0.12462512,  0.06359108,
#        -0.15297943, -0.29321262, -0.10384607, -0.15435091, -0.14537963,
#         0.01358862,  0.07176311, -0.07980981,  0.07658387, -0.02844209,
#         0.15349197, -0.03586367,  0.15333065,  0.38873202, -0.0874844 ,
#         0.05307415,  0.07060435, -0.04588145,  0.07939413,  0.02136753,
#         0.08585132, -0.02975523, -0.02489975, -0.00765735, -0.0325399 ,
#         0.19006214,  0.12865613, -0.00158705, -0.19983518,  0.05064084,
#         0.01627658,  0.06159398, -0.08748134,  0.02655601,  0.04043987,
#         0.04940887,  0.06744285, -0.11081626,  0.03456525,  0.26695538,
#        -0.22751129,  0.03667454,  0.37027362,  0.04261706,  0.10005637,
#         0.05104521,  0.01832328, -0.01099928, -0.06535056,  0.19818002,
#         0.07853507,  0.08496703,  0.27941537,  0.07632852, -0.03376957,
#         0.2852596 ,  0.11047747,  0.01663514,  0.07342265,  0.0403302 ,
#         0.05942378,  0.07237254,  0.10042594, -0.25724459,  0.01701427,
#        -0.03807391, -0.11034177,  0.041277  , -0.15922175, -0.10688595,
#         0.23188166,  0.13098469, -0.07791851,  0.08476429, -0.04449598,
#         0.00169774,  0.12213635, -0.10308746,  0.18313988,  0.08977167,
#        -0.09337328, -0.10979855,  0.00599403,  0.07317992, -0.26786259,
#         0.08656609,  0.03155193, -0.10455233, -0.24398257,  0.0215553 ,
#        -0.19439211,  0.14123686, -0.00090345,  0.22368833, -0.04822178], dtype=float32)

# %%
right_on_left = [w for w, s in model_rightext.most_similar(['liberal'], topn=100)]
left_on_left = [w for w, s in model_leftext.most_similar(['liberal'], topn=100)]

[r for r in right_on_left if r not in left_on_left]
# Out:
# [u'leftwing',
#  u'hard-left',
#  u'ultra-liberal',
#  u'social_justice',
#  u'lefties',
#  u'social_justice_warriors',
#  u'bleeding-heart',
#  u'environmentalist',
#  u'lefts',
#  u'elitist',
#  u'statist',
#  u'radical_pro-abortion',
#  u'hollywood',
#  u'hardcore',
#  u'big-government',
#  u'abortion_rights',
#  u'open-borders',
#  u'sjw',
#  u'billionaire_george_soros',
#  u'candidate_bernie_sanders',
#  u'socialistic',
#  u'anti-capitalist',
#  u'right-of-center',
#  u'liberal_media',
#  u'marxist',
#  u'social-justice',
#  u'loons',
#  u'like_bernie_sanders',
#  u'anti-freedom',
#  u'pro-abort',
#  u'leftist_agenda',
#  u'anti-life',
#  u'lib',
#  u'conservative-leaning',
#  u'dyed-in-the-wool',
#  u'lunacy',
#  u'college_professors',
#  u'mainstream_media',
#  u'pundit',
#  u'loony',
#  u'globalist',
#  u'typical',
#  u'soros-funded',
#  u'pro-amnesty',
#  u'activists',
#  u'daily_kos',
#  u'anti-second',
#  u'pro-homosexual',
#  u'media_matters',
#  u'talking_heads',
#  u'columnists',
#  u'filmmaker_michael_moore',
#  u'sympathetic',
#  u'commentators',
#  u'anti-war',
#  u'pro-gay',
#  u'media_figures',
#  u'anti-god']

# %%
left_on_right = [w for w, s in model_leftext.most_similar(['conservative'], topn=100)]
right_on_right = [w for w, s in model_rightext.most_similar(['conservative'], topn=100)]

[l for l in left_on_right if r not in right_on_right]

# %%
cossim = modelext.similar_by_vector(candidate_vec, topn=False)
idx_cossim_ordered = np.argsort(cossim)[::-1]
vocab = {v.index: k for k, v in modelext.vocab.items()}
[vocab[i] for i in idx_cossim_ordered]
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-5-be7066c29028> in <module>()
# ----> 1 cossim = modelext.similar_by_vector(candidate_vec, topn=False)
#       2 idx_cossim_ordered = np.argsort(cossim)[::-1]
#       3 vocab = {v.index: k for k, v in modelext.vocab.items()}
#       4 [vocab[i] for i in idx_cossim_ordered]
#
# NameError: name 'modelext' is not defined

# %%
[(l, lscore) for l, lscore in ru_left if l not in [r for r, rscore in ru_right]]
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-7-0ce035f0ebc3> in <module>()
# ----> 1 [(l, lscore) for l, lscore in ru_left if l not in [r for r, rscore in ru_right]]
#
# NameError: name 'ru_left' is not defined

# %% [markdown]
# ## Using Histwords on Data
