# %% [raw]
# ---
# layout: post
# title:  "Alternate Realities: Article Processing"
# date:   2016-12-30 20:01:00 -0500
# categories: partisan media analysis
# ---

# %% [markdown]
# ## Text Processing
# ### [In progress]
# In a previous post, we collected roughly 500,000 articles from 80 left- and right-aligned online news sources, going back to July 2015. Here, we'll start to clean and process the text data to enable future analyses.
#
# This is sort of an iterative problem -- I'll likely be revising this process to account for noise that makes it through.
#
# We'll rely on a combination of [nltk](http://www.nltk.org/), [gensim](https://radimrehurek.com/gensim/index.html), and [scikit-learn's](http://scikit-learn.org/stable/index.html) to tokenize our documents, generate n-grams, do some POS tagging, and place the data in a term-document-matrix.

# %% [markdown]
# ### Streaming tokenized text

# %% [markdown]
# To start, we'll create a generator to return all articles from a query. We'll be using similar functionality in the future, so I've opted to make it a class so that we may inherit from it in the future and stream, for e.g., sentences for use in Word2Vec models.

# %%
#stream.py
from sqlalchemy import create_engine

class QueryStream(object):
    """ 
    Stream documents from the articles database
    Can be subclassed to stream words or sentences from each document
    """
    def __init__(self, sqldb, query=None, idcol='post_id', 
                 textcol='article_text', chunksize=1000):

        self.sql_engine = create_engine(sqldb)
        self.query = query
        self.chunksize = chunksize
        self.textcol = textcol
        self.idcol = idcol

    def __iter__(self):
        """ Iterate through each row in the query """
        query_results = self.sql_engine.execute(self.query)
        result_set = query_results.fetchmany(self.chunksize)
        while result_set:
            for row in result_set:
                yield row
            result_set = query_results.fetchmany(self.chunksize)

# %% [markdown]
# We want to create a pipeline for tokenizing documents that will split a document into sentences, then those sentences into words. Here, we'll use nltk for tokenization.

# %%
from nltk import sent_tokenize, word_tokenize
from nltk.tokenize import MWETokenizer

import regex as re

class SentenceStream(QueryStream):
    """
    Stream tokenized sentences from a query
    """
    def __init__(self, ngrams=None, *args, **kwargs):
        super(SentenceStream, self).__init__(*args, **kwargs)
        # this will allow us to treat pre-defined n-grams as
        # a single word, e.g., 'hillary_clinton', once
        # we've identified them
        self.mwe = MWETokenizer(ngrams)
        
    def __iter__(self):
        rows = super(SentenceStream, self).__iter__()
        # remove all punctuation, except hyphens
        punct = re.compile("[^A-Za-z0-9\-]")
        
        for doc in rows:
            id = getattr(doc, self.idcol)
            text = getattr(doc, self.textcol)
            
            for sentence in sent_tokenize(text):
                split_sentence = [punct.sub('', word).lower()
                                  for word in word_tokenize(sentence)]
                yield id, self.mwe.tokenize([word for word in split_sentence 
                                             if word.replace('-', '')])

# %% [markdown]
# ### Identifying Collocations
#
# We'll use the article text we've scraped to identify n-grams like 'donald trump'. Should we deem it necessary, we can later identify synonyms like 'senator sanders' and 'bernie sanders' using Word2Vec.

# %%
from gensim.models.phrases import Phrases
from gensim.models.phrases import Phraser
from itertools import imap 

sql_url = 'postgres://postgres:**PASSWORD**@localhost/articles'

full_query = """
             SELECT post_id, article_text
             FROM articles
             WHERE num_words > 100
             """

# Since I'm running this on a Google Compute instance, I can afford
# to load everything in memory as a list. While this isn't strictly necessary,
# I can now avoid pulling from the database multiple times
stream = list(SentenceStream(sqldb=sql_url, query=full_query))

# %% [markdown]
# To illustrate, here's the 9th sentence in the data, split into words.

# %%
stream[9]
# Out:
# [(u'144317282271701_1045074145529339',
#   [u'a', u'mixture', u'of', u'motives', u'is', u'on', u'display'])]

# %% [markdown]
# We must iteratively generate collocations from the sentence stream. The bigram object contains things like 'marco rubio', the trigram might now include 'senator marco rubio'.

# %%
phrase_kwargs = {'max_vocab_size': 100000000,
                  'threshold': 10,
                  'min_count': 50}

bigram = Phrases(imap(lambda x: x[1], stream), **phrase_kwargs)
trigram = Phrases(bigram[imap(lambda x: x[1], stream)], **phrase_kwargs)
quadgram = Phrases(trigram[imap(lambda x: x[1], stream)], **phrase_kwargs)

phraser = Phraser(quadgram)
phraser.save('../intermediate/phraser_all.pkl')

# %% [markdown]
# ### Trimming n-grams
# Many of the n-grams we found have stopwords at either the end or beginning, for instance, 'the supreme court'. We'd like to trim these so that they are individually meaningful components.

# %%
from nltk.corpus import stopwords
from nltk.corpus import wordnet as wn
from collections import defaultdict
import cPickle as pickle

def trim_phrases(phraser):
    """
    Remove stopwords at the start and end of an ngram,
    generate list of unique ngrams in corpus
    """
    stop = stopwords.words('english')
    ngrams = defaultdict(tuple)
    for bigram, score in phraser.phrasegrams.items():
        ngram = bigram[0].split('_') + bigram[1].split('_')
        
        idx = [i for i, v in enumerate(ngram) if v not in stop]  
        ngram = ngram[idx[0]:idx[-1] + 1] if idx else []
        
        
        if len(ngram) > 1:
            ngrams[tuple(ngram)] = score
                        
    return ngrams
  
ngrams = trim_phrases(phraser)

with open('../intermediate/phrasegrams_all.pkl', 'wb') as o:
    pickle.dump(ngrams, o)

# %% [markdown]
# ### POS Tagging
# Of the n-grams collected above, we're largely interested in noun-phrases like 'fetal_organs' (appearing 56 times in the sample, uh, ok). rather than adjective or verb phrases like 'radical_islamic'. To subset to only nouns, we'll use [Part-of-Speech tagging](http://www.nltk.org/book/ch05.html) to see how these n-grams are employed in the data.

# %%
from nltk import pos_tag

class POSSentenceStream(SentenceStream):
    """
    Assign parts of speech to n-grams
    """
    def __iter__(self):
        sentences = super(POSSentenceStream, self).__iter__()
        for id, sentence in sentences:
            for word, pos in pos_tag(sentence):
                if '_' in word:
                    yield word, pos
            
pos_words = POSSentenceStream(sqldb=sql_url, query=full_query, ngrams=ngrams)

# %% [markdown]
# To take a look at what we're referring to, see some examples below.

# %%
pos_words[:10]
# Out:
# [(u'hasnt_stopped', 'VBD'),
#  (u'republican_politicians', 'NNS'),
#  (u'radio_show', 'NN'),
#  (u'rafael_cruz', 'VBD'),
#  (u'ted_cruz', 'NN'),
#  (u'barack_obama', 'NN'),
#  (u'conversion_therapy', 'NN'),
#  (u'reminds_us', 'NN'),
#  (u'conversion_therapy', 'NN'),
#  (u'sharp_contrast', 'NN')]

# %% [markdown]
# We might expect that certain n-grams, like 'presidential_candidate', could be considered both a noun or adjective phrase. As a result, we'll determine the POS distribution for each phrase, selecting only those that are nouns over 75% of the time.

# %%
from collections import defaultdict
from collections import Counter
import numpy as np

def count_ngram_occurances(pos_stream):
    """
    Tally up the different POS associated with each n-gram
    """
    pos_counts = {word: Counter() for word, pos in pos_stream}
    
    for word, pos in pos_stream:
        pos_counts[word].update([pos])
        
    return pos_counts

def identify_np_ngrams(pos_counts):
    """
    Determine the n-grams that are most often employed as noun phrases
    """     
    np_ngrams = defaultdict(str)
    
    for word, counts in pos_counts.items():
        split_word = tuple(word.split('_'))
                
        word_count = sum(counts.values())        
        noun_count = sum([v for k, v in counts.items() if 'NN' in k])
        
        # is it usually used as a noun?
        if np.true_divide(noun_count, word_count) > 0.75:
            np_ngrams[split_word] = word_count
            
    return np_ngrams
            
pos_counts = count_ngram_occurances(pos_words)  
noun_ngrams = identify_np_ngrams(pos_counts)

# %% [markdown]
# Already, we're seeing some moderately interesting findings in the data. For instance, *rigged election by hillary clinton* appears 113 times in 57 sources, *congress must investigate planned parenthood* 58 times over 16 sources. These these ngrams and their counts are saved to github.

# %%
# save n-grams appearing over 25 times in the data
ngram_data = pd.DataFrame.from_records(pos_counts)\
                         .transpose()
    
ngram_data['total'] = ngram_data.sum(axis=1)
ngram_data.loc[ngram_data.total >= 25]\
          .to_csv('../output/ngram_pos_counts.csv', index_label='n-gram')

# %%
from itertools import combinations
def find_top_collocations(ngrams):
    """
    For similar ngrams ('sen hillary clinton' and 'hillary clinton'),
    and return only the most common
    """
    
    ngrams_string = {'_'.join(k): v[0] for k, v in ngrams.items()}
    combin_ngrams = combinations(ngrams_string, r=2)
    remove = []
    
    for n1, n2 in combin_ngrams:
        if n1 in n2 or n2 in n1:
            remove.append(min([n1, n2], key=lambda x: ngrams_string[x]))
                
    return {k: v for k, v in ngrams.items() if '_'.join(k) not in remove}

top_ngrams = find_top_collocations(ngrams)

# %%
ngrams_string = {'_'.join(k): v for k, v in ngrams.items()}
[(n,v) for n,v in ngrams_string.items() if 'hillary_clinton' in n]
# Out:
# [('hillary_clinton_would', (128, 191.59602688589797)),
#  ('candidate_hillary_clinton', (237, 14464.714377379476)),
#  ('support_hillary_clinton', (67, 87.66493562048167)),
#  ('hillary_clinton', (263, 455.9353804630901)),
#  ('hillary_clinton_said', (103, 35.061411384055475)),
#  ('hillary_clintons_health', (69, 133.97272709547855)),
#  ('presidential_candidate_hillary_clinton', (98, 10.88110080057768)),
#  ('hillary_clinton_hillaryclinton', (191, 60.34598829351883)),
#  ('beat_hillary_clinton', (65, 72.51695042135432)),
#  ('hillary_clintons_private_email', (60, 29.628529997296432)),
#  ('state_hillary_clinton', (434, 4950.490482097788)),
#  ('elect_hillary_clinton', (52, 77.35141378277794)),
#  ('democrat_hillary_clinton', (150, 10.104236165825691)),
#  ('hillary_clintons_campaign', (181, 408.9326524693404)),
#  ('said_hillary_clinton', (52, 13.260242362761932)),
#  ('hillary_clinton_campaign', (120, 33.510077611320725)),
#  ('hillary_clintons', (99, 218.72281453577784)),
#  ('investigation_into_hillary_clinton', (63, 1157.9887684729065)),
#  ('endorsed_hillary_clinton', (62, 126.57504073545482)),
#  ('presidential_nominee_hillary_clinton', (84, 18.393286542569424)),
#  ('nominee_hillary_clinton', (251, 155.9963294682779)),
#  ('hillary_clinton_presidency', (64, 95.35140265766717)),
#  ('hillary_clinton_wants', (60, 146.18333508492526)),
#  ('rival_hillary_clinton', (66, 51.56760918851863)),
#  ('frontrunner_hillary_clinton', (54, 16.284508164795355)),
#  ('front-runner_hillary_clinton', (101, 106.61951629518042)),
#  ('president_hillary_clinton', (53, 43.51017025281259)),
#  ('hillary_clintons_presidential_campaign', (67, 33.396506094778694)),
#  ('like_hillary_clinton', (114, 228.484176096821)),
#  ('hillary_clinton_wins', (54, 39.95677825654624)),
#  ('democratic_front-runner_hillary_clinton', (80, 71.91838682734758)),
#  ('democratic_nominee_hillary_clinton', (136, 54.95366631093144)),
#  ('hillary_clintons_emails', (64, 60.80379299909211))]

# %% [markdown]
# A similar problem are the preponderence of phrases like 'follow johnsmith on twitter' or 'source shutterstock'. We'll remove these as well

# %% [markdown]
# ### n-grams by Source

# %% [markdown]
# Some phrases are meaningless and are disproportionately attached to certain publications. We're going to attempt to identify these by looking at n-grams that are uniquely common for each publication, then strip them from the data.
#
# What will likely be more fruitful is a side-effect of this analysis: we'll attempt to identify n-grams that are nearly-exclusive to the left and the right.

# %%
from itertools import groupby, imap
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, TfidfTransformer

query = """
        SELECT base_url, article_text
        FROM articles
        WHERE num_words > 100
        ORDER BY base_url
        """

class SourceNGramStream(SentenceStream):
    """
    Get a stream of pre-identified n-grams from each source
    """
    def __iter__(self):
        rows = super(SourceStream, self).__iter__()
        source_sentences = groupby(rows, lambda x: x[0])
        
        for source, sentences in source_sentences:
            source_ngrams = [word for id, sentence in sentences for word in sentence if '_' in word]
            if source_ngrams:
                yield source, source_ngrams

# dummy tokenizer -- we can't do lambda x: x because it is unpicklable
def no_tokenizer(x):
    return x

# the n-grams we've located will now be identified in the stream of text
src_stream = SourceNGramStream(sqldb=sql_url, query=query,
                               ngrams=ngrams, idcol='base_url')
    
# we're using max_df=1 so that we only keep 
vectorizer = CountVectorizer(analyzer='word', preprocessor=None,
                             lowercase=False, tokenizer=no_tokenizer, max_df=1)
dtm = vectorizer.fit_transform(imap(lambda x: x[1], src_stream))

# %% [markdown]
# By limiting ourselves to only phrases that appear within each source and no others, we can handily remove junk phrases like "subscribe to our newsletter". Next, we'll re-run the above query but will limit ourselves to phrases that only appear on a given side [alternatively, we could do tf-idf side by side, perhaps finding that things like 'united states' appear more on the right than the left. In all likelihood, both options are appropriate].

# %%
with open('../intermediate/vec_source_5gram.pkl', 'wb') as vecf,\
     open('../intermediate/dtm_source_5gram.pkl', 'wb') as dtmf:
    pickle.dump(vectorizer, vecf)
    pickle.dump(dtm_source, dtmf, pickle.HIGHEST_PROTOCOL)

# %%
# we want a parallel list of sources
source_query = "SELECT base_url FROM articles GROUP BY base_url ORDER BY base_url"
sources = [r.base_url for r in create_engine(sql_url).execute(source_query).fetchall()]

# %%
features = vectorizer.get_feature_names()
np.random.permutation(features)[:15]
# Out:
# array([u'2015_thehill', u'image_screenshot_via', u'buy_point',
#        u'us_based_cleric', u'contact_robert_trigaux',
#        u'shares_shares_facebooktwitter_googlepinterestdigglinkedin_reddit_stumbleupon_printdeliciouspockettumblr',
#        u'receive_your_first_alert', u'credit_ap_photosusan_walsh',
#        u'weekly_standard_podcast', u'newsabortion_catholic_church',
#        u'taxes_depreciation', u'bioethics_attorney',
#        u'uwgreen_bay_because_students_lean', u'special_lets_slam_congress',
#        u'richard_danielson'],
#       dtype='<U103')

# %% [markdown]
# Note that we have phrases like "weekly standard podcast" or "follow X on twitter". These should made for a decent stopword list.

# %% [markdown]
# We can now remove junk phrases from each publication knowing that we'll keep the real meat of the article. What's more, in the next post, we'll explore the most characteristic phrases from each source.
#
# NOTE: You can also do tf-idf after having summed up left- and right-.

# %%
wfidf_dtm = TfidfTransformer(sublinear_tf=True).fit_transform(dtm) 
#also can do tfidf w/o sublinear
bb_dict_sorted_wf = np.argsort(wfidf_dtm[bbidx,].toarray()[0])[::-1]
bb_top_features = [features[i] for i in bb_dict_sorted]

# %%
query = """
        SELECT base_url, article_text
        FROM articles
        WHERE num_words > 100
        ORDER BY base_url
        """

# %% [markdown]
# ### Part-of-Speech Tagging
# Of the n-grams collected above, we're largely interested in noun-phrases like 'fetal_organs' (appears 56 times in the sample) rather than verbal or adjectival phrases like 'radical-islamic'.

# %%
ngrams[('crooked','hillary')]
# Out:
# (212, 726.420180499342)

# %%
from nltk import pos_tag

class POSSentenceStream(SentenceStream):
    def __iter__(self):
        sentences = super(POSSentenceStream, self).__iter__()
        for id, sentence in sentences:
            for word, pos in pos_tag(sentence):
                if '_' in word:
                    yield word, pos
            
pos_words = list(POSSentenceStream(sqldb=sql_url, query=query, ngrams=ngrams))

# %%
with open('../intermediate/pos_stream_all.pkl', 'wb') as o:
    pickle.dump(pos_words, o)

# %%
from collections import defaultdict
from collections import Counter

def count_ngram_pos(pos_stream, ngrams):
    pos_counts = {word: Counter() for word, pos in pos_stream}
    for word, pos in pos_stream:
        pos_counts[word].update([pos])
    
    for word, counts in pos_counts.items():
        split_word = tuple(word.split('_'))
                
        word_count = ngrams[split_word][0]
        has_high_score = ngrams[split_word][1] > 1000
        
        noun_counts = counts['NN'] + counts['NNS']
        is_noun = 'NN' in top_pos[0]
         
        if is_noun and has_high_score:
            yield split_word 
            
noun_ngrams = list(count_ngram_pos(pos_words, ngrams))
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-36-7208bbe2039d> in <module>()
#      19             yield split_word
#      20
# ---> 21 noun_ngrams = list(count_ngram_pos(pos_words, ngrams))
#
# <ipython-input-36-7208bbe2039d> in count_ngram_pos(pos_stream, ngrams)
#      14
#      15         noun_counts = counts['NN'] + counts['NNS']
# ---> 16         is_noun = 'NN' in top_pos[0]
#      17
#      18         if is_noun and has_high_score:
#
# NameError: global name 'top_pos' is not defined

# %% [markdown]
# ## TESTING GROUNDS

# %%
[(k, v) for k, v in ngrams.items() if 'subscribe' in k]
# Out:
# [(('subscribe', 'today'), (227, 9305.383664156087))]

# %%
[(k, v) for k, v in phraser.phrasegrams.items() 
 if 'xl' in k[0] or 'xl' in k[1] or
    'keystone' in k[0] or 'keystone' in k[1]]

# %%
eng = create_engine(sql_url)
query = """
        SELECT article_text, url, base_url
        FROM articles
        WHERE lower(article_text) like '%%please_try_again_later%%'
        LIMIT 2
        """
eng.execute(query).fetchall()
# Out:
# [(u'Vice presidential candidate Sen. Tim Kaine, D-Va., suggested Wednesday that Donald Trump faked a health condition in the 1960s so as to avoid being drafted and sent off to Vietnam.\n\nThe Virginia senator\'s insinuation came as he continued his week-long campaign to cast doubt on Trump\'s claim he is in good physical shape.\n\n"Look, the one good thing we can say about Trump\'s health is apparently the medical issue that kept him out of the services magically cleared up, because now he\'s the healthiest individual who has ever going to be elected," Kaine, whose son is a United States Marine, said at a campaign stop in Bethlehem, Pa.\n\n"So I guess we got a medical miracle working here," he said to laughs.\n\nStay abreast of the latest developments from nation\'s capital and beyond with curated News Alerts from the Washington Examiner news desk and delivered to your inbox. Sorry, there was a problem processing your email signup. Please try again later. Processing... Thank you for signing up for Washington Examiner News Alerts. You should receive your first alert soon!\n\nThe only medical record that Trump has made publicly available is a hastily written letter claiming he would "be the healthiest individual ever elected to the presidency."\n\nTrump\'s physician, Harold Bornstein, told NBC News last week, "I don\'t think he\'s in any better or worse (shape) than the average person that goes and exercises every single day."\n\n"Doesn\'t smoke, doesn\'t drink \u2014 and that\'s simply the best advantage you can have to live \u2014 and he\'s got a good family history," he said.\n\nOn Wednesday, Kaine took aim at Bornstein\'s letter specifically, and joked before the crowd in Bethlehem that Trump\'s health diagnosis is a bit funny considering the GOP nominee\'s alleged health issues.\n\nTrump received five draft deferments during Vietnam: Four for college and one for bone spurs.\n\n"Back in 1968, at the age of 22, Donald J. Trump seemed the picture of health," the New York Times reported. "He stood 6 feet 2 inches with an athletic build; had played football, tennis and squash; and was taking up golf. His medical history was unblemished, aside from a routine appendectomy when he was 10."\n\n"But after he graduated from college in the spring of 1968, making him eligible to be drafted and sent to Vietnam, he received a diagnosis that would change his path: bone spurs in his heels," the report noted.', u'http://www.washingtonexaminer.com/article/2600736/', u'washingtonexaminer.com'),
#  (u'Donald Trump spent Monday afternoon meeting with local members of the Fraternal Order of Police in Akron, Ohio, just one month before the national police union is expected to make its presidential endorsement.\n\nTrump, who is working to solidify his image as the "law and order" candidate, could benefit tremendously if he succeeds in securing the 330,000-member union\'s support. The group is said to be working toward scheduling a meeting with Hillary Clinton, but not until she completes a questionnaire that FOP officials sent her campaign earlier this summer.\n\nAfter a brief photo-op, Trump patiently fielded questions from Akron police during a roundtable about his relationship with law enforcement, whether he would reverse President Obama\'s recall of military gear for police and how he plans to combat poverty and crime in urban areas.\n\n"We\'ve had a tremendous relationship with law enforcement. I appreciate everything that is going on," Trump told the officers on Monday. "We\'ve had many endorsements from many different groups all over the country and we have tremendous support for them.\n\nStay abreast of the latest developments from nation\'s capital and beyond with curated News Alerts from the Washington Examiner news desk and delivered to your inbox. Sorry, there was a problem processing your email signup. Please try again later. Processing... Thank you for signing up for Washington Examiner News Alerts. You should receive your first alert soon!\n\n"I\'m with you 100 percent," he added. "It\'s an honor to be here."\n\nTrump met with FOP President Chuck Canterbury and executive director Jim Pasco at his Manhattan skyscraper earlier this month. The group, which has chapters across battleground states that are crucial to Trump\'s path to the White House, is slated to announce its endorsement after board members convene in early September.\n\nAfter endorsing Bill Clinton\'s re-election bid in 1996, the FOP backed George W. Bush in both 2000 and 2004, and John McCain in 2008. Neither President Obama nor GOP nominee Mitt Romney received the group\'s endorsement in the last election cycle.\n\nAccording to Ohio Sen. Rob Portman, there is an opening for Trump to win the support of the FOP and union voters "if he doesn\'t squander it."\n\n"I think Donald Trump has an opportunity if he talks about those issues. If he gets off on Gold Star families or whatever, he\'s not going to be able to get as much support," Portman told the Washington Examiner after his own meeting with the Akron FOP chapter last week. "If he\'s talking about the New York Times, I don\'t think it works."', u'http://www.washingtonexaminer.com/trump-courts-police-union-ahead-of-endorsement/article/2599920?custom_click=rss', u'washingtonexaminer.com')]

# %%
import pandas as pd
df = pd.DataFrame().from_records([{'ngram':nltk.pos_tag(k), 'count':v[0], 'score':v[1]} for k, v in ngrams.items()])
# Out:
#        count                                              ngram         score
# 43178   2057                     [(supreme, NN), (courts, NNS)]  2.060704e+03
# 42519   2049                       [(gop, NN), (candidate, NN)]  1.471702e+01
# 47289   2017                   [(federal, JJ), (agencies, NNS)]  1.025098e+02
# 11881   1996                        [(donald, NN), (trump, NN)]  8.610223e+02
# 33101   1996                           [(2, CD), (percent, NN)]  3.851224e+01
# 38577   1988                   [(interesting, JJ), (story, NN)]  9.989389e+02
# 44755   1984                  [(affirmative, JJ), (action, NN)]  1.713739e+03
# 27144   1978                    [(get, VB), (intelligence, NN)]  1.034730e+01
# 28302   1977                   [(jacqueline, NN), (klimas, NN)]  2.395293e+06
# 42337   1975                          [(issue, NN), (soon, RB)]  1.240909e+01
# 32003   1969                      [(jamie, NN), (mcintyre, NN)]  1.622197e+05
# 47475   1969                [(veteran, NN), (journalists, NNS)]  9.177786e+04
# 33901   1968  [(morning, NN), (from, IN), (veteran, NN), (jo...  1.813218e+07
# 16439   1968  [(inbox, JJ), (each, DT), (weekday, NN), (morn...  1.142327e+07
# 44948   1968  [(veteran, NN), (journalists, NNS), (jamie, VB...  1.237509e+04
# 576     1968                     [(subscribe, NN), (today, NN)]  6.764227e+03
# 40420   1968           [(inbox, JJ), (each, DT), (weekday, NN)]  1.469655e+03
# 42293   1967                        [(four, CD), (months, NNS)]  3.811784e+01
# 32948   1965                  [(defense, NN), (newsletter, NN)]  1.457044e+04
# 33565   1965  [(daily, RB), (on, IN), (defense, NN), (newsle...  1.303495e+03
# 29655   1965             [(first, RB), (issue, NN), (soon, RB)]  1.066996e+02
# 7220    1964                           [(3, CD), (percent, NN)]  4.722359e+01
# 19588   1964                        [(large, JJ), (number, NN)]  2.585038e+01
# 43263   1963                            [(mr, NN), (obama, NN)]  1.001975e+01
# 46268   1959                          [(first, JJ), (step, NN)]  1.139340e+01
# 18300   1956                     [(twitter, NN), (content, NN)]  6.083775e+03
# 22940   1951               [(told, VBD), (fox, JJ), (news, NN)]  5.411568e+02
# 37563   1940           [(morning, NN), (news, NN), (blast, NN)]  5.145530e+04
# 20576   1934                   [(international, JJ), (law, NN)]  1.108419e+01
# 45254   1929  [(well, RB), (told, RB), (from, IN), (charisma...  5.497331e+07
# ...      ...                                                ...           ...
# 28097   1762                     [(public, JJ), (interest, NN)]  1.563980e+01
# 25050   1754                   [(assisted, VBN), (suicide, NN)]  4.854297e+03
# 45730   1753                           [(12, CD), (years, NNS)]  1.538655e+01
# 8840    1748                          [(final, JJ), (form, NN)]  1.221534e+05
# 14552   1748                  [(recently, RB), (released, VBN)]  1.045729e+01
# 34931   1738                  [(muslim, NN), (immigration, NN)]  2.639812e+01
# 15145   1736                        [(vietnam, NNS), (war, NN)]  2.194316e+03
# 22263   1735                     [(rush, NN), (transcript, NN)]  1.579802e+04
# 11382   1731                            [(copy, NN), (may, MD)]  2.070612e+01
# 14386   1730                        [(last, JJ), (weekend, NN)]  2.554798e+01
# 32568   1726                   [(senate, NN), (democrats, NNS)]  1.077205e+01
# 43198   1724                             [(tv, NN), (show, NN)]  1.975488e+01
# 32207   1721                         [(last, JJ), (friday, NN)]  1.075432e+01
# 19324   1719                        [(second, JJ), (place, NN)]  1.131546e+01
# 26149   1718                    [(abortion, NN), (rights, NNS)]  1.541397e+01
# 5901    1694                          [(ted, VBN), (cruzs, NN)]  1.418600e+03
# 33939   1693                         [(baby, NN), (parts, NNS)]  8.286045e+01
# 46174   1692                        [(least, JJS), (three, CD)]  5.251458e+03
# 19828   1690                       [(locker, NN), (rooms, NNS)]  3.428478e+04
# 1065    1690           [(us, PRP), (district, NN), (judge, NN)]  2.227888e+02
# 12455   1684                             [(10, CD), (2016, CD)]  1.287236e+01
# 19229   1682         [(southern, JJ), (poverty, NN), (law, NN)]  2.086030e+05
# 21058   1678                          [(weeks, NNS), (ago, RB)]  3.312917e+03
# 40497   1661                            [(nt, NNS), (care, NN)]  7.928962e+02
# 46665   1660   [(related, JJ), (comments, NNS), (facebook, NN)]  1.409803e+05
# 29895   1660  [(related, JJ), (comments, NNS), (facebook, VB...  5.523911e+02
# 45264   1645                         [(doesnt, NN), (care, NN)]  1.251644e+01
# 21287   1636                        [(first, RB), (ballot, NN)]  2.008143e+01
# 24883   1632                          [(37, CD), (percent, NN)]  3.162100e+02
# 27224   1629                       [(almost, RB), (always, RB)]  1.062970e+01
#
# [99 rows x 3 columns]

# %%
df.sort_values(['count', 'score'], ascending = False)[200:299]

# %%
nltk.pos_tag(['the','republican','presidential', 'candidate'])
# Out:
# [('the', 'DT'),
#  ('republican', 'JJ'),
#  ('presidential', 'JJ'),
#  ('candidate', 'NN')]

# %%
### MAKE SURE `grammar` IS CORRECT
### ONLY COLLECT NOUN PHRASES

import nltk
#Taken from Su Nam Kim Paper...
# http://stackoverflow.com/questions/38194579/extracting-noun-phrases-from-nltk-using-python
posttoks = nltk.tag.pos_tag(['justin','clinton', 'is','a','big','boy', 'who',
                            'studies','campaign','finance','reform', 'on','september','11th'])
grammar = r"""
           NBAR:
               {<NN.*|JJ>*<NN.*>}  # Nouns and Adjectives, terminated with Nouns
           NP:
               {<NBAR>}
               {<NBAR><IN><NBAR>}  # Above, connected with in/of/etc...
           """
chunker = nltk.RegexpParser(grammar)
tree = chunker.parse(posttoks)

# %%
nltk.tag.pos_tag(['selling', 'aborted', 'baby', 'parts'])
# Out:
# [('selling', 'VBG'), ('aborted', 'VBN'), ('baby', 'NN'), ('parts', 'NNS')]

# %%
for subtree in tree.subtrees(filter=lambda t: t.label() == 'NP'):
    print(subtree)
# Out:
# (NP (NBAR justin/NN clinton/NN))
# (NP (NBAR big/JJ boy/NN))
# (NP (NBAR studies/NNS campaign/NN finance/NN reform/NN))
# (NP (NBAR september/NN))

# %%
[(k, v) for k, v in ngrams.items() if v[1] > 100]
# Out:
# [(('right', 'direction'), (183, 132.2074442511208)),
#  (('new', 'c-pop', 'podcast', 'where', 'taylor'), (98, 2854.845853234911)),
#  (('best', 'friend'), (67, 260.4415876744121)),
#  (('next', 'week'), (642, 131.6409975015382)),
#  (('human', 'rights'), (156, 201.4450398890045)),
#  (('sen', 'marco', 'rubio', 'r-fla'), (56, 3278.5030417871744)),
#  (('taken', 'into', 'custody'), (173, 1476.139290830475)),
#  (('wide', 'range'), (172, 2434.9890714363773)),
#  (('las', 'vegas'), (605, 615422.6624165149)),
#  (('tampabaycom', 'or', '813'), (60, 70242.62820512822)),
#  (('criminal', 'justice', 'system'), (197, 12140.518164003617)),
#  (('media', 'outlets'), (529, 445.54178533497395)),
#  (('police', 'brutality'), (85, 521.2237162551507)),
#  (('oval', 'office'), (446, 27032.822078245703)),
#  (('car', 'accident'), (57, 120.04505702945998)),
#  (('analysts', 'polled'), (59, 3592.737704918033)),
#  (('lifenews', 'previously', 'reported'), (72, 2522.050300253175)),
#  (('abraham', 'lincoln'), (149, 8576.25106726117)),
#  (('congress', 'must', 'investigate', 'planned'), (58, 175325.6)),
#  (('less', 'than', '1', 'percent'), (63, 13597.942917143948)),
#  (('cnn', 'politics', 'cnnpolitics'), (60, 190903.3101045296)),
#  (('standing', 'ovation'), (91, 1079980.408653846)),
#  (('puerto', 'ricans'), (61, 1255586.9791666665)),
#  (('michael', 'brown'), (110, 2417.5283129872037)),
#  (('voting', 'rights', 'act'), (196, 333.2333745332722)),
#  (('charlie', 'rose'), (86, 214.668987044196)),
#  (('truck', 'driver'), (76, 155.68666174130485)),
#  (('jimmy', 'kimmel'), (101, 16226.781358885017)),
#  (('35', 'percent'), (79, 114.74967428733201)),
#  (('march', '4', '2016'), (79, 180.86212646896786)),
#  (('john', 'bel', 'edwards'), (52, 399.3676652817261)),
#  (('fast', 'forward'), (56, 156.0310129766572)),
#  (('ron', 'johnson'), (78, 163.54442065942314)),
#  (('sept', '11', '2001'), (94, 150107.53424657532)),
#  (('charles', 'krauthammer'), (97, 1957.8896247072778)),
#  (('law', 'enforcement'), (103, 3614.966450054775)),
#  (('quid', 'pro', 'quo'), (98, 6261628.571428571)),
#  (('incident', 'took', 'place'), (98, 128.34587566981932)),
#  (('florida', 'senator'), (117, 195.61749957368804)),
#  (('highest', 'levels'), (70, 122.76547641454474)),
#  (('via', 'wikimedia'), (59, 294.210838772807)),
#  (('news', 'alerts'), (1390, 11331.029857979362)),
#  (('rhode', 'island'), (271, 18608.305286614413)),
#  (('dr', 'carson'), (196, 106.95652668053224)),
#  (('elementary', 'school'), (53, 152.712715549279)),
#  (('elijah', 'cummings'), (65, 5595.30739379085)),
#  (('ayn', 'rand'), (65, 30734.433433059086)),
#  (('past', '20', 'years'), (54, 499.3551768137076)),
#  (('tv', 'station'), (136, 149.15992443039474)),
#  (('gun', 'owners'), (411, 410.550164166768)),
#  (('huma', 'abedin'), (322, 32110.915750915752)),
#  (('december', '27', '2015'), (72, 3134.885565669701)),
#  (('bottom', 'line'), (594, 579.650642334009)),
#  (('taking', 'advantage'), (118, 527.3730356227829)),
#  (('census', 'bureau'), (59, 373.506476291471)),
#  (('gmo', 'labeling'), (85, 1481.0192693852332)),
#  (('brit', 'hume'), (65, 98306.07057416267)),
#  (('president', 'barack', 'obama'), (93, 3932.9867950986613)),
#  (('30', 'years', 'ago'), (83, 300.8770229229937)),
#  (('trade', 'deals'), (364, 616.6510566762729)),
#  (('rallying', 'cry'), (79, 1503.8457716151627)),
#  (('former', 'hewlett-packard', 'ceo'), (55, 1173.6194413503556)),
#  (('natural', 'gas'), (81, 1546.8731785063753)),
#  (('house', 'armed', 'services'), (120, 1345.757540668379)),
#  (('september', '1', '2016'), (115, 785.2058758681512)),
#  (('biological', 'diversity'), (56, 2899.9250176429077)),
#  (('first', 'alert', 'soon'), (1323, 1022.0745566332173)),
#  (('jim', 'witcher'), (76, 7701.77605968858)),
#  (('crude', 'oil'), (136, 396.5063685048487)),
#  (('sen', 'ted', 'cruz', 'r-texas'), (80, 360455.59210526315)),
#  (('per', 'year'), (591, 164.2933563890672)),
#  (('mad', 'world', 'news'), (85, 6905.876368481706)),
#  (('title', 'ix'), (250, 66471.64088565363)),
#  (('31', 'percent'), (139, 163.56464758038035)),
#  (('nbcs', 'meet'), (87, 1065.8826699616172)),
#  (('north', 'dakota'), (116, 51379.518329070765)),
#  (('greenhouse', 'gas'), (122, 2103.065973610556)),
#  (('pop', 'culture'), (214, 404.4635570625985)),
#  (('capital', 'punishment'), (108, 208.72095238095235)),
#  (('ballot', 'box'), (103, 860.3635574438836)),
#  (('memorial', 'day', 'weekend'), (55, 3192.102656723374)),
#  (('follow', 'warner', 'todd', 'huston', 'on', 'twitter', 'warnerthuston'),
#   (81, 25887.31519585429)),
#  (('july', '22', '2016'), (152, 659.1631104789)),
#  (('recent', 'months'), (276, 1461.5381573744562)),
#  (('health', 'care'), (154, 282.7822434363752)),
#  (('national', 'intelligence'), (106, 434.0663507109005)),
#  (('thank', 'you', 'for', 'signing'), (1548, 290220.2846534654)),
#  (('tony', 'perkins'), (115, 2907.4695072170334)),
#  (('sound', 'bites'), (135, 3934.3467517107374)),
#  (('donald', 'trump', 'would'), (162, 558.2601892285298)),
#  (('composite', 'rating'), (58, 6007.5932017543855)),
#  (('lt', 'gen'), (88, 2321.5783898305085)),
#  (('drug', 'administration'), (138, 978.6177640659253)),
#  (('malheur', 'national', 'wildlife', 'refuge'), (57, 330624.7844827586)),
#  (('73', 'percent'), (71, 127.93469135871106)),
#  (('gaza', 'strip'), (61, 7400.316183693517)),
#  (('slippery', 'slope'), (76, 96251.38513513515)),
#  (('image', 'credit', 'twitter'), (66, 4669.3725364866295)),
#  (('brokered', 'convention'), (104, 6855.003475440223)),
#  (('anywhere', 'near'), (137, 160.8118126557373)),
#  (('58', 'percent'), (117, 290.6683572067685)),
#  (('catholic', 'bishops'), (70, 172.9294890004103)),
#  (('tea', 'party'), (80, 1427.0511373502343)),
#  (('concealed', 'carry', 'permit'), (67, 17322.24753580063)),
#  (('plea', 'deal'), (60, 128.43056590859013)),
#  (('study', 'published'), (117, 178.49221167895635)),
#  (('tell', 'us', 'what', 'you', 'think'), (164, 612.2333965565406)),
#  (('december', '4', '2015'), (57, 165.04916727632653)),
#  (('nine', 'months'), (199, 145.80835277927363)),
#  (('live', 'action', 'news'), (72, 665.3034359045122)),
#  (('donald', 'trump'), (644, 2189.438062331225)),
#  (('metric', 'tons'), (74, 3035.695816788254)),
#  (('campaign', 'rally'), (153, 149.12547585286205)),
#  (('attorney', 'marilyn'), (55, 214.8395837254533)),
#  (('1237', 'delegates'), (93, 1248.1921662746095)),
#  (('68', 'percent'), (81, 176.1156890680669)),
#  (('july', '28', '2016'), (88, 341.4029883542079)),
#  (('nt', 'work'), (58, 530.6914629569092)),
#  (('jerry', 'falwell', 'jr'), (63, 1688.6207918444761)),
#  (('price', 'tag'), (137, 1348.1263628573124)),
#  (('march', '24', '2016'), (105, 669.8488320914767)),
#  (('center', 'for', 'american', 'progress'), (169, 99237.75875190258)),
#  (('2016', 'presidential', 'race'), (116, 1196.5726793821393)),
#  (('new', 'york', 'times', 'report'), (56, 216.52264119874854)),
#  (('globalist', 'agenda'), (128, 5525.9665614978785)),
#  (('ht', 'breitbart'), (131, 130.06902883369773)),
#  (('independence', 'letter', 'today'), (125, 1975573.9182692308)),
#  (('less', 'than', 'half'), (121, 12377.61470663103)),
#  (('r', 'b'), (67, 2529.1008200282395)),
#  (('nt', 'mean'), (94, 1535494.9044585987)),
#  (('george', 'pataki'), (76, 2477.5131308915093)),
#  (('last', 'few', 'months'), (89, 160.73537774808972)),
#  (('alicia', 'machado'), (85, 9612.149122807017)),
#  (('much', 'larger'), (82, 363.77473742743206)),
#  (('consumer', 'financial', 'protection', 'bureau'), (54, 547892.5)),
#  (('opened', 'fire'), (128, 2630.855392760404)),
#  (('donald', 'trump', 'doesnt'), (60, 216.71591196759695)),
#  (('ku', 'klux', 'klan'), (228, 669813.6332417582)),
#  (('congressional', 'legislator'), (90, 57916.754756871036)),
#  (('second', 'world', 'war'), (82, 100.48256684295829)),
#  (('take', 'just', '30', 'seconds'), (74, 103132.70588235295)),
#  (('espionage', 'act'), (70, 1335.2159185066043)),
#  (('fifth', 'circuit'), (65, 526.5564333218007)),
#  (('operation', 'rescue'), (206, 942.7999885281632)),
#  (('thank', 'god'), (52, 101.98092135877152)),
#  (('israeli', 'prime', 'minister', 'benjamin', 'netanyahu'),
#   (100, 5097.907400859743)),
#  (('homeland', 'security'), (89, 1737.5591578844653)),
#  (('took', 'advantage'), (81, 166.52320487706356)),
#  (('september', '20', '2016'), (70, 282.60090264345587)),
#  (('every', 'member'), (118, 311.99651966523135)),
#  (('gallup', 'poll'), (99, 337.34636934687575)),
#  (('anybody', 'else'), (189, 545.9036825550655)),
#  (('july', '11', '2016'), (60, 103.34474498264674)),
#  (('student', 'loan', 'debt'), (65, 3705.982819264069)),
#  (('john', 'mccain'), (81, 530.5884695885788)),
#  (('cant', 'wait'), (84, 169.0321933762167)),
#  (('1', 'get'), (758, 412.71626466926983)),
#  (('1', 'site', 'wide'), (80, 568.2058594762769)),
#  (('follow', 'tregp'), (91, 6048.355546580507)),
#  (('co2', 'emissions'), (84, 737.9023569023568)),
#  (('mark', 'zuckerberg'), (110, 728.2560295612991)),
#  (('ai', 'nt'), (111, 301.0257355987649)),
#  (('2', 'learn'), (758, 2961.12893129771)),
#  (('source', 'getty', 'images'), (86, 214.4225500939261)),
#  (('al', 'sharpton'), (196, 5304.810931614409)),
#  (('values', 'voter', 'summit'), (74, 25572.578763127185)),
#  (('special', 'prosecutor'), (67, 155.74393355672825)),
#  (('breast', 'cancer'), (229, 2470.477216678968)),
#  (('august', '3', '2016'), (115, 938.9462992404168)),
#  (('theres', 'so', 'much'), (60, 360.265978432404)),
#  (('told', 'from', 'charisma'), (239, 408649.10220994474)),
#  (('3', 'reasons', 'why', 'you', 'should', 'read'), (758, 6698.229900538749)),
#  (('november', '20', '2015'), (71, 183.98884624610218)),
#  (('kanye', 'west', 'kanyewest'), (91, 34035.746212121216)),
#  (('follow', 'steve', 'on', 'twitter'), (193, 68331.26417233559)),
#  (('80', 'percent'), (283, 1287.4868133885204)),
#  (('sandy', 'hook', 'elementary', 'school'), (70, 1678.900839615125)),
#  (('refugee', 'camps'), (67, 167.64531451363243)),
#  (('billionaire', 'businessman'), (129, 1371.3369293159712)),
#  (('october', '3', '2016'), (59, 173.75638676486133)),
#  (('andrea', 'mitchell'), (88, 2431.4093356222775)),
#  (('ht', 'opposing', 'views'), (57, 297.665975908851)),
#  (('elena', 'kagan'), (59, 9949.62167070218)),
#  (('could', 'care', 'less'), (52, 522.9978045055365)),
#  (('red', 'meat'), (92, 138.03633342531162)),
#  (('subscribe', 'today'), (220, 9186.118014872674)),
#  (('american', 'exceptionalism'), (82, 234.08832372905795)),
#  (('oliver', 'darcy'), (51, 939.6201337677928)),
#  (('february', '13', '2016'), (67, 894.578507078507)),
#  (('fetal', 'body', 'parts'), (90, 23821.41304347826)),
#  (('boston', 'marathon'), (95, 12050.4215542522)),
#  (('open', 'borders'), (242, 237.70674280848897)),
#  (('state', 'john', 'kerry'), (322, 1455.9536835852625)),
#  (('last', 'eight', 'years'), (67, 404.23990503966803)),
#  (('private', 'sector'), (208, 4579.150841594109)),
#  (('sen', 'rand', 'paul', 'r-ky'), (64, 13402.926786650358)),
#  (('homeless', 'shelters'), (62, 348.4213036565978)),
#  (('consulting', 'firm'), (76, 366.34944270423466)),
#  (('new', 'zealand'), (133, 4224.109896336478)),
#  (('charlie', 'hebdo'), (130, 115103.46638655463)),
#  (('paul', 'ryan', 'versus', 'bernie', 'sanders'), (58, 19611.364653243847)),
#  (('nikki', 'haley'), (138, 45687.99393537383)),
#  (('like', 'blackamericawebcom', 'on', 'facebook'), (262, 1079.4566900302407)),
#  (('rnc', 'chairman', 'reince', 'priebus'), (64, 19428.812056737588)),
#  (('nina', 'simone'), (62, 1951.0683126595047)),
#  (('liberal', 'media'), (273, 154.25290944303325)),
#  (('63', 'percent'), (64, 207.4093352513628)),
#  (('2016', 'election'), (298, 174.62296226384055)),
#  (('vice', 'presidential', 'running', 'mate'), (53, 141696.33620689655)),
#  (('small', 'businesses'), (217, 102.14389255796091)),
#  (('climate', 'change'), (76, 707.8538597232229)),
#  (('investigative', 'journalism'), (63, 180.59932249288136)),
#  (('quicken', 'loans', 'arena'), (70, 15667.500714898486)),
#  (('armed', 'forces'), (94, 706.1711289472144)),
#  (('orlando', 'florida'), (115, 122.46228611317434)),
#  (('soviet', 'union'), (253, 3730.310020190637)),
#  (('daily', 'kos'), (107, 12572.412439613527)),
#  (('middle', 'east'), (1860, 6405.698649338233)),
#  (('please', 'chip'), (115, 530.9344535535012)),
#  (('civil', 'rights', 'movement'), (291, 160.7733906721741)),
#  (('emphasis', 'mine'), (67, 612.3716305062459)),
#  (('arrest', 'warrant'), (66, 110.42045597682329)),
#  (('bill', 'cosby'), (223, 209.09390269459428)),
#  (('jerry', 'miller'), (63, 201.87409303222)),
#  (('nations', 'largest'), (167, 213.8072145575928)),
#  (('march', '13', '2016'), (53, 100.46068796068795)),
#  (('oh', 'my', 'god'), (202, 891.2157953876612)),
#  (('alma', 'mater'), (64, 426138.6111111111)),
#  (('general', 'population'), (133, 267.5168216173225)),
#  (('fast', 'track'), (111, 161.1185954265891)),
#  (('wrote', 'on', 'facebook'), (91, 198.17343048100977)),
#  (('immigration', 'studies'), (81, 2552.6266945204243)),
#  (('based', 'upon'), (153, 152.26775582516046)),
#  (('united', 'states', 'supreme', 'court'), (69, 27826.670676289763)),
#  (('pledged', 'delegates'), (187, 276.794199663103)),
#  (('college', 'tuition'), (88, 184.669978676828)),
#  (('natural', 'disasters'), (73, 313.9393996013951)),
#  (('hotel', 'room'), (162, 120.39613580027459)),
#  (('follow', 'kitdaniels1776'), (54, 252.89291483960307)),
#  (('democratic', 'national', 'convention'), (84, 1012.3990500103259)),
#  (('civil', 'unrest'), (82, 589.0624422530952)),
#  (('border', 'protection'), (76, 2658.6795446061965)),
#  (('violent', 'crime'), (254, 118.67247659227476)),
#  (('erick', 'erickson'), (130, 64353.839377477605)),
#  (('ariana', 'grande'), (52, 6286.775674125071)),
#  (('hillary', 'rodham', 'clinton'), (164, 7749.8287734971145)),
#  (('rob', 'portman'), (75, 2422.4166136106396)),
#  (('18', 'months'), (203, 132.39761904761906)),
#  (('white', 'supremacy'), (287, 939.1491819996528)),
#  (('15', 'an', 'hour'), (65, 609.2026552214909)),
#  (('appellate', 'court'), (58, 114.13892057143154)),
#  (('stephen', 'breyer'), (56, 424.17483870967743)),
#  (('safe', 'spaces'), (124, 337.64644598862077)),
#  (('fetal', 'tissue'), (58, 5001.871505192285)),
#  (('executive', 'vice', 'president'), (144, 331.2276710920914)),
#  (('white', 'house', 'press', 'secretary'), (175, 69346.45858647226)),
#  (('sheldon', 'adelson'), (61, 17121.640625)),
#  (('allen', 'dulles'), (62, 879.7952629466077)),
#  (('via', 'social', 'media'), (52, 982.2382574399427)),
#  (('pickup', 'truck'), (69, 1278.7388831564465)),
#  (('inspector', 'generals'), (75, 7325.15776244719)),
#  (('campaign', 'finance', 'reform'), (80, 364.22080454523297)),
#  (('74', 'percent'), (66, 100.02795581383938)),
#  (('september', '11th'), (66, 222.0435663627153)),
#  (('debt', 'ceiling'), (73, 2867.0460491889066)),
#  (('last', 'few', 'days'), (74, 823.8984962406015)),
#  (('license', 'plates'), (60, 515.5810364459334)),
#  (('click', 'here', 'for', 'reuse', 'options'), (101, 3289.6383960631492)),
#  (('marriage', 'licenses'), (70, 364.1292247776083)),
#  (('jonah', 'goldberg'), (70, 4414.216081211731)),
#  (('republican', 'presidential', 'candidate'), (113, 126.93517217792945)),
#  (('sanders', 'campaign'), (362, 413.8212968441194)),
#  (('illegal', 'alien'), (288, 1557.7474387644904)),
#  (('coming', 'weeks'), (96, 218.05044141210342)),
#  (('make', 'america', 'great'), (485, 504.28569841657753)),
#  (('mitt', 'romneys'), (92, 22865.14805246423)),
#  (('makes', 'sense'), (113, 155.41412049794144)),
#  (('bernie', 'sanders', 'campaign'), (95, 267.83078051165063)),
#  (('private', 'equity'), (79, 128.1464835873861)),
#  (('stem', 'cells'), (75, 809.3090276341678)),
#  (('nt', 'take'), (58, 430.961791831357)),
#  (('terrorist', 'group'), (140, 169.89025940221487)),
#  (('matt', 'bevin'), (54, 306.0680967543713)),
#  (('john', 'podesta'), (141, 274.62814262446153)),
#  (('illegal', 'aliens'), (68, 3457.947054698457)),
#  (('directly', 'at', 'awrhawkins', 'breitbartcom'), (85, 3306247.8448275863)),
#  (('greta', 'van', 'susteren'), (118, 9314172.5)),
#  (('ht', 'mad', 'world', 'news'), (86, 234.15043270771753)),
#  (('president', 'cecile', 'richards'), (53, 52851.366559485534)),
#  (('islamic', 'extremism'), (90, 194.57895400394563)),
#  (('british', 'prime', 'minister', 'david'), (54, 77715.24822695035)),
#  (('harris', 'county'), (51, 117.85675873343658)),
#  (('overwhelming', 'majority'), (137, 324.7438383238306)),
#  (('least', 'five'), (108, 3021.4755688246983)),
#  (('law-abiding', 'citizens'), (133, 515.6559279636417)),
#  (('told', 'from', 'charisma', 'news'), (239, 442.3385789436588)),
#  (('political', 'career'), (64, 100.96476333385985)),
#  (('clinton', 'global', 'initiative'), (108, 32215.901257096513)),
#  (('78', 'percent'), (83, 233.883435051109)),
#  (('eminent', 'domain'), (161, 199724.35960591133)),
#  (('internet', 'delivered', 'free'), (74, 264575.8551307847)),
#  (('judge', 'gonzalo', 'curiel'), (51, 27394.625)),
#  (('palo', 'alto'), (96, 12601527.499999998)),
#  (('least', 'four'), (113, 3281.947600619931)),
#  (('jazz', 'shaw'), (114, 310.0364279398762)),
#  (('chief', 'executive', 'officer'), (55, 602.5431650720335)),
#  (('us', 'district', 'judge'), (197, 240.10815125524323)),
#  (('get', 'rid'), (287, 671.1724329889875)),
#  (('wisconsin', 'gov'), (146, 135.37767791303273)),
#  (('inner', 'circle'), (84, 1426.4537643959814)),
#  (('common', 'core'), (67, 299.2793682925262)),
#  (('harvard', 'university'), (118, 105.12390542635397)),
#  (('eastern', 'europe'), (101, 132.70244798285756)),
#  (('colin', 'powell'), (155, 6860.907871198569)),
#  (('thursday', 'afternoon'), (132, 264.3963816679967)),
#  (('august', '5', '2015'), (66, 379.986129172085)),
#  (('wasted', 'no', 'time'), (85, 4901.901201431493)),
#  (('28', 'percent'), (151, 132.05174600561023)),
#  (('religious', 'objectors'), (55, 208.14370051818196)),
#  (('republican', 'front-runner'), (82, 327.76592741596266)),
#  (('central', 'intelligence', 'agency'), (55, 603.7382920110192)),
#  (('june', '14', '2016'), (88, 349.938063063063)),
#  (('elected', 'official'), (54, 127.99731339796752)),
#  (('third-party', 'candidate'), (84, 255.98935000687095)),
#  (('trans-pacific', 'partnership', 'tpp'), (55, 105363.94230769231)),
#  (('83', 'percent'), (66, 148.74286935954038)),
#  (('reproductive', 'health'), (200, 410.1792066216512)),
#  (('immediately', 'respond'), (64, 614.0325808517451)),
#  (('dr', 'martin', 'luther', 'king', 'jr'), (60, 1565407.1428571427)),
#  (('civil', 'liberties'), (225, 4080.4846260240456)),
#  (('sign', 'up', 'for', 'pro-life', 'news', 'alerts'),
#   (57, 146.65441120237384)),
#  (('detention', 'center'), (184, 219.9786036683877)),
#  (('katie', 'couric'), (66, 3334.20051726761)),
#  (('latest', 'pro-life', 'news'), (125, 3548.5265544041454)),
#  (('parking', 'lot'), (59, 103.95302433635781)),
#  (('enter', 'god', 's', 'presence', '3', 'hear', 'god'),
#   (758, 6742.448402807471)),
#  (('democratic', 'primary'), (240, 216.38454455128604)),
#  (('pulse', 'nightclub'), (88, 8609.674551319164)),
#  (('iphone', '6s'), (53, 1751.201257191562)),
#  (('ta-nehisi', 'coates'), (55, 53714.950980392154)),
#  (('general', 'assembly'), (82, 796.0588806857911)),
#  (('see', 'an', 'error'), (758, 37615.310545454544)),
#  (('crooked', 'hillary'), (251, 749.8630857539731)),
#  (('image', 'credit'), (345, 309.6818566240009)),
#  (('sex', 'offender'), (102, 497.33808378341575)),
#  (('attorney', 'general'), (51, 109.3728789875035)),
#  (('grocery', 'store'), (67, 1619.715242152856)),
#  (('presidential', 'race'), (485, 175.34621265271312)),
#  (('lets', 'talk'), (78, 123.06008377813394)),
#  (('may', 'very', 'well'), (86, 14094.704873517221)),
#  (('june', '23'), (147, 148.3767998642023)),
#  (('san', 'bernardino'), (918, 3064244.1365979384)),
#  (('gay', 'community'), (107, 162.5311480272916)),
#  (('october', '17', '2016'), (57, 101.1172937643526)),
#  (('look', 'forward'), (311, 190.29057582217538)),
#  (('environmental', 'protection', 'agency', 'epa'), (67, 298.89616807704283)),
#  (('click', 'like', 'if', 'youre'), (167, 447962.4213836478)),
#  (('deadly', 'weapon'), (55, 163.9630890961108)),
#  (('jeremy', 'corbyn'), (64, 3108.6099290780144)),
#  (('race', 'relations'), (181, 135.0868587253405)),
#  (('60', 'minutes'), (185, 646.6498182415858)),
#  (('student', 'loans'), (147, 248.77531727931816)),
#  (('july', '19', '2016'), (141, 1163.1723007652108)),
#  (('sarah', 'palin'), (467, 5770.9896664780645)),
#  (('sign', 'up', 'for', 'free'), (64, 1357.345472562864)),
#  (('speaker', 'paul', 'ryan'), (98, 200.68480031744699)),
#  (('partial', 'birth'), (67, 289.9660197499502)),
#  (('tamir', 'rice'), (178, 25974.162962962964)),
#  (('september', '12', '2016'), (76, 491.1411411411411)),
#  (('us', 'state', 'department'), (114, 1960.3689830603232)),
#  (('karen', 'armstrong'), (80, 5117.6209602092285)),
#  (('labor', 'unions'), (139, 239.48232211614018)),
#  (('household', 'income'), (75, 135.7438288856119)),
#  (('advocacy', 'group'), (268, 169.1045627292985)),
#  (('let', 'me', 'say'), (71, 696.8742618333788)),
#  (('mark', 'kirk'), (103, 433.404912507985)),
#  (('assault', 'rifle'), (109, 380.78477763563666)),
#  (('houston', 'chronicle'), (61, 2137.169326241135)),
#  (('vice', 'president', 'joe', 'biden'), (242, 1402604.8)),
#  (('scientific', 'consensus'), (82, 238.67851580793064)),
#  (('conventional', 'wisdom'), (179, 2898.8188887567317)),
#  (('lgbt', 'rights'), (270, 139.20981543226915)),
#  (('bob', 'dylan'), (118, 1472.5964426877472)),
#  (('collective', 'bargaining'), (122, 3989.024390243903)),
#  (('post', 'has', 'been', 'updated'), (93, 15133.20754110997)),
#  (('100', 'million'), (398, 144.76374395636435)),
#  (('donald', 'trumps'), (66, 223.78315731969133)),
#  (('student', 'loan'), (89, 107.2603561790714)),
#  (('lyin', 'ted'), (126, 39491.49279210925)),
#  (('august', '24', '2016'), (98, 1049.501963413466)),
#  (('stephen', 'k', 'bannon'), (52, 32612.64880952381)),
#  (('assault', 'rifles'), (124, 813.3469680069973)),
#  (('zika', 'virus'), (287, 3866.3939954264483)),
#  (('thank', 'you', 'very', 'much'), (105, 268.74194017312016)),
#  (('conference', 'call'), (61, 428.3087085678549)),
#  (('supreme', 'court', 'justice', 'antonin', 'scalia'),
#   (110, 375.5882571364916)),
#  (('january', '4', '2016'), (69, 499.9115186615187)),
#  (('baby', 'body', 'parts'), (144, 187.4475712056184)),
#  (('ht', 'theblaze'), (128, 597.032900251467)),
#  (('gun', 'control', 'measures'), (114, 6777.047215940936)),
#  (('charter', 'school'), (262, 341.0469072612943)),
#  (('resisting', 'arrest'), (73, 366.63042023554607)),
#  (('sidney', 'blumenthal'), (109, 26178.86094914156)),
#  (('second', 'amendment', 'right'), (54, 228.440835557038)),
#  (('concealed', 'weapons'), (65, 123.68074325341168)),
#  (('jesus', 'christ'), (553, 1205.3654170821742)),
#  (('ballistic', 'missiles'), (103, 16456.025444860028)),
#  (('july', '9', '2016'), (62, 200.9213759213759)),
#  (('white', 'nationalist'), (159, 310.1031378841221)),
#  (('south', 'carolina'), (621, 230406.99477095302)),
#  (('two', 'evils'), (69, 849.7092121588089)),
#  (('president', 'xi', 'jinping'), (53, 456577.0833333333)),
#  (('state', 'department', 'emails'), (59, 899.1015425570711)),
#  (('piers', 'morgan'), (68, 8523.087892144154)),
#  (('force', 'awakens'), (98, 69062.07983193277)),
#  (('federal', 'court'), (187, 561.2301131563088)),
#  (('upstate', 'new', 'york'), (84, 730.3343056306995)),
#  (('crony', 'capitalism'), (68, 1580.5604525931149)),
#  (('sarah', 'silverman'), (57, 786.0724533715925)),
#  (('conspiracy', 'theorists'), (83, 8323.950324570693)),
#  (('stricter', 'gun'), (72, 179.20076772920746)),
#  (('long', 'history'), (282, 103.50279661230869)),
#  (('rolling', 'stone'), (231, 2038.3156876770215)),
#  (('miley', 'cyrus'), (92, 65784.69125214408)),
#  (('trump', 'does', 'nt'), (78, 168.8814691519483)),
#  (('west', 'virginia'), (106, 786.7577824503821)),
#  (('disorderly', 'conduct'), (103, 12009.223531844498)),
#  (('second', 'quarter'), (86, 102.17030170705745)),
#  (('open', 'letter'), (196, 120.67368491875844)),
#  (('studies', 'have', 'shown'), (87, 1339.5019492533368)),
#  (('daily', 'mail'), (636, 2670.5211286115436)),
#  (('alphabet', 'googl'), (58, 6301.236342725704)),
#  (('vice', 'presidential'), (104, 407.94477766287486)),
#  (('uphill', 'battle'), (55, 911.331503659348)),
#  (('paul', 'ryan'), (745, 646.559531110767)),
#  (('several', 'years'), (136, 245.39740117702203)),
#  (('general', 'public'), (191, 113.63999336278596)),
#  (('issue', 'marriage', 'licenses'), (130, 630.0058930907105)),
#  (('obama', 'administration'), (3347, 5136.842745467161)),
#  (('syrian', 'civil', 'war'), (73, 111.95386904761905)),
#  (('internal', 'revenue', 'service'), (73, 2925.960690071515)),
#  (('medicaid', 'expansion'), (183, 960.3205891888045)),
#  (('riot', 'gear'), (57, 128699.58053691276)),
#  (('executive', 'orders'), (217, 592.0421847146328)),
#  (('miles', 'away'), (192, 130.30039148366026)),
#  (('august', '10', '2016'), (93, 1583.93018018018)),
#  (('cultural', 'appropriation'), (90, 1793.399453364102)),
#  (('executive', 'actions'), (166, 105.5145349189518)),
#  (('told', 'mic'), (303, 195.5495751191777)),
#  (('site', 'wide', 'get', 'truth', 'delivered'), (57, 7646.0277113237635)),
#  (('mark', 'halperin'), (81, 747.8279103557591)),
#  (('september', '3', '2015'), (74, 259.08145170823974)),
#  (('seven', 'years', 'ago'), (71, 228.69692903995227)),
#  (('new', 'jersey', 'gov'), (194, 14657.15241138441)),
#  (('told', 'lifesitenews'), (63, 707.3793326050253)),
#  (('family', 'research', 'council'), (121, 9246.141733219243)),
#  (('matt', 'lauer'), (155, 4263.091347650171)),
#  (('could', 'end'), (86, 139.7679006466809)),
#  (('35', '50', '100'), (58, 3072.6533473536624)),
#  (('affordable', 'care', 'act'), (575, 717673.5591317365)),
#  (('gop', 'frontrunner', 'donald', 'trump'), (90, 3833.359570411573)),
#  (('37', 'percent'), (168, 306.596576905804)),
#  (('fbi', 'director', 'james', 'comey'), (389, 47860.12098021026)),
#  (('follow', 'david', 'on', 'twitter'), (134, 138958.2427536232)),
#  (('finish', 'line'), (58, 694.0179872062829)),
#  (('happy', 'birthday'), (113, 192.13148092279502)),
#  (('troy', 'newman'), (83, 6663.884896063689)),
#  (('large', 'part'), (180, 630.5241441460582)),
#  (('advertisement', 'become'), (410, 408.9631678471313)),
#  (('sen', 'tim', 'kaine'), (100, 11762.398024903394)),
#  (('nermeen', 'shaikh'), (128, 32873550.0)),
#  (('witch', 'hunt'), (92, 3337.70668948712)),
#  (('josh', 'earnest'), (179, 2369.3323756972754)),
#  (('republican', 'voters'), (107, 127.29927353925218)),
#  (('two-party', 'system'), (63, 417.209612230553)),
#  (('charlie', 'sheen'), (52, 175.15744884910484)),
#  (('gofundme', 'page'), (81, 955.0532782276204)),
#  (('middle', 'eastern'), (312, 1172.356909863954)),
#  (('follow', 'davidrutz'), (56, 758.6787445188091)),
#  (('navy', 'seals'), (53, 188.7722229878721)),
#  (('new', 'orleans'), (72, 10368.718279569892)),
#  (('mental', 'illness'), (65, 12029.255708430912)),
#  (('neil', 'degrasse', 'tyson'), (67, 90253.60949612405)),
#  (('clinton', 'camp'), (111, 223.290286222809)),
#  (('take', 'into', 'account'), (107, 137515.95112285338)),
#  (('former', 'president', 'george', 'w'), (122, 18157.166528583264)),
#  (('weekly', 'standard'), (298, 1003.4705636471862)),
#  (('north', 'korean'), (147, 2568.9702719033235)),
#  (('hot', 'sauce'), (56, 179.1171518708011)),
#  (('february', '24', '2016'), (69, 1399.752252252252)),
#  (('new', 'jersey', 'governor', 'chris'), (53, 210.046579683846)),
#  (('september', '8', '2016'), (86, 408.02494802494806)),
#  (('gun', 'violence'), (183, 1132.6022369257503)),
#  (('energy', 'efficiency'), (108, 285.89982006297794)),
#  (('donald', 'trump', 'rally'), (86, 357.68925270930964)),
#  (('walt', 'disney'), (103, 5023.058726863864)),
#  (('coal', 'industry'), (99, 566.8028953746632)),
#  (('orlando', 'sentinel'), (65, 381.9450253750488)),
#  (('robert', 'lewis', 'dear'), (64, 43214.05633802817)),
#  (('nbc', 'news'), (82, 205.74137637664066)),
#  (('florida', 'sen', 'marco', 'rubio'), (137, 338.7092012167955)),
#  (('weve', 'seen'), (511, 196.66072001407733)),
#  (('said', 'last', 'week'), (112, 5184.57493894994)),
#  (('january', '23', '2016'), (68, 324.41003289473684)),
#  (('admitting', 'privileges'), (112, 3376.6063298940376)),
#  (('source', 'micgetty', 'images'), (104, 3883.3143014647976)),
#  (('dont', 'miss', 'our', 'hottest', 'stories'), (77, 18124.35371232541)),
#  (('united', 'states', 'senate'), (106, 123023.17562149158)),
#  (('news', 'station'), (128, 185.82536189441308)),
#  (('carbon', 'dioxide', 'emissions'), (90, 868.1204198851258)),
#  (('terminally', 'ill'), (56, 1134.3530020703934)),
#  (('eric', 'bolling'), (87, 1795.6369136196142)),
#  (('july', '21', '2016'), (85, 271.4201043148411)),
#  (('sen', 'lindsey', 'graham'), (86, 366.33897461423595)),
#  (('silent', 'majority'), (64, 764.3589564732142)),
#  (('fully', 'intact', 'aborted', 'babies'), (63, 12094.757174392937)),
#  (('91', 'percent'), (71, 199.1036587370669)),
#  (('hollywood', 'reporter'), (161, 1913.104686497301)),
#  (('jesse', 'jackson'), (85, 375.0603871820749)),
#  (('presumptive', 'democratic', 'nominee'), (59, 2323.7664938737043)),
#  (('north', 'carolina'), (2235, 77779.62592989637)),
#  (('determine', 'whether'), (284, 120.0242179463511)),
#  (('chairwoman', 'debbie', 'wasserman', 'schultz'), (52, 18263.083333333332)),
#  (('whole', 'foods'), (163, 196.9014863693292)),
#  (('latest', 'video', 'at', 'videofoxnewscom'), (275, 362256.2812224508)),
#  (('follow', 'pam', 'key', 'on', 'twitter', 'pamkeynen'),
#   (64, 18726.79443359375)),
#  (('pacific', 'ocean'), (82, 297.4771580063627)),
#  (('melissa', 'harris-perry'), (52, 539.6892237982663)),
#  (('whoopi', 'goldberg'), (68, 13712.548665183538)),
#  (('financial', 'institutions'), (153, 126.65731692536966)),
#  (('search', 'engine'), (69, 285.3465974814839)),
#  (('beyond', 'with', 'curated'), (1327, 54660837.6953125)),
#  (('many', 'cases'), (240, 344.4337003778529)),
#  (('council', 'on', 'american-islamic', 'relations'),
#   (95, 173627.90492957746)),
#  (('secret', 'service', 'agent'), (70, 15200.235816340688)),
#  (('margaret', 'thatcher'), (52, 2067.1288436144123)),
#  (('tampabaycom', 'or', '727'), (116, 436725.90579710144)),
#  (('october', '16', '2016'), (69, 280.50867667268466)),
#  (('baton', 'rouge'), (155, 7990098.958333333)),
#  (('all-star', 'game'), (70, 428.70249017038003)),
#  (('intact', 'fetal'), (61, 384.87636581923607)),
#  (('86', 'percent'), (73, 183.9550430417221)),
#  (('clinton', 'foundation'), (1203, 1880.8833127148378)),
#  (('terrorist', 'organization'), (126, 207.022743261417)),
#  (('west', 'coast'), (114, 418.43419155903047)),
#  (('business', 'dealings'), (76, 126.9750599434882)),
#  (('pete', 'souza'), (54, 8696.70634920635)),
#  (('ellen', 'degeneres'), (79, 19910.880325814538)),
#  (('josh', 'voorhees'), (92, 121368.59177215188)),
#  (('walked', 'away'), (165, 146.32946265277093)),
#  (('hottest', 'most', 'important'), (74, 529.7165991902834)),
#  (('movie', 'theater'), (111, 253.34705760175137)),
#  (('congress', 'must', 'de-fund'), (90, 95285.65217391304)),
#  (('last', 'two', 'years'), (100, 172.19144028058884)),
#  (('photo', 'credit', 'splash'), (51, 1215.9176653351087)),
#  (('former', 'new', 'york'), (126, 1397309.7315436243)),
#  (('hes', 'talking'), (85, 197.77513464342954)),
#  (('state', 'legislatures'), (207, 222.4727221142004)),
#  (('medical', 'marijuana'), (206, 223.06929220169118)),
#  (('red', 'carpet'), (77, 3686.110211302701)),
#  (('eric', 'holder'), (115, 1077.1454129161827)),
#  (('republican', 'candidates'), (61, 176.66439490539213)),
#  (('detroit', 'free', 'press'), (69, 883.0828710065998)),
#  (('drug', 'addiction'), (85, 169.39989487725376)),
#  (('december', '29', '2015'), (62, 2137.421976592978)),
#  (('green', 'cards'), (112, 317.9208579632451)),
#  (('mitt', 'romney'), (68, 30288.897420147423)),
#  (('foreseeable', 'future'), (86, 32355.8562992126)),
#  (('poll', 'numbers'), (78, 4917.929730076297)),
#  (('regular', 'basis'), (110, 789.6013028095434)),
#  (('exchange', 'commission'), (72, 7683.836935041754)),
#  (('presidential', 'nominee'), (279, 305.7236166247721)),
#  (('executive', 'amnesty'), (74, 115.43753193327329)),
#  (('mentally', 'ill'), (72, 2772.862893949851)),
#  (('2016', 'presidential', 'election'), (134, 433.06769421860884)),
#  (('syrian', 'president', 'bashar'), (75, 360455.59210526315)),
#  (('human', 'rights', 'watch'), (136, 127727.71753862835)),
#  (('august', '21'), (115, 103.68015209794079)),
#  (('army', 'corps'), (60, 1055.1612903225807)),
#  (('coal', 'miners'), (81, 737.565898037172)),
#  (('april', '14', '2016'), (106, 959.4385082757177)),
#  (('new', 'mexico'), (66, 117.64386958937348)),
#  (('mother', 'jones'), (276, 137.79478739096348)),
#  (('four', 'years', 'ago'), (251, 179.72518673231184)),
#  (('presidential', 'elections'), (208, 218.55765404844234)),
#  (('purpose', 'turn'), (758, 14768.891537090904)),
#  (('blac', 'chyna'), (62, 38652.02821869488)),
#  (('portland', 'oregon'), (60, 135.51632451150135)),
#  (('developing', 'countries'), (85, 739.5072904736011)),
#  (('daily', 'on', 'defense', 'newsletter'), (220, 1704.394030888596)),
#  (('registered', 'voters'), (281, 149.26394467276918)),
#  (('radio', 'station'), (117, 207.49480115513558)),
#  (('andrew', 'cuomo'), (102, 1101.2063234384664)),
#  (('van', 'dyke'), (101, 18363.904771293375)),
#  (('kim', 'kardashian', 'west', 'kimkardashian'), (59, 33544.4387755102)),
#  (('featured', 'image', 'via', 'screen', 'capture', 'related'),
#   (60, 4299.219240426867)),
#  (('work', 'ethic'), (98, 276.9467954368107)),
#  (('santa', 'clara'), (74, 8455.131172839505)),
#  (('bill', 'oreilly'), (335, 259.86628439622655)),
#  (('super', 'bowl'), (160, 32182.503871415607)),
#  (('american', 'medical', 'association'), (63, 190.1967630298596)),
#  (('tampa', 'bay'), (83, 3173.9024154758977)),
#  (('collateral', 'damage'), (66, 1695.080826049965)),
#  (('katy', 'tur'), (53, 2808.744873547505)),
#  (('really', 'paid', 'attention'), (57, 3676.7783529862913)),
#  (('ivy', 'league'), (89, 2458.1606768975907)),
#  (('mass', 'shooting'), (104, 242.98281490606715)),
#  (('great', 'deal'), (431, 194.8443523926012)),
#  (('long', 'overdue'), (102, 572.4207282035209)),
#  (('ca', 'nt', 'even'), (78, 5602.172801635992)),
#  (('panama', 'papers'), (82, 1840.225035161744)),
#  (('talking', 'points'), (501, 460.21363844197543)),
#  (('carbon', 'pollution'), (133, 857.8746533607501)),
#  (('wreak', 'havoc'), (70, 36356.502986065025)),
#  (('khloe', 'kardashian'), (66, 2576.801881246326)),
#  (('comments', 'section'), (225, 3679.4591975746876)),
#  (('eric', 'garner'), (61, 9881.648630923102)),
#  (('gop', 'presidential'), (169, 113.20383866381731)),
#  (('right-wing', 'conspiracy'), (74, 127.40179939968336)),
#  (('illegal', 'immigrant'), (133, 179.35808845424947)),
#  (('hillary', 'clinton'), (255, 476.90060993603424)),
#  (('oreilly', 'factor'), (162, 215994.2273847237)),
#  (('koch', 'industries'), (71, 602.2435461245341)),
#  (('organ', 'harvesting'), (72, 2226.218048167849)),
#  (('inner', 'cities'), (131, 578.9016151586461)),
#  (('december', '16', '2015'), (64, 664.9757260511486)),
#  (('background', 'check'), (136, 4327.903868763318)),
#  (('30', 'percent'), (166, 214.3947745525594)),
#  (('pleaded', 'guilty'), (163, 24365.15249901613)),
#  (('joni', 'ernst'), (57, 36877.379807692305)),
#  (('hillsborough', 'county'), (141, 779.9974577994712)),
#  (('dana', 'loesch'), (67, 6577.805437853108)),
#  (('naomi', 'klein'), (102, 9910.74199046857)),
#  (('first', 'responders'), (198, 754.3850068379089)),
#  (('barack', 'obama'), (100, 10816.798941798943)),
#  (('break', 'transcript', 'rush'), (249, 417901.90686086623)),
#  (('republican', 'national', 'committee'), (307, 2741.062341833755)),
#  (('white', 'house', 'photo'), (52, 1109.543337383556)),
#  (('lgbtq', 'community'), (116, 1308.177532902591)),
#  (('bruce', 'jenner'), (101, 968.2091995841995)),
#  (('morning', 'news', 'blast'), (196, 407707.9765545362)),
#  (('planned', 'parenthood', 'federation'), (86, 342.4060620264042)),
#  (('tap', 'water'), (84, 176.20404974257548)),
#  (('mexican', 'heritage'), (78, 160.06007603928)),
#  (('georgetown', 'university'), (103, 356.9507750365699)),
#  (('something', 'else'), (466, 187.39089233515517)),
#  (('super', 'pacs'), (265, 24321.61697602874)),
#  (('twitter', 'warnerthuston', 'or', 'email'), (81, 456.1393367118115)),
#  (('bush', 'administration'), (277, 684.4736356932154)),
#  (('wake-up', 'call'), (72, 4903.439508583516)),
#  (('usa', 'today'), (80, 2088.137584958394)),
#  (('impeach', 'obama', 'fax'), (111, 3983.058134407513)),
#  (('temporary', 'ban'), (68, 113.81153017912906)),
#  (('rosario', 'dawson'), (54, 18635.799319727892)),
#  (('platte', 'river', 'networks'), (52, 164.9185780506893)),
#  (('eligible', 'news', 'publisher'), (620, 520497875.0)),
#  (('health', 'care', 'law'), (93, 41037.06235847413)),
#  (('republican', 'presidential', 'primary'), (113, 191.4496738660188)),
#  (('treasury', 'secretary'), (94, 208.60445898178077)),
#  (('wrong', 'direction'), (81, 157.1257724615157)),
#  (('august', '18', '2016'), (78, 377.2918880100736)),
#  (('pat', 'buchanan'), (60, 852.0083662488726)),
#  (('campaign', 'manager', 'corey', 'lewandowski'), (139, 1159.9221801452923)),
#  (('second-degree', 'murder'), (66, 392.13956609259674)),
#  (('next', 'five', 'years'), (72, 610.3229938834205)),
#  (('franklin', 'roosevelt'), (64, 382.6370320855615)),
#  (('lives', 'matter'), (247, 5773.7064169635505)),
#  (('hillary', 'clinton', 'would'), (123, 184.55986313569684)),
#  (('speaks', 'volumes'), (66, 902.3262516469038)),
#  (('april', '29', '2016'), (122, 1352.6725462226366)),
#  (('foreign', 'minister'), (239, 470.0519045984901)),
#  (('muslim', 'brotherhood'), (347, 13530.684624531235)),
#  (('republican', 'presidential', 'hopeful'), (100, 1298.692756234)),
#  (('democratic', 'front-runner', 'hillary', 'clinton'),
#   (80, 157.66494038923256)),
#  (('security', 'clearance'), (85, 412.2246549252025)),
#  (('jerry', 'brown'), (140, 515.2109519480927)),
#  (('recent', 'reports'), (111, 380.93886206550684)),
#  (('trade', 'agreements'), (201, 628.7181771894094)),
#  (('orlando', 'shooter'), (89, 136.12912442854304)),
#  (('town', 'hall'), (110, 2052.8006744098916)),
#  (('democratic', 'partys'), (122, 427.9407170194486)),
#  (('search', 'warrant'), (108, 504.1888858038158)),
#  (('press', 'conferences'), (75, 164.80368871739523)),
#  (('newt', 'gingrich'), (271, 26993.99021312645)),
#  (('presidential', 'election'), (109, 266.53565527272247)),
#  (('same-sex', 'marriage'), (133, 3370.9963232296277)),
#  (('double', 'standard'), (74, 556.37489898071)),
#  (('state', 'attorney', 'general'), (70, 1011.2635892135329)),
#  (('et', 'al'), (92, 512.4139351563196)),
#  (('keith', 'ellison'), (74, 3991.930783242259)),
#  (('republican', 'presidential', 'nomination'), (146, 1253.8661784478074)),
#  (('blast', 'all', '535'), (125, 6848656.25)),
#  (('democratic', 'presidential', 'candidates'), (104, 169.6816124980644)),
#  (('nazi', 'germany'), (113, 374.93458212943455)),
#  (('people', 'with', 'disabilities'), (66, 461.3637320533872)),
#  (('remain', 'silent'), (89, 112.09400442756422)),
#  (('san', 'francisco', '49ers', 'quarterback'), (52, 749.10103910309)),
#  (('sexually', 'transmitted'), (90, 3277.114018691588)),
#  (('wildlife', 'refuge'), (58, 199.12954591917864)),
#  (('competitive', 'enterprise', 'institute'), (53, 9136.617565314064)),
#  (('decades', 'ago'), (178, 280.71184405395667)),
#  (('early', 'stages'), (74, 103.16021527309243)),
#  (('grocery', 'stores'), (75, 971.8541577976443)),
#  (('financial', 'crisis'), (303, 168.61768203119536)),
#  (('kentucky', 'clerk'), (87, 485.79013898873706)),
#  (('oral', 'arguments'), (100, 1333.837678082792)),
#  (('trevor', 'noah'), (54, 599.625160743112)),
#  (('past', 'few', 'days'), (76, 649.1321485532012)),
#  (('set', 'aside'), (169, 164.37689432807102)),
#  (('varying', 'degrees'), (52, 182.95099757909674)),
#  (('real', 'estate'), (131, 578.4903546470931)),
#  (('october', '5', '2016'), (93, 736.7117117117117)),
#  (('aborted', 'fetal'), (59, 306.6905810351905)),
#  (('past', 'few', 'years'), (209, 1443.590420243264)),
#  (('house', 'minority', 'leader', 'nancy', 'pelosi'), (56, 271.8979520942235)),
#  (('tuesday', 'evening'), (140, 176.20804991396915)),
#  (('european', 'union'), (59, 242.41600790513831)),
#  (('gennifer', 'flowers'), (54, 16602.803030303032)),
#  (('found', 'no', 'evidence'), (124, 682.1049435056764)),
#  (('gun-free', 'zone'), (52, 596.832788671024)),
#  (('christian', 'leaders'), (760, 154.9492822729419)),
#  (('el', 'paso'), (85, 53865.8356741573)),
#  (('theres', 'no', 'question'), (83, 131.045975112035)),
#  (('guccifer', '20'), (66, 447.27515778624746)),
#  (('surveillance', 'footage'), (79, 127.58834247151745)),
#  (('last', 'few', 'weeks'), (75, 1427.9933798999166)),
#  (('supreme', 'court', 'decision'), (207, 56002.032877604164)),
#  (('de', 'facto'), (63, 2094883.088235294)),
#  (('st', 'johns'), (55, 324.5962486373762)),
#  (('two', 'dozen'), (67, 1094.6903096903097)),
#  (('chris', 'cuomo'), (116, 857.6902003757045)),
#  (('ronda', 'rousey'), (65, 27051.966754443714)),
#  (('social', 'media'), (129, 163.70637623999042)),
#  (('emanuel', 'ame', 'church'), (74, 10565.177567089828)),
#  (('64', 'percent'), (101, 223.2848807243559)),
#  (('aborted', 'babies'), (72, 18916.564657878218)),
#  (('gas', 'station'), (193, 455.0588944227447)),
#  (('saddam', 'hussein'), (185, 55907.39795918367)),
#  (('city', 'council'), (193, 109.92136240901341)),
#  (('trans', 'pacific'), (72, 179.06978644382542)),
#  (('monmouth', 'university'), (81, 315.9209317292383)),
#  (('voter', 'id'), (112, 157.38260241883773)),
#  (('kevin', 'mccarthy'), (125, 658.3083682444069)),
#  (('justice', 'clarence', 'thomas'), (72, 286.37492159732386)),
#  (('nt', 'want'), (196, 1072.5071864893998)),
#  (('stock', 'market'), (172, 377.055892569657)),
#  (('blast', 'all', '535', 'members'), (125, 10272984.375)),
#  (('pamela', 'geller'), (128, 27882.569974554706)),
#  (('supreme', 'court'), (87, 10284.102323457791)),
#  (('august', '31', '2016'), (87, 1048.397435897436)),
#  (('high', 'alert'), (54, 888.8586956521739)),
#  (('midterm', 'elections'), (60, 704.0148283305921)),
#  (('good', 'news'), (284, 139.9894030840792)),
#  (('air', 'force', 'one'), (78, 3321.6390603009636)),
#  (('came', 'under', 'fire'), (94, 194.6863426318501)),
#  (('islamic', 'terrorism'), (245, 130.43979692523624)),
#  (('iowa', 'caucus'), (186, 235.76885764712657)),
#  (('womens', 'health'), (369, 203.36522490489892)),
#  (('mandatory', 'minimum'), (76, 460.1565705019495)),
#  (('vermont', 'senator'), (195, 2926.873220081715)),
#  (('james', 'cone'), (116, 6119.839053614947)),
#  (('jada', 'pinkett', 'smith'), (80, 9111.799434558456)),
#  (('bryan', 'pagliano'), (84, 5144.8146818382675)),
#  (('social', 'media', 'accounts'), (79, 4110.965717981889)),
#  (('persian', 'gulf'), (97, 75383.33577283373)),
#  (('religious', 'freedom', 'restoration', 'act'), (80, 85341.5109034268)),
#  (('santa', 'monica'), (66, 1610.5011757789537)),
#  (('nearly', 'two', 'years'), (74, 239.69048487057964)),
#  (('amicus', 'brief'), (75, 2415.538753196367)),
#  (('sheriffs', 'deputy'), (61, 263.7406843374337)),
#  (('presumptive', 'republican', 'nominee'), (153, 5287.843884110118)),
#  (('election', 'cycle'), (234, 182.90678400311194)),
#  (('60', 'percent'), (215, 700.7840406630615)),
#  (('emphasis', 'added'), (190, 687.6900663439126)),
#  (('american', 'thinker'), (88, 228.340619351782)),
#  (('like', 'ted', 'cruz'), (67, 1457.3889062744483)),
#  (('republican', 'primary', 'voters'), (128, 427.62127519061823)),
#  (('saul', 'alinsky'), (57, 6547.025435302151)),
#  (('somewhere', 'else'), (110, 520.3190586834991)),
#  (('congressional', 'district'), (206, 211.79122695902208)),
#  (('twitter', 'users'), (159, 111.37135401339657)),
#  (('relations', 'cair'), (60, 162.4945132512397)),
#  (('saturday', 'night'), (135, 101.78782734551355)),
#  (('advocacy', 'groups'), (122, 109.44415729691804)),
#  (('getting', 'rid'), (128, 713.730534901898)),
#  (('less', 'likely'), (92, 224.44098197565543)),
#  (('donald', 'trump', 'said'), (254, 243.16406351980032)),
#  (('keystone', 'xl', 'pipeline'), (118, 3763302.02020202)),
#  (('republican', 'convention'), (192, 130.9891354125277)),
#  (('august', '27'), (109, 146.7181974067377)),
#  (('97', 'percent'), (88, 391.3863630809489)),
#  (('david', 'axelrod'), (71, 551.6542566453147)),
#  (('new', 'jersey', 'governor', 'chris', 'christie'),
#   (52, 309.89394796380094)),
#  (('press', 'release'), (417, 4196.044438184075)),
#  (('new', 'york', 'times', 'published'), (64, 2526.0974806520667)),
#  (('hot', 'bpr', 'news', 'stories'), (256, 9689.719694368132)),
#  (('trillion', 'dollars'), (102, 178.39196577728688)),
#  (('new', 'york', 'university'), (54, 271.42874835897055)),
#  (('scalias', 'death'), (85, 110.1697020985184)),
#  (('south', 'sudan'), (99, 586.813825136612)),
#  (('radio', 'show'), (76, 382.3302620313536)),
#  (('special', 'fight', 'back'), (125, 161.40595080276918)),
#  (('looked', 'like'), (111, 122.54028952285414)),
#  (('democratic', 'party'), (111, 298.895177460234)),
#  (('february', '10', '2016'), (91, 1678.0655655655655)),
#  (('noam', 'chomsky'), (119, 153864.8046398046)),
#  (('chuck', 'todd'), (279, 8052.1751338099575)),
#  (('nt', 'know'), (104, 7916.46241939368)),
#  (('democratic', 'presidential', 'nominee'), (101, 212.27722016345544)),
#  (('democratic', 'nomination'), (273, 427.8434617843919)),
#  (('88', 'percent'), (66, 124.49131457265878)),
#  (('watchdog', 'group'), (150, 198.12027247605639)),
#  (('national', 'review'), (67, 379.8850047311407)),
#  (('religious', 'minorities'), (121, 109.58754483116493)),
#  (('darren', 'wilson'), (58, 403.4925895240725)),
#  (('talk', 'radio'), (233, 196.0922252768906)),
#  (('facebook', 'page'), (256, 8998.744658119658)),
#  (('cancer', 'screenings'), (63, 408.3943980963849)),
#  (('college', 'graduates'), (75, 151.60715748322588)),
#  (('hydraulic', 'fracturing'), (68, 224137.8409090909)),
#  (('holly', 'odonnell'), (59, 1222.2468024985128)),
#  (('second', 'presidential', 'debate'), (78, 188.15312762925188)),
#  (('president', 'ronald', 'reagan'), (95, 14793.689247569902)),
#  (('rosa', 'parks'), (93, 5554.7538490557135)),
#  (('radio', 'stations'), (66, 118.77510815560316)),
#  (('take', 'advantage'), (163, 114.03557541944717)),
#  (('pepper', 'spray'), (134, 19121.263866384146)),
#  (('nt', 'make'), (77, 2302.8218839023025)),
#  (('february', '7', '2016'), (90, 699.4335136515231)),
#  (('rick', 'santorum'), (299, 6801.028565019069)),
#  (('montgomery', 'county'), (99, 306.63616874009165)),
#  (('constitutionally', 'protected'), (73, 867.4018612462916)),
#  (('clean', 'power', 'plan'), (195, 3009258.049242425)),
#  (('prison', 'sentence'), (125, 107.29861894466379)),
#  (('vice', 'president', 'biden'), (63, 63312.02222222222)),
#  (('orlando', 'nightclub'), (69, 314.24199751261807)),
#  (('abc', 'news'), (98, 516.3317234067617)),
#  (('november', '11', '2015'), (68, 582.9332663435395)),
#  (('drivers', 'licenses'), (70, 294.39175756273175)),
#  (('77', 'percent'), (66, 119.92880566161897)),
#  (('holy', 'communion'), (54, 246.1774352983465)),
#  (('joint', 'chiefs'), (53, 430.37219836615)),
#  (('government', 'accountability', 'office'), (54, 118.72122124833422)),
#  (('world', 'trade', 'center'), (245, 2695.994768955911)),
#  (('religious', 'beliefs'), (105, 1958.3484971567832)),
#  (('former', 'house', 'speaker'), (116, 146.26588417455685)),
#  (('take', 'for', 'example'), (63, 274.2901676717731)),
#  (('david', 'daleiden'), (164, 629.3198662765392)),
#  (('please', 'share', 'this', 'story'), (197, 110.89627973772696)),
#  (('26', 'percent'), (140, 113.32322830492689)),
#  (('ny', 'daily', 'news'), (112, 3238.968982713083)),
#  (('committee', 'chairman'), (220, 138.45491840319275)),
#  (('audio', 'clip'), (87, 265.87235334543436)),
#  (('marriage', 'license'), (155, 186.24414716368713)),
#  (('viewer', 'supported', 'news'), (74, 913154.1666666666)),
#  (('ben', 'sasse'), (82, 2396.664570631818)),
#  (('wndcom', 'americas', 'independent', 'news', 'network'),
#   (63, 5857.8851056830335)),
#  (('ben', 'jerrys'), (58, 2958.38282937365)),
#  (('michelle', 'fields'), (99, 356.06501596850865)),
#  (('democratic', 'presidential'), (322, 163.32394188377543)),
#  (('voter', 'rolls'), (63, 221.63384344427573)),
#  (('warren', 'buffett'), (56, 365.9936539746159)),
#  (('khizr', 'khan'), (104, 9754.762611275964)),
#  (('august', '23', '2016'), (71, 336.3249118683901)),
#  (('malcolm', 'x'), (107, 3200.7002521215104)),
#  (('assault', 'weapons'), (192, 176.81374416156535)),
#  (('marsha', 'blackburn'), (60, 14848.035230352303)),
#  (('elon', 'musk'), (107, 80655.66244834711)),
#  (('fossil', 'fuel', 'industry'), (213, 363.54164631306764)),
#  (('read', 'page', '1'), (101, 5390.146122685184)),
#  (('winston', 'churchill'), (57, 6460.996462264151)),
#  (('president', 'obamas'), (64, 219.68172549289156)),
#  (('150', 'billion'), (86, 128.89237844863584)),
#  (('claimed', 'responsibility'), (126, 223.32399058645848)),
#  (('discrimination', 'based'), (100, 290.43419950595296)),
#  (('may', '26', '2016'), (109, 1317.151242151242)),
#  (('great', 'depression'), (120, 439.565883636597)),
#  (('no-fly', 'list'), (98, 11429.308996088657)),
#  (('911', 'attacks'), (162, 440.20846858803066)),
#  (('first', 'amendment'), (64, 104.81109258854394)),
#  (('reporter', 'michelle', 'fields'), (64, 9512.022569444443)),
#  (('5', 'percent'), (351, 125.48826016111195)),
#  (('abortion', 'providers'), (236, 303.228685501273)),
#  (('brookings', 'institution'), (64, 1435.347118263473)),
#  (('1', 'site', 'wide', 'blogads', 'premium', 'right'), (80, 25682.4609375)),
#  (('cbs', 'news'), (506, 235.9554776715451)),
#  (('president', 'bill', 'clinton'), (153, 1645.7546660834062)),
#  (('think', 'tank'), (245, 335.0202741772425)),
#  (('special', 'donate', 'today'), (96, 298614.3957345972)),
#  (('active', 'tb'), (70, 495.57916350085026)),
#  (('new', 'york', 'times', 'magazine'), (55, 902.1776716614523)),
#  (('shares',
#    'shares',
#    'facebooktwitter',
#    'googlepinterestdigglinkedin',
#    'reddit',
#    'stumbleupon',
#    'printdeliciouspockettumblr'),
#   (580, 8632.075653983353)),
#  (('football', 'player'), (99, 303.4756715145788)),
#  (('cnns', 'anderson', 'cooper'), (59, 302.3392664443027)),
#  (('june', '27', '2016'), (72, 284.0353134403623)),
#  (('ben', 'carson'), (125, 4780.077647879952)),
#  (('david', 'bowie'), (60, 175.12833544295705)),
#  (('rick', 'snyder'), (83, 610.712620965699)),
#  (('hillary', 'clintons', 'private', 'email'), (60, 192.63230247799058)),
#  (('county', 'sheriff'), (217, 259.2589950623567)),
#  (('first', 'lady', 'michelle', 'obama'), (141, 2642.671043007219)),
#  (('san', 'jose'), (98, 23273.30973451327)),
#  (('kamala', 'harris'), (54, 2558.1533792459436)),
#  (('peyton', 'manning'), (56, 5384.692874692874)),
#  (('martial', 'law'), (159, 1115.1830463848223)),
#  (('state', 'department', 'official'), (99, 753.0935997486578)),
#  (('united', 'methodist', 'church'), (77, 1122.474960163897)),
#  (('solitary', 'confinement'), (85, 119107.06521739133)),
#  (('jason', 'van', 'dyke'), (55, 856082.03125)),
#  (('lifenewscom', 'note'), (85, 377.58458924204416)),
#  (('republican', 'partys'), (162, 395.16940442489044)),
#  (('executive', 'branch'), (145, 3231.5411813643927)),
#  (('hb', '2'), (146, 653.3873291925466)),
#  (('jorge', 'ramos'), (98, 15325.664335664336)),
#  (('laquan', 'mcdonald'), (132, 51759.429723502304)),
#  (('unconditional', 'relationship'), (55, 2484.0972977874503)),
#  (('gold', 'star'), (149, 205.07191515135017)),
#  (('presumptive', 'nominee'), (131, 3734.624722297024)),
#  (('entirely', 'different'), (80, 210.51763687291793)),
#  (('harms', 'way'), (58, 873.170245826527)),
#  (('south', 'dakota'), (235, 7949.812745098039)),
#  (('holy', 'spirit'), (1014, 8246.896610950198)),
#  (('committed', 'suicide'), (137, 150.73182173498932)),
#  (('july', '14', '2015'), (80, 319.0182054616385)),
#  (('hedge', 'fund', 'managers'), (56, 585.2510236781201)),
#  (('chemical', 'weapons'), (110, 210.85331530551505)),
#  (('patrol', 'car'), (77, 118.7803713779171)),
#  (('conservative', 'movement'), (183, 130.46003058581394)),
#  (('rep', 'trey', 'gowdy'), (59, 24508.113817097415)),
#  (('breaking', 'news'), (57, 163.1464820486643)),
#  (('al', 'gore'), (217, 5001.861251421324)),
#  (('responsive', 'politics'), (54, 1361.392719592496)),
#  (('rooftop', 'solar'), (56, 378.94145312445966)),
#  (('several', 'years', 'ago'), (98, 843.5874899759423)),
#  (('email', 'scandal'), (58, 145.96551287772323)),
#  (('christina', 'cauterucci'), (79, 219459.70303867405)),
#  (('centered', 'around'), (81, 191.78907080130668)),
#  (('district', 'attorney'), (288, 268.4840104915932)),
#  (('enter', 'god', 's', 'presence'), (759, 121392.43203125)),
#  (('jonathan', 'haidt'), (79, 27889.911356854485)),
#  (('george', 'zimmerman'), (129, 1557.4817294994368)),
#  (('columbus', 'ohio'), (87, 227.57097552761564)),
#  (('american', 'foreign', 'policy'), (60, 6789.250309789343)),
#  (('cleveland', 'cavaliers'), (56, 907.707919151756)),
#  (('wide', 'right', 'internal', 'skyscraper', 'site', 'wide'),
#   (80, 25682.4609375)),
#  (('original',
#    'content',
#    'please',
#    'contact',
#    'licensing',
#    'dailycallernewsfoundationorg'),
#   (64, 1933.0884576612902)),
#  (('wells', 'fargo'), (251, 57615.56581563252)),
#  (('steve', 'doocy'), (107, 2820.3114275909406)),
#  (('birth', 'certificate'), (355, 10133.237068704142)),
#  (('super', 'tuesday'), (345, 785.092305061842)),
#  (('washington', 'post', 'reporter'), (53, 307.01710966247646)),
#  (('mad', 'max'), (61, 329.3630863900669)),
#  (('slave', 'trade'), (93, 147.74474789915968)),
#  (('browser', 'does', 'not', 'support', 'iframes'), (145, 23461.70272706784)),
#  (('unborn', 'children'), (78, 306.2318348770361)),
#  (('joint', 'comprehensive', 'plan'), (58, 1683.2334869431643)),
#  (('begin', 'transcript', 'rush'), (151, 230379.4442131557)),
#  (('sexually', 'abused'), (72, 532.6278694681956)),
#  (('thursday', 'evening'), (110, 138.7034505455558)),
#  (('urban', 'development'), (78, 1220.794340463458)),
#  (('gun', 'control'), (99, 499.04143570411514)),
#  (('pj', 'media'), (58, 126.7404203148313)),
#  (('important', 'thing'), (135, 276.034368813495)),
#  (('aborted', 'baby', 'parts'), (73, 805.7242647058823)),
#  (('new', 'york', 'city', 'mayor', 'rudy', 'giuliani'),
#   (58, 649.1040488108284)),
#  (('deep', 'south'), (60, 117.19625668449198)),
#  (('life', 'expectancy'), (89, 1859.0401513833306)),
#  (('reassignment', 'surgery'), (57, 1589.5422330901856)),
#  (('four', 'years'), (102, 324.58086492891)),
#  (('new', 'york'), (90, 1628.572490153823)),
#  (('gabriel', 'sherman'), (55, 519.7826540680024)),
#  (('loretta', 'lynch'), (126, 11108.398025877017)),
#  (('daily', 'basis'), (199, 4937.759783463376)),
#  (('concert', 'hall'), (78, 270.021297567501)),
#  (('cold', 'war'), (265, 868.7803675524821)),
#  (('baptist', 'church'), (217, 991.8164991924382)),
#  (('high', 'court'), (186, 217.26057081743534)),
#  (('october', '19', '2016'), (60, 165.11937338766063)),
#  (('rikers', 'island'), (57, 388.14365954862876)),
#  (('45', 'minutes'), (94, 247.00172951528486)),
#  (('past', '15', 'years'), (67, 1697.8076011666058)),
#  (('july', '15', '2016'), (90, 434.1633979159238)),
#  (('dylann', 'roof'), (200, 18613.00788150564)),
#  (('sen', 'bernie', 'sanders'), (400, 33782.98803798249)),
#  (('working', 'class'), (120, 1199.3168869181266)),
#  (('make', 'ends', 'meet'), (60, 222.95617319117767)),
#  (('wall', 'street'), (101, 144.4183138381007)),
#  (('hateful', 'rhetoric'), (73, 107.35238493602658)),
#  (('click', 'like'), (209, 3109.0481552330853)),
#  (('jill', 'stein'), (215, 8967.14402618658)),
#  (('rural', 'areas'), (103, 195.00677258356097)),
#  (('first-degree', 'murder'), (91, 1314.044603685288)),
#  (('extreme', 'weather'), (82, 127.89684542862895)),
#  (('universal', 'background', 'checks'), (77, 50748.190394511155)),
#  (('uk', 'daily', 'mail'), (67, 108.32045350935952)),
#  (('among', 'likely', 'voters'), (60, 143.25934506128937)),
#  (('twitter', 'account'), (74, 761.8612250573593)),
#  (('went', 'viral'), (312, 444.05622322243363)),
#  (('assistant', 'professor'), (63, 279.4492506277464)),
#  (('republican', 'presidential'), (156, 167.8550495010587)),
#  ...]

# %%
docs = SentenceStream(sql_url, "").sql_engine.execute("SELECT * FROM articles WHERE article_text like '%%selling%%aborted%%baby%%parts%%'").fetchall()

# %%
for d in docs:
    print d.base_url, d.date, d.title, len(d.article_text), d.url
# Out:
# teaparty.org 2016-10-18T22:24:03+0000 Michelle Obama Recruited to Run for Senate, Chicago Mayor 2423 http://www.teaparty.org/michelle-obama-recruited-run-senate-chicago-mayor-193024/?utm_source=rss&utm_medium=rss&utm_campaign=michelle-obama-recruited-run-senate-chicago-mayor
# teaparty.org 2016-10-18T19:14:01+0000 Americans In Philippines Jittery As Duterte Rails Against United States 4787 http://www.teaparty.org/americans-philippines-jittery-duterte-rails-united-states-192960/?utm_source=rss&utm_medium=rss&utm_campaign=americans-philippines-jittery-duterte-rails-united-states
# teaparty.org 2016-10-18T11:35:01+0000 1% Russians Approve of Obama, Global Disapproval at 8 Year High 1721 http://www.teaparty.org/1-russians-approve-obama-global-disapproval-8-year-high-192880/?utm_source=rss&utm_medium=rss&utm_campaign=1-russians-approve-obama-global-disapproval-8-year-high
# teaparty.org 2016-10-18T11:34:01+0000 Obama Adopts a Grand Design to Shape His Legacy 8265 http://www.teaparty.org/obama-adopts-grand-design-shape-legacy-192877/?utm_source=rss&utm_medium=rss&utm_campaign=obama-adopts-grand-design-shape-legacy
# teaparty.org 2016-10-18T08:53:03+0000 POLL: Millenials Clueless To Dark History of Communism... 1898 http://www.teaparty.org/poll-millenials-clueless-dark-history-communism-192833/?utm_source=rss&utm_medium=rss&utm_campaign=poll-millenials-clueless-dark-history-communism
# teaparty.org 2016-10-17T23:03:01+0000 WikiLeaks Exposes a Corporate Media as Out-Of-Touch As Politicians 6911 http://www.teaparty.org/wikileaks-exposes-corporate-media-touch-politicians-192701/?utm_source=rss&utm_medium=rss&utm_campaign=wikileaks-exposes-corporate-media-touch-politicians
# teaparty.org 2016-10-17T19:17:01+0000 Obama, Holder to Lead Post-Trump Redistricting Campaign 7230 http://www.teaparty.org/obama-holder-lead-post-trump-redistricting-campaign-192641/?utm_source=rss&utm_medium=rss&utm_campaign=obama-holder-lead-post-trump-redistricting-campaign
# teaparty.org 2016-10-16T23:33:01+0000 Rigged Poll? WSJ/NBC Poll with 11 Point Clinton Lead Includes 14 Percent More Obama Voters 1590 http://www.teaparty.org/rigged-poll-wsjnbc-poll-11-point-clinton-lead-includes-14-percent-obama-voters-192549/?utm_source=rss&utm_medium=rss&utm_campaign=rigged-poll-wsjnbc-poll-11-point-clinton-lead-includes-14-percent-obama-voters
# teaparty.org 2016-10-16T22:35:02+0000 Counter-Terrorism Expert: Obama Failed to Reduce Threat 4162 http://www.teaparty.org/counter-terrorism-expert-obama-failed-reduce-threat-192534/?utm_source=rss&utm_medium=rss&utm_campaign=counter-terrorism-expert-obama-failed-reduce-threat
# teaparty.org 2016-10-16T22:33:03+0000 Obama Enters Media Wars: Why His Recent Attack On Free Speech Is So Dangerous & Radical 7416 http://www.teaparty.org/obama-enters-media-wars-recent-attack-free-speech-dangerous-radical-192536/?utm_source=rss&utm_medium=rss&utm_campaign=obama-enters-media-wars-recent-attack-free-speech-dangerous-radical
# teaparty.org 2016-10-16T03:26:29+0000 EMAILS: Clinton Allies ‘Believe The Obama Forces’ Committed Voter Fraud In ’08 2290 http://www.teaparty.org/emails-clinton-allies-believe-obama-forces-committed-voter-fraud-08-192437/?utm_source=rss&utm_medium=rss&utm_campaign=emails-clinton-allies-believe-obama-forces-committed-voter-fraud-08
# teaparty.org 2016-10-15T23:23:01+0000 Michelle Obama Very Upset With Trump’s Words But OK With Obama Flashing a Boner to Reporters? 630 http://www.teaparty.org/michelle-obama-upset-trumps-words-ok-obama-flashing-boner-reporters-192411/?utm_source=rss&utm_medium=rss&utm_campaign=michelle-obama-upset-trumps-words-ok-obama-flashing-boner-reporters
# teaparty.org 2016-10-15T04:25:05+0000 Wikileaks Uncovers Attempt to Protect Obama in Email Scandal 8853 http://www.teaparty.org/wikileaks-uncovers-attempt-protect-obama-email-scandal-192277/?utm_source=rss&utm_medium=rss&utm_campaign=wikileaks-uncovers-attempt-protect-obama-email-scandal
# teaparty.org 2016-10-15T03:54:05+0000 Video: Obama TRIGGERED by Bill Clinton Rape Protester 1901 http://www.teaparty.org/video-obama-triggered-bill-clinton-rape-protester-192271/?utm_source=rss&utm_medium=rss&utm_campaign=video-obama-triggered-bill-clinton-rape-protester
# teaparty.org 2016-10-14T17:42:03+0000 Pentagon Issues Handbook on Sex Change in the Ranks 9625 http://www.teaparty.org/pentagon-issues-handbook-sex-change-ranks-192167/?utm_source=rss&utm_medium=rss&utm_campaign=pentagon-issues-handbook-sex-change-ranks
# teaparty.org 2016-10-13T21:47:58+0000 Obamacare Enrollment to See 'Significant Slowdown' Next Year 2458 http://www.teaparty.org/obamacare-enrollment-see-significant-slowdown-next-year-192011/?utm_source=rss&utm_medium=rss&utm_campaign=obamacare-enrollment-see-significant-slowdown-next-year
# teaparty.org 2016-10-14T18:14:04+0000 1 Million in Obamacare to Lose Plans as Insurers Quit 5415 http://www.teaparty.org/1-million-obamacare-lose-plans-insurers-quit-192182/?utm_source=rss&utm_medium=rss&utm_campaign=1-million-obamacare-lose-plans-insurers-quit
# teaparty.org 2016-10-14T17:29:11+0000 Obama, Aides Expected to Weigh Syria Military Options on Friday 5102 http://www.teaparty.org/obama-aides-expected-weigh-syria-military-options-friday-192157/?utm_source=rss&utm_medium=rss&utm_campaign=obama-aides-expected-weigh-syria-military-options-friday
# teaparty.org 2016-10-14T16:04:39+0000 Leaked Emails Reveals Clinton Campaign Plotted Supreme Court Threat Over Obamacare 2621 http://www.teaparty.org/leaked-emails-reveals-clinton-campaign-plotted-supreme-court-threat-obamacare-192136/?utm_source=rss&utm_medium=rss&utm_campaign=leaked-emails-reveals-clinton-campaign-plotted-supreme-court-threat-obamacare
# teaparty.org 2016-10-14T15:47:49+0000 Obama Decries 'Wild West' Media Landscape 1896 http://www.teaparty.org/obama-decries-wild-west-media-landscape-192132/?utm_source=rss&utm_medium=rss&utm_campaign=obama-decries-wild-west-media-landscape
# teaparty.org 2016-10-14T15:27:06+0000 Obama Hits 'Swamp of Crazy' Republicans as Trump Falters 2260 http://www.teaparty.org/obama-hits-swamp-crazy-republicans-trump-falters-192127/?utm_source=rss&utm_medium=rss&utm_campaign=obama-hits-swamp-crazy-republicans-trump-falters
# teaparty.org 2016-10-14T15:05:56+0000 296 Refugees Diagnosed with Active TB in Minnesota, Ten Times Any Other State; Majority Are Somalis 8570 http://www.teaparty.org/296-refugees-diagnosed-active-tb-minnesota-ten-times-state-majority-somalis-192114/?utm_source=rss&utm_medium=rss&utm_campaign=296-refugees-diagnosed-active-tb-minnesota-ten-times-state-majority-somalis
# teaparty.org 2016-10-14T14:33:00+0000 White House Warns Trump Not to Attack Michelle Obama After Fiery Speech 3379 http://www.teaparty.org/white-house-warns-trump-attack-michelle-obama-fiery-speech-192100/?utm_source=rss&utm_medium=rss&utm_campaign=white-house-warns-trump-attack-michelle-obama-fiery-speech
# teaparty.org 2016-10-14T04:01:27+0000 Limbaugh: Michelle Obama Hypocrite When She Slams Trump's Language 5241 http://www.teaparty.org/limbaugh-michelle-obama-hypocrite-slams-trumps-language-192078/?utm_source=rss&utm_medium=rss&utm_campaign=limbaugh-michelle-obama-hypocrite-slams-trumps-language
# teaparty.org 2016-10-13T22:11:56+0000 Obama To Decide Friday On Military Action In Syria 6307 http://www.teaparty.org/obama-decide-friday-military-action-syria-192016/?utm_source=rss&utm_medium=rss&utm_campaign=obama-decide-friday-military-action-syria
# teaparty.org 2016-10-13T13:50:30+0000 WikiLeaks: CNBC Host Rebecca Quick Promises to ‘Defend’ Obama Appointee 4115 http://www.teaparty.org/wikileaks-cnbc-host-rebecca-quick-promises-defend-obama-appointee-191952/?utm_source=rss&utm_medium=rss&utm_campaign=wikileaks-cnbc-host-rebecca-quick-promises-defend-obama-appointee
# teaparty.org 2016-10-13T11:14:04+0000 Another State Tells Churches to Shut up About Transgenders 7475 http://www.teaparty.org/another-state-tells-churches-shut-transgenders-191944/?utm_source=rss&utm_medium=rss&utm_campaign=another-state-tells-churches-shut-transgenders
# teaparty.org 2016-10-13T10:37:04+0000 The Imperial President's Toolbox Of Terror: A Dictatorship Waiting To Happen 8108 http://www.teaparty.org/imperial-presidents-toolbox-terror-dictatorship-waiting-happen-191939/?utm_source=rss&utm_medium=rss&utm_campaign=imperial-presidents-toolbox-terror-dictatorship-waiting-happen
# teaparty.org 2016-10-13T01:17:02+0000 MN Dem Governor Announces Affordable Care Act No Longer Affordable in His State 1536 http://www.teaparty.org/mn-dem-governor-announces-affordable-care-act-longer-affordable-state-191866/?utm_source=rss&utm_medium=rss&utm_campaign=mn-dem-governor-announces-affordable-care-act-longer-affordable-state
# teaparty.org 2016-10-12T18:38:14+0000 Video from 2008 Campaign Appears to Show Obama Flaunting Erection to Female Reporters 1269 http://www.teaparty.org/video-2008-campaign-appears-show-obama-flaunting-erection-female-reporters-191775/?utm_source=rss&utm_medium=rss&utm_campaign=video-2008-campaign-appears-show-obama-flaunting-erection-female-reporters
# teaparty.org 2016-10-12T15:20:38+0000 White House To Deliver "Proportional" Response To Russian Hacking, Won't Disclose What It Is 2894 http://www.teaparty.org/white-house-deliver-proportional-response-russian-hacking-wont-disclose-191745/?utm_source=rss&utm_medium=rss&utm_campaign=white-house-deliver-proportional-response-russian-hacking-wont-disclose
# teaparty.org 2016-10-12T08:41:51+0000 ‘Get Your Own Rally!’ Obama Frustrated by ’Bill Clinton Is a Rapist’ Protesters 2691 http://www.teaparty.org/get-rally-obama-frustrated-bill-clinton-rapist-protesters-191705/?utm_source=rss&utm_medium=rss&utm_campaign=get-rally-obama-frustrated-bill-clinton-rapist-protesters
# teaparty.org 2016-10-12T08:11:52+0000 Here Are 37 Companies That Directly Fund Planned Parenthood 3781 http://www.teaparty.org/37-companies-directly-fund-planned-parenthood-191692/?utm_source=rss&utm_medium=rss&utm_campaign=37-companies-directly-fund-planned-parenthood
# teaparty.org 2016-10-12T02:25:38+0000 Diller: Trump Presidential Run is 'Evil Miracle' 2240 http://www.teaparty.org/diller-trump-presidential-run-evil-miracle-191639/?utm_source=rss&utm_medium=rss&utm_campaign=diller-trump-presidential-run-evil-miracle
# teaparty.org 2016-10-11T05:34:01+0000 Email: Clinton Camp Feared ‘Obama’-Style Voter Fraud in 2016 2909 http://www.teaparty.org/email-clinton-camp-feared-obama-style-voter-fraud-2016-191433/?utm_source=rss&utm_medium=rss&utm_campaign=email-clinton-camp-feared-obama-style-voter-fraud-2016
# teaparty.org 2016-10-10T23:41:09+0000 Afghan Police: Up to Half of U.S.-Funded Afghan Troops in Helmand ‘Do Not Exist’ 3403 http://www.teaparty.org/afghan-police-half-u-s-funded-afghan-troops-helmand-exist-191361/?utm_source=rss&utm_medium=rss&utm_campaign=afghan-police-half-u-s-funded-afghan-troops-helmand-exist
# teaparty.org 2016-10-10T20:42:30+0000 Obama Memo: Security Agencies Need More ‘Diversity’ 3703 http://www.teaparty.org/obama-memo-security-agencies-need-diversity-191316/?utm_source=rss&utm_medium=rss&utm_campaign=obama-memo-security-agencies-need-diversity
# teaparty.org 2016-10-09T16:39:46+0000 US Soldiers Resist Obama's Support Of Al Qaeda 13364 http://www.teaparty.org/us-soldiers-resist-obamas-support-al-qaeda-191029/?utm_source=rss&utm_medium=rss&utm_campaign=us-soldiers-resist-obamas-support-al-qaeda
# teaparty.org 2016-10-08T22:27:00+0000 Obama Admin Blames Putin and Russia for Interfering with Presidential Election by Leaking Scandalous DNC Emails 1662 http://www.teaparty.org/obama-admin-blames-putin-russia-interfering-presidential-election-leaking-scandalous-dnc-emails-190960/
# teaparty.org 2016-10-08T20:41:00+0000 Obama Administration Rushes More Than 900 Refugees Into U.S. On Consecutive Days, On Track for 185,000 in FY 2017 6087 http://www.teaparty.org/obama-administration-rushes-900-refugees-u-s-consecutive-days-track-185000-fy-2017-190984/
# teaparty.org 2016-10-08T19:33:00+0000 FLASHBACK VIDEO: Presidents Being Colorful, Including Obama’s “B*tch Nigga Buy Your Own Damn Fries!” 897 http://www.teaparty.org/flashback-video-presidents-colorful-including-obamas-btch-nigga-buy-damn-fries-190922/
# teaparty.org 2016-10-07T04:21:15+0000 Obama Quietly Delaying Thousands of Deportation Cases 4804 http://www.teaparty.org/obama-quietly-delaying-thousands-deportation-cases-190741/?utm_source=rss&utm_medium=rss&utm_campaign=obama-quietly-delaying-thousands-deportation-cases
# teaparty.org 2016-10-07T19:31:43+0000 Russia’s Nuclear Surge: Putin Adding Nukes While Obama Cuts 6110 http://www.teaparty.org/russias-nuclear-surge-putin-adding-nukes-obama-cuts-190814/?utm_source=rss&utm_medium=rss&utm_campaign=russias-nuclear-surge-putin-adding-nukes-obama-cuts
# teaparty.org 2016-10-07T19:13:01+0000 Woman Who Survived Nazi Invasion Issues Warning: Don’t Let Obama Postpone Election 1057 http://www.teaparty.org/woman-survived-nazi-invasion-issues-warning-dont-let-obama-postpone-election-190805/?utm_source=rss&utm_medium=rss&utm_campaign=woman-survived-nazi-invasion-issues-warning-dont-let-obama-postpone-election
# teaparty.org 2016-10-07T10:42:55+0000 Obama Hits Trump Over 'Crude Populism,' Pushes TPP 2361 http://www.teaparty.org/obama-hits-trump-crude-populism-pushes-tpp-190778/?utm_source=rss&utm_medium=rss&utm_campaign=obama-hits-trump-crude-populism-pushes-tpp
# teaparty.org 2016-10-07T03:42:00+0000 Fueled by Hillary Clinton, White House Debated Nominating Wikileaks Founder for Obama-Controlled Drone “Kill List” 13067 http://www.teaparty.org/white-house-debated-nominating-wikileaks-founder-obama-controlled-drone-kill-list-190727/?utm_source=rss&utm_medium=rss&utm_campaign=white-house-debated-nominating-wikileaks-founder-obama-controlled-drone-kill-list
# teaparty.org 2016-10-07T02:53:49+0000 Obama Releases Dozens more Cocaine Dealers 40223 http://www.teaparty.org/obama-releases-dozens-cocaine-dealers-190708/?utm_source=rss&utm_medium=rss&utm_campaign=obama-releases-dozens-cocaine-dealers
# teaparty.org 2016-10-06T22:48:34+0000 Obama Administration issues Martial Law Directive 7296 http://www.teaparty.org/obama-administration-issues-martial-law-directive-5-190696/?utm_source=rss&utm_medium=rss&utm_campaign=obama-administration-issues-martial-law-directive-5
# teaparty.org 2016-10-06T19:18:10+0000 Worst Economic President Since Great Depression Offers Economic Advice to Next President 3762 http://www.teaparty.org/worst-economic-president-since-great-depression-offers-economic-advice-next-president-190674/?utm_source=rss&utm_medium=rss&utm_campaign=worst-economic-president-since-great-depression-offers-economic-advice-next-president
# teaparty.org 2016-10-06T19:13:48+0000 AWFUL. Barack Obama Blew $500 Million in Taxpayer Funds on PR Army to Promote His Failed Policies 742 http://www.teaparty.org/awful-barack-obama-blew-500-million-taxpayer-funds-pr-army-promote-failed-policies-190672/?utm_source=rss&utm_medium=rss&utm_campaign=awful-barack-obama-blew-500-million-taxpayer-funds-pr-army-promote-failed-policies
# teaparty.org 2016-10-06T18:41:06+0000 Once Lauded as a Peacemaker, Obama's Tenure Fraught with War 7417 http://www.teaparty.org/lauded-peacemaker-obamas-tenure-fraught-war-190666/?utm_source=rss&utm_medium=rss&utm_campaign=lauded-peacemaker-obamas-tenure-fraught-war
# teaparty.org 2016-10-06T00:26:41+0000 Government Destroys Tea-Party Leader for Opposing Obama 7192 http://www.teaparty.org/government-destroys-tea-party-leader-opposing-obama-190509/?utm_source=rss&utm_medium=rss&utm_campaign=government-destroys-tea-party-leader-opposing-obama
# teaparty.org 2016-10-04T20:52:57+0000 Obama Admin Releases 128K Illegal Immigrant Kids Into U.S. In Under 3 Years 3199 http://www.teaparty.org/obama-admin-releases-128k-illegal-immigrant-kids-u-s-3-years-190282/?utm_source=rss&utm_medium=rss&utm_campaign=obama-admin-releases-128k-illegal-immigrant-kids-u-s-3-years
# teaparty.org 2016-10-06T16:03:46+0000 Report: Federal Government Spends $1.5 Billion Per Year on Public Relations 1941 http://www.teaparty.org/report-federal-government-spends-1-5-billion-per-year-public-relations-190624/?utm_source=rss&utm_medium=rss&utm_campaign=report-federal-government-spends-1-5-billion-per-year-public-relations
# teaparty.org 2016-10-06T16:03:46+0000 Report: Federal Government Spends $1.5 Billion Per Year on Public Relations 1941 http://www.teaparty.org/report-federal-government-spends-1-5-billion-per-year-public-relations-190624/?utm_source=rss&utm_medium=rss&utm_campaign=report-federal-government-spends-1-5-billion-per-year-public-relations
# teaparty.org 2016-10-06T09:20:56+0000 Obama Administation Hires Hundreds of PR Staffers for $500 Million a Year 1849 http://www.teaparty.org/obama-administation-hires-hundreds-pr-staffers-500-million-year-190566/?utm_source=rss&utm_medium=rss&utm_campaign=obama-administation-hires-hundreds-pr-staffers-500-million-year
# teaparty.org 2016-10-04T17:46:12+0000 Obama on Race: "I Am Saddened that Whites are Still Superior 2820 http://www.teaparty.org/never-seen-video-obama-race-saddened-whites-still-superior-190251/?utm_source=rss&utm_medium=rss&utm_campaign=never-seen-video-obama-race-saddened-whites-still-superior
# teaparty.org 2016-10-05T16:10:41+0000 5 Devastating Obamacare Facts Every American Should Know 3340 http://www.teaparty.org/5-devastating-obamacare-facts-every-american-know-2-190390/?utm_source=rss&utm_medium=rss&utm_campaign=5-devastating-obamacare-facts-every-american-know-2
# teaparty.org 2016-10-05T15:59:12+0000 Not Just Bill Clinton! ALL Dems Know Obamacare Failing 5928 http://www.teaparty.org/just-bill-clinton-dems-know-obamacare-failing-190387/?utm_source=rss&utm_medium=rss&utm_campaign=just-bill-clinton-dems-know-obamacare-failing
# teaparty.org 2016-10-04T17:23:39+0000 Philippine President Tells Obama 'Go to Hell' 5429 http://www.teaparty.org/philippine-president-tells-obama-go-hell-190248/?utm_source=rss&utm_medium=rss&utm_campaign=philippine-president-tells-obama-go-hell
# teaparty.org 2016-10-05T14:41:53+0000 Obama Warned To Defuse Tensions With Russia, "Unintended Consequences Likely To Be Catastrophic" 9998 http://www.teaparty.org/obama-warned-defuse-tensions-russia-unintended-consequences-likely-catastrophic-190349/?utm_source=rss&utm_medium=rss&utm_campaign=obama-warned-defuse-tensions-russia-unintended-consequences-likely-catastrophic
# teaparty.org 2016-10-05T10:27:25+0000 Blameshifting: Obama Tells DiCaprio Climate Change ‘Contributed’ to the Syrian Civil War 1349 http://www.teaparty.org/blameshifting-obama-tells-dicaprio-climate-change-contributed-syrian-civil-war-190338/?utm_source=rss&utm_medium=rss&utm_campaign=blameshifting-obama-tells-dicaprio-climate-change-contributed-syrian-civil-war
# teaparty.org 2016-10-04T11:01:01+0000 REPORT: CIA Used Makeshift Electric Chair in Secret Afghan Prison 2745 http://www.teaparty.org/report-cia-used-makeshift-electric-chair-secret-afghan-prison-190148/?utm_source=rss&utm_medium=rss&utm_campaign=report-cia-used-makeshift-electric-chair-secret-afghan-prison
# teaparty.org 2016-10-04T15:18:01+0000 More Federal Money for Somali Refugees in Maine 4428 http://www.teaparty.org/federal-money-somali-refugees-maine-190197/?utm_source=rss&utm_medium=rss&utm_campaign=federal-money-somali-refugees-maine
# teaparty.org 2016-10-04T12:01:03+0000 SCOTUS Refuses to Rescue Obama on Executive Amnesty 3316 http://www.teaparty.org/scotus-refuses-rescue-obama-executive-amnesty-190164/?utm_source=rss&utm_medium=rss&utm_campaign=scotus-refuses-rescue-obama-executive-amnesty
# teaparty.org 2016-10-04T04:24:02+0000 Obama Lives in 'Make-Believe World' with Muslim Dictator Erdogan 4335 http://www.teaparty.org/obama-lives-make-believe-world-muslim-dictator-erdogan-190107/?utm_source=rss&utm_medium=rss&utm_campaign=obama-lives-make-believe-world-muslim-dictator-erdogan
# teaparty.org 2016-10-04T03:59:11+0000 Police State, USA: No 'Praying' in Own Home 4898 http://www.teaparty.org/police-state-usa-praying-home-190097/?utm_source=rss&utm_medium=rss&utm_campaign=police-state-usa-praying-home
# teaparty.org 2016-10-04T03:07:04+0000 4 States Will Have Only 1 Obamacare Insurer 4636 http://www.teaparty.org/4-states-will-1-obamacare-insurer-190095/?utm_source=rss&utm_medium=rss&utm_campaign=4-states-will-1-obamacare-insurer
# teaparty.org 2016-10-04T01:12:04+0000 Obama Makes Last Stand at Supreme Court 7268 http://www.teaparty.org/obama-makes-last-stand-supreme-court-190071/?utm_source=rss&utm_medium=rss&utm_campaign=obama-makes-last-stand-supreme-court
# teaparty.org 2016-10-04T00:46:59+0000 DICTATOR: Obama Bypasses Congress, Launches Assault on the Second Amendment 7296 http://www.teaparty.org/dictator-obama-bypasses-congress-launches-assault-second-amendment-3-190064/?utm_source=rss&utm_medium=rss&utm_campaign=dictator-obama-bypasses-congress-launches-assault-second-amendment-3
# teaparty.org 2016-10-03T22:20:01+0000 Secret Service Officer Blows Lid Off 'Murdered Mom' Case 23292 http://www.teaparty.org/secret-service-officer-blows-lid-murdered-mom-case-190055/?utm_source=rss&utm_medium=rss&utm_campaign=secret-service-officer-blows-lid-murdered-mom-case
# teaparty.org 2016-10-03T22:13:01+0000 Cha-ching! Mosque Wins $1.7M with Help from Obama's DOJ 9400 http://www.teaparty.org/cha-ching-mosque-wins-1-7m-help-obamas-doj-190052/?utm_source=rss&utm_medium=rss&utm_campaign=cha-ching-mosque-wins-1-7m-help-obamas-doj
# teaparty.org 2016-10-03T16:47:03+0000 Obama Syrian Refugee Tally '16: 12,486 Muslims, 68 Christians 4347 http://www.teaparty.org/obama-syrian-refugee-tally-16-12486-muslims-68-christians-189977/?utm_source=rss&utm_medium=rss&utm_campaign=obama-syrian-refugee-tally-16-12486-muslims-68-christians
# teaparty.org 2016-10-02T20:02:01+0000 Illegal Who Killed 12 yr Old Girl was Obama Amnesty Eecipient -- with Prior Drug Arrest 4800 http://www.teaparty.org/illegal-killed-12-yr-old-girl-obama-amnesty-eecipient-prior-drug-arrest-189924/?utm_source=rss&utm_medium=rss&utm_campaign=illegal-killed-12-yr-old-girl-obama-amnesty-eecipient-prior-drug-arrest
# teaparty.org 2016-09-30T16:07:02+0000 Obama Admin Signed Secret Documents to Lift UN Sanctions on Iranian Banks – Same Day Tehran Released US Hostages 7673 http://www.teaparty.org/obama-admin-signed-secret-documents-lift-un-sanctions-iranian-banks-day-tehran-released-us-hostages-189589/?utm_source=rss&utm_medium=rss&utm_campaign=obama-admin-signed-secret-documents-lift-un-sanctions-iranian-banks-day-tehran-released-us-hostages
# teaparty.org 2016-09-30T15:15:04+0000 Ice Cube Calls For Obama Third Term: Trump and Hillary ‘Both Suck’ 2526 http://www.teaparty.org/ice-cube-calls-obama-third-term-trump-hillary-suck-189538/?utm_source=rss&utm_medium=rss&utm_campaign=ice-cube-calls-obama-third-term-trump-hillary-suck
# teaparty.org 2016-09-30T15:18:05+0000 WH Spox Compares Congress to Children After Veto Override 2160 http://www.teaparty.org/wh-spox-compares-congress-children-veto-override-189543/?utm_source=rss&utm_medium=rss&utm_campaign=wh-spox-compares-congress-children-veto-override
# teaparty.org 2016-10-02T09:18:07+0000 White House wants New Racial Category for Mideast, North Africa 6402 http://www.teaparty.org/white-house-wants-new-racial-category-mideast-north-africa-189834/?utm_source=rss&utm_medium=rss&utm_campaign=white-house-wants-new-racial-category-mideast-north-africa
# teaparty.org 2016-09-30T01:24:03+0000 Wow! Watch Jacka$$ Obama Clash with Gold Star Mother, Smear Christians at CNN Town Hall (VIDEO) 3782 http://www.teaparty.org/wow-watch-jacka-obama-clash-gold-star-mother-smear-christians-cnn-town-hall-video-189465/?utm_source=rss&utm_medium=rss&utm_campaign=wow-watch-jacka-obama-clash-gold-star-mother-smear-christians-cnn-town-hall-video
# teaparty.org 2016-10-01T21:28:45+0000 Near 'Collapse,' Minnesota to Raise Obamacare Rates by Half 3393 http://www.teaparty.org/near-collapse-minnesota-raise-obamacare-rates-half-189809/?utm_source=rss&utm_medium=rss&utm_campaign=near-collapse-minnesota-raise-obamacare-rates-half
# teaparty.org 2016-10-01T19:37:05+0000 Jeff Sessions Slams Top Immigration Official for Suppressing Reports of Refugee Terrorism, Crime 4191 http://www.teaparty.org/jeff-sessions-slams-top-immigration-official-suppressing-reports-refugee-terrorism-crime-189774/?utm_source=rss&utm_medium=rss&utm_campaign=jeff-sessions-slams-top-immigration-official-suppressing-reports-refugee-terrorism-crime
# teaparty.org 2016-10-01T05:50:02+0000 Obama Implies He’ll be More Vocal About Issues After He Leaves Office 2484 http://www.teaparty.org/obama-implies-hell-vocal-issues-leaves-office-189678/?utm_source=rss&utm_medium=rss&utm_campaign=obama-implies-hell-vocal-issues-leaves-office
# teaparty.org 2016-10-01T05:37:02+0000 Obama Administration Denies Jerusalem Is Located in Israel 1680 http://www.teaparty.org/obama-administration-denies-jerusalem-located-israel-189671/?utm_source=rss&utm_medium=rss&utm_campaign=obama-administration-denies-jerusalem-located-israel
# teaparty.org 2016-10-01T05:19:04+0000 Donald Trump Demands President Obama Not Pardon Hillary Clinton 1432 http://www.teaparty.org/donald-trump-demands-president-obama-pardon-hillary-clinton-189664/?utm_source=rss&utm_medium=rss&utm_campaign=donald-trump-demands-president-obama-pardon-hillary-clinton
# teaparty.org 2016-09-30T14:46:02+0000 Report: Obama May Use Hidden Fund to Pay Off Billions in Obamacare Debts 6181 http://www.teaparty.org/mess-obama-maneuvering-pay-health-insurers-billions-dollars-189528/?utm_source=rss&utm_medium=rss&utm_campaign=mess-obama-maneuvering-pay-health-insurers-billions-dollars
# teaparty.org 2016-09-27T17:09:03+0000 PAYBACK: Obama Admin Sues Peter Thiel’s Palantir for Bogus ‘Racial Discrimination’ 3454 http://www.teaparty.org/payback-obama-admin-sues-peter-thiels-palantir-bogus-racial-discrimination-189117/?utm_source=rss&utm_medium=rss&utm_campaign=payback-obama-admin-sues-peter-thiels-palantir-bogus-racial-discrimination
# teaparty.org 2016-09-29T00:14:02+0000 Navy SEAL: Obama CREATING Conditions To Impose Martial Law 7296 http://www.teaparty.org/navy-seal-obama-creating-conditions-impose-martial-law-2-189370/?utm_source=rss&utm_medium=rss&utm_campaign=navy-seal-obama-creating-conditions-impose-martial-law-2
# teaparty.org 2016-09-28T23:04:05+0000 Congress Slaps Obama with 1st Veto Override of Presidency 13682 http://www.teaparty.org/congress-slaps-obama-1st-veto-override-presidency-189352/?utm_source=rss&utm_medium=rss&utm_campaign=congress-slaps-obama-1st-veto-override-presidency
# teaparty.org 2016-09-29T18:40:02+0000 'American Psycho' Author: 'Backlash is Beginning Against PC Victim Culture' 5894 http://www.teaparty.org/american-psycho-author-backlash-beginning-pc-victim-culture-189405/?utm_source=rss&utm_medium=rss&utm_campaign=american-psycho-author-backlash-beginning-pc-victim-culture
# teaparty.org 2016-09-29T16:48:01+0000 Americans Erupt Over Obama's Potentially Greatest Scandal 7296 http://www.teaparty.org/americans-erupt-obamas-potentially-greatest-scandal-5-189377/?utm_source=rss&utm_medium=rss&utm_campaign=americans-erupt-obamas-potentially-greatest-scandal-5
# teaparty.org 2016-09-29T14:44:02+0000 Obama Telling Refugees: Just Vet Yourself 13746 http://www.teaparty.org/obama-telling-refugees-just-vet-189375/?utm_source=rss&utm_medium=rss&utm_campaign=obama-telling-refugees-just-vet
# teaparty.org 2016-09-28T18:09:03+0000 Congress Has Three Days to Stop Obama’s Internet Surrender 8315 http://www.teaparty.org/congress-three-days-stop-obamas-internet-surrender-189288/?utm_source=rss&utm_medium=rss&utm_campaign=congress-three-days-stop-obamas-internet-surrender
# teaparty.org 2016-09-28T10:53:03+0000 UN Demands U.S. Pay Reparations To Blacks 3989 http://www.teaparty.org/un-demands-u-s-pay-reparations-blacks-189190/?utm_source=rss&utm_medium=rss&utm_campaign=un-demands-u-s-pay-reparations-blacks
# teaparty.org 2016-09-28T14:36:02+0000 James Comey: I Am a ‘Deeply Flawed and Fallible Human Being’ Who Did Not Stop Terrorists 3458 http://www.teaparty.org/james-comey-deeply-flawed-fallible-human-stop-terrorists-189249/?utm_source=rss&utm_medium=rss&utm_campaign=james-comey-deeply-flawed-fallible-human-stop-terrorists
# teaparty.org 2016-09-26T20:47:02+0000 Leaked FBI Data Reveal 7,700 Terrorist Encounters in USA in One Year; Border States Most Targeted 3018 http://www.teaparty.org/leaked-fbi-data-reveal-7700-terrorist-encounters-usa-one-year-border-states-targeted-189007/?utm_source=rss&utm_medium=rss&utm_campaign=leaked-fbi-data-reveal-7700-terrorist-encounters-usa-one-year-border-states-targeted
# teaparty.org 2016-09-26T20:37:04+0000 Malaysia to Launch ‘Made by Muslims’ Logo 2374 http://www.teaparty.org/malaysia-launch-made-muslims-logo-188995/?utm_source=rss&utm_medium=rss&utm_campaign=malaysia-launch-made-muslims-logo
# teaparty.org 2016-09-24T03:03:05+0000 Obama Hints at Activist Plans After White House 2707 http://www.teaparty.org/obama-hints-activist-plans-white-house-188696/?utm_source=rss&utm_medium=rss&utm_campaign=obama-hints-activist-plans-white-house
# teaparty.org 2016-09-26T15:26:03+0000 Nebraska Town Considers Banning Smoking in Apartments 4785 http://www.teaparty.org/nebraska-town-considers-banning-smoking-apartments-188907/?utm_source=rss&utm_medium=rss&utm_campaign=nebraska-town-considers-banning-smoking-apartments
# teaparty.org 2016-09-26T15:24:04+0000 Saudi Arabia Injects $5.3 Billion in Bank System Amid Crunch 2392 http://www.teaparty.org/saudi-arabia-injects-5-3-billion-bank-system-amid-crunch-188900/?utm_source=rss&utm_medium=rss&utm_campaign=saudi-arabia-injects-5-3-billion-bank-system-amid-crunch
# teaparty.org 2016-09-26T15:12:03+0000 Top US General Warns Syrian 'No-Fly' Zone Means War with Russia 4856 http://www.teaparty.org/top-us-general-warns-syrian-no-fly-zone-means-war-with-russia-188902/?utm_source=rss&utm_medium=rss&utm_campaign=top-us-general-warns-syrian-no-fly-zone-means-war-with-russia
# teaparty.org 2016-09-26T00:39:02+0000 MILITARY PURGE: Top US Admiral FIRED for Questioning Obama Purchase of Mansion in Dubai 7296 http://www.teaparty.org/military-purge-top-us-admiral-fired-questioning-obama-purchase-mansion-dubai-188856/?utm_source=rss&utm_medium=rss&utm_campaign=military-purge-top-us-admiral-fired-questioning-obama-purchase-mansion-dubai
# teaparty.org 2016-09-25T19:48:02+0000 Obama's Colossal Email Lie Final Test for Tarnished MSM 7354 http://www.teaparty.org/obamas-colossal-email-lie-final-test-tarnished-msm-188813/?utm_source=rss&utm_medium=rss&utm_campaign=obamas-colossal-email-lie-final-test-tarnished-msm
# teaparty.org 2016-09-24T23:52:01+0000 Do ‘White Lives Matter’ in Charlotte? Internet Outrage Grows After Protests Turn Violent 1728 http://www.teaparty.org/white-lives-matter-charlotte-internet-outrage-grows-protests-turn-violent-188761/?utm_source=rss&utm_medium=rss&utm_campaign=white-lives-matter-charlotte-internet-outrage-grows-protests-turn-violent
# teaparty.org 2016-09-25T19:39:01+0000 Growing Number of Race Riots Leave a Dark Mark on Obama's Legacy 7225 http://www.teaparty.org/growing-number-race-riots-leave-dark-mark-obamas-legacy-188799/?utm_source=rss&utm_medium=rss&utm_campaign=growing-number-race-riots-leave-dark-mark-obamas-legacy
# teaparty.org 2016-09-24T23:48:02+0000 Obama Opens New African American Museum Amid National Racial Strife 4691 http://www.teaparty.org/obama-opens-new-african-american-museum-amid-national-racial-strife-188759/?utm_source=rss&utm_medium=rss&utm_campaign=obama-opens-new-african-american-museum-amid-national-racial-strife
# teaparty.org 2016-09-24T02:58:55+0000 FBI Bombshell: Obama Used Pseudonym in Emails with Clinton 4314 http://www.teaparty.org/fbi-bombshell-obama-used-pseudonym-emails-clinton-188693/?utm_source=rss&utm_medium=rss&utm_campaign=fbi-bombshell-obama-used-pseudonym-emails-clinton
# teaparty.org 2016-09-24T17:42:47+0000 Texas Lieutenant Gov. Calls For Impeachment Of Obama 7296 http://www.teaparty.org/texas-lieutenant-gov-calls-impeachment-obama-188721/?utm_source=rss&utm_medium=rss&utm_campaign=texas-lieutenant-gov-calls-impeachment-obama
# teaparty.org 2016-09-23T23:15:02+0000 Obama says Trump Should Visit New African-American Museum 3451 http://www.teaparty.org/obama-says-trump-visit-new-african-american-museum-188685/?utm_source=rss&utm_medium=rss&utm_campaign=obama-says-trump-visit-new-african-american-museum
# teaparty.org 2016-09-23T22:17:02+0000 Suspected Illegal Alien Marijuana Farmers Held Workers Hostage: ICE 5193 http://www.teaparty.org/suspected-illegal-alien-marijuana-farmers-held-workers-hostage-ice-188673/?utm_source=rss&utm_medium=rss&utm_campaign=suspected-illegal-alien-marijuana-farmers-held-workers-hostage-ice
# teaparty.org 2016-09-23T18:40:04+0000 Obama's Ex-Secret Service Agent: Whites Hunted Down in Charlotte, Where the Hell is Obama? (VIDEO) 1272 http://www.teaparty.org/obamas-ex-secret-service-agent-whites-hunted-down-in-charlotte-where-the-hell-is-obama-video-188634/?utm_source=rss&utm_medium=rss&utm_campaign=obamas-ex-secret-service-agent-whites-hunted-down-in-charlotte-where-the-hell-is-obama-video
# teaparty.org 2016-09-22T22:51:01+0000 Obama-Era Surveillance Worse than Stasi, says Oliver Stone 2148 http://www.teaparty.org/obama-era-surveillance-worse-stasi-says-oliver-stone-188529/?utm_source=rss&utm_medium=rss&utm_campaign=obama-era-surveillance-worse-stasi-says-oliver-stone
# teaparty.org 2016-09-22T22:05:01+0000 John Bolton on Obama’s Internet Handover: ‘Within Ten Years, the Internet as We Know It Will End’ 10150 http://www.teaparty.org/john-bolton-obamas-internet-handover-within-ten-years-internet-know-will-end-188526/?utm_source=rss&utm_medium=rss&utm_campaign=john-bolton-obamas-internet-handover-within-ten-years-internet-know-will-end
# teaparty.org 2016-09-23T17:32:02+0000 Haitian Immigrants Cross into USA from Mexico 6153 http://www.teaparty.org/haitian-immigrants-cross-usa-mexico-188618/?utm_source=rss&utm_medium=rss&utm_campaign=haitian-immigrants-cross-usa-mexico
# teaparty.org 2016-09-23T17:24:01+0000 Obama's Climate Adviser Trolled with Article from 1922 4589 http://www.teaparty.org/obamas-climate-adviser-trolled-article-1922-188611/?utm_source=rss&utm_medium=rss&utm_campaign=obamas-climate-adviser-trolled-article-1922
# teaparty.org 2016-09-23T16:45:02+0000 DHS: Refugee Fraud 'Easy' to Commit 4621 http://www.teaparty.org/dhs-refugee-fraud-easy-commit-188574/?utm_source=rss&utm_medium=rss&utm_campaign=dhs-refugee-fraud-easy-commit
# teaparty.org 2016-09-23T16:44:03+0000 Obama Kept Military Out of the Loop on Cash Payments to Iran 4641 http://www.teaparty.org/obama-kept-military-loop-cash-payments-iran-188570/?utm_source=rss&utm_medium=rss&utm_campaign=obama-kept-military-loop-cash-payments-iran
# teaparty.org 2016-09-23T16:43:01+0000 Obama New Citizen Push 'Due to Election' 4151 http://www.teaparty.org/obama-new-citizen-push-due-election-188577/?utm_source=rss&utm_medium=rss&utm_campaign=obama-new-citizen-push-due-election
# teaparty.org 2016-09-23T16:25:02+0000 Snowden Warning: New Google Messenger Spying on You 1571 http://www.teaparty.org/snowden-warning-new-google-messenger-spying-188562/?utm_source=rss&utm_medium=rss&utm_campaign=snowden-warning-new-google-messenger-spying
# teaparty.org 2016-09-23T16:18:02+0000 NSA Whistleblower: Spy-Grid is Part of World Gov't Takeover 1791 http://www.teaparty.org/nsa-whistleblower-spy-grid-part-world-govt-takeover-188560/?utm_source=rss&utm_medium=rss&utm_campaign=nsa-whistleblower-spy-grid-part-world-govt-takeover
# teaparty.org 2016-09-23T04:14:05+0000 IRS Targets 20 Million Over Obamacare 3681 http://www.teaparty.org/irs-targets-20-million-obamacare-188545/?utm_source=rss&utm_medium=rss&utm_campaign=irs-targets-20-million-obamacare
# teaparty.org 2016-09-21T22:43:02+0000 Poll—84 Percent of Working Class Whites Say Government Doesn’t Represent Our Views 4276 http://www.teaparty.org/poll-84-percent-working-class-whites-say-government-doesnt-represent-views-188379/?utm_source=rss&utm_medium=rss&utm_campaign=poll-84-percent-working-class-whites-say-government-doesnt-represent-views
# teaparty.org 2016-09-22T21:17:01+0000 NYC: No Longer Safe for Seniors to Go Out 4257 http://www.teaparty.org/nyc-no-longer-safe-for-seniors-to-go-out-188514/?utm_source=rss&utm_medium=rss&utm_campaign=nyc-no-longer-safe-for-seniors-to-go-out
# teaparty.org 2016-09-22T21:15:01+0000 White House Staffer's Email is Hacked Revealing Joe Biden and Hillary Clinton's Private Schedules, Secret Service Plans, and Even Michelle Obama's PASSPORT 3006 http://www.teaparty.org/white-house-staffers-email-hacked-revealing-joe-biden-hillary-clintons-private-schedules-secret-service-plans-even-michelle-obamas-passport-188511/?utm_source=rss&utm_medium=rss&utm_campaign=white-house-staffers-email-hacked-revealing-joe-biden-hillary-clintons-private-schedules-secret-service-plans-even-michelle-obamas-passport
# teaparty.org 2016-09-22T19:44:02+0000 State Supremes Give Blacks Green Light to Flee Cops 5345 http://www.teaparty.org/state-supremes-give-blacks-green-light-flee-cops-188497/?utm_source=rss&utm_medium=rss&utm_campaign=state-supremes-give-blacks-green-light-flee-cops
# teaparty.org 2016-09-22T14:47:01+0000 Long Goodbye: Obama in Conversation with Historian Kearns Goodwin 41377 http://www.teaparty.org/long-goodbye-obama-conversation-historian-kearns-goodwin-188468/?utm_source=rss&utm_medium=rss&utm_campaign=long-goodbye-obama-conversation-historian-kearns-goodwin
# teaparty.org 2016-09-22T04:34:02+0000 Obama Set to Veto 9/11 Victims' Bid to Sue Saudis 4813 http://www.teaparty.org/obama-set-veto-911-victims-bid-sue-saudis-188450/?utm_source=rss&utm_medium=rss&utm_campaign=obama-set-veto-911-victims-bid-sue-saudis
# teaparty.org 2016-09-22T04:20:07+0000 Mysterious Paralyzing Illness Surging Across America 9037 http://www.teaparty.org/mysterious-paralyzing-illness-surging-across-america-188443/?utm_source=rss&utm_medium=rss&utm_campaign=mysterious-paralyzing-illness-surging-across-america
# teaparty.org 2016-09-22T03:53:05+0000 Donald Trump Comes Out Against Obama’s United Nations Internet Takeover 3448 http://www.teaparty.org/donald-trump-comes-obamas-united-nations-internet-takeover-188434/?utm_source=rss&utm_medium=rss&utm_campaign=donald-trump-comes-obamas-united-nations-internet-takeover
# teaparty.org 2016-09-22T02:09:02+0000 Limbaugh: Riots the New Normal Under 1st Black President 2834 http://www.teaparty.org/limbaugh-riots-new-normal-1st-black-president-188406/?utm_source=rss&utm_medium=rss&utm_campaign=limbaugh-riots-new-normal-1st-black-president
# teaparty.org 2016-09-22T01:54:05+0000 IRS Chief Throws '2 Guys on Night Shift' Under Bus 18613 http://www.teaparty.org/irs-chief-throws-2-guys-night-shift-bus-188398/?utm_source=rss&utm_medium=rss&utm_campaign=irs-chief-throws-2-guys-night-shift-bus
# teaparty.org 2016-09-21T23:52:03+0000 Farrakhan to Obama: Let Trump Do Want He Wants, You Failed Inner City Blacks 2514 http://www.teaparty.org/farrakhan-obama-let-trump-want-wants-failed-inner-city-blacks-188390/?utm_source=rss&utm_medium=rss&utm_campaign=farrakhan-obama-let-trump-want-wants-failed-inner-city-blacks
# teaparty.org 2016-09-21T21:26:01+0000 MUSLIM LEADER Promises More VIOLENCE-RIOTING in Charlotte: ‘We’re Not Telling Our Brothers to Stop!” 1395 http://www.teaparty.org/muslim-leader-promises-violence-rioting-charlotte-telling-brothers-stop-188353/?utm_source=rss&utm_medium=rss&utm_campaign=muslim-leader-promises-violence-rioting-charlotte-telling-brothers-stop
# teaparty.org 2016-09-21T21:19:02+0000 State Admits: Islamic State Terrorists Trying to Pose as Refugees 1692 http://www.teaparty.org/state-admits-islamic-state-terrorists-trying-pose-refugees-188351/?utm_source=rss&utm_medium=rss&utm_campaign=state-admits-islamic-state-terrorists-trying-pose-refugees
# teaparty.org 2016-09-21T19:56:03+0000 Sheriff Joe Arpaio Says He Is Still Investigating Obama Birth Certificate 1948 http://www.teaparty.org/sheriff-joe-arpaio-says-still-investigating-obama-birth-certificate-188334/?utm_source=rss&utm_medium=rss&utm_campaign=sheriff-joe-arpaio-says-still-investigating-obama-birth-certificate
# teaparty.org 2016-09-21T19:14:05+0000 SHOWDOWN: TX Threatens to 'Exit' Federal Refugee Program Over Terror Threat 2879 http://www.teaparty.org/showdown-tx-threatens-exit-federal-refugee-program-terror-threat-188315/?utm_source=rss&utm_medium=rss&utm_campaign=showdown-tx-threatens-exit-federal-refugee-program-terror-threat
# teaparty.org 2016-09-21T15:16:02+0000 Poll: 74% Voters Reject Obama’s Middle East Refugee Plan 5271 http://www.teaparty.org/poll-74-voters-reject-obamas-middle-east-refugee-plan-188309/?utm_source=rss&utm_medium=rss&utm_campaign=poll-74-voters-reject-obamas-middle-east-refugee-plan
# teaparty.org 2016-09-21T14:57:01+0000 Obama Slams Trump’s Wall in Final UN Speech… But Paid $75 Million to Build Mexico’s Wall 1133 http://www.teaparty.org/obama-slams-trumps-wall-final-un-speech-paid-75-million-build-mexicos-wall-188307/?utm_source=rss&utm_medium=rss&utm_campaign=obama-slams-trumps-wall-final-un-speech-paid-75-million-build-mexicos-wall
# teaparty.org 2016-09-21T13:47:01+0000 Only 37 Republicans Back Plan to Defund Muslim 'Refugees' 15058 http://www.teaparty.org/37-republicans-back-plan-defund-muslim-refugees-188273/?utm_source=rss&utm_medium=rss&utm_campaign=37-republicans-back-plan-defund-muslim-refugees
# teaparty.org 2016-09-21T01:07:05+0000 Obama Flooding More U.S. Cities With Muslim Migrants 2934 http://www.teaparty.org/obama-flooding-u-s-cities-muslim-migrants-188243/?utm_source=rss&utm_medium=rss&utm_campaign=obama-flooding-u-s-cities-muslim-migrants
# teaparty.org 2016-09-21T00:58:04+0000 Leaked Video Shows Obama Railing Against White People During Kenya Trip 2023 http://www.teaparty.org/leaked-video-shows-obama-railing-white-people-kenya-trip-188240/?utm_source=rss&utm_medium=rss&utm_campaign=leaked-video-shows-obama-railing-white-people-kenya-trip
# teaparty.org 2016-09-21T00:48:56+0000 Democrat Plan Lets Obama Run for 3rd Term 7296 http://www.teaparty.org/democrat-plan-lets-obama-run-3rd-term-188235/?utm_source=rss&utm_medium=rss&utm_campaign=democrat-plan-lets-obama-run-3rd-term
# teaparty.org 2016-09-20T23:19:01+0000 OBAMA LATE FOR UN ADDRESS=> World Leaders Forced to Skip Ahead to Next Speech 1637 http://www.teaparty.org/obama-late-un-address-world-leaders-forced-skip-ahead-next-speech-188225/?utm_source=rss&utm_medium=rss&utm_campaign=obama-late-un-address-world-leaders-forced-skip-ahead-next-speech
# teaparty.org 2016-09-20T15:46:01+0000 Obama’s Farewell to a World Awash With Troubles 10648 http://www.teaparty.org/obamas-farewell-world-awash-troubles-188146/?utm_source=rss&utm_medium=rss&utm_campaign=obamas-farewell-world-awash-troubles
# teaparty.org 2016-09-20T18:36:01+0000 11 Times Obama Talked Down the U.S. in his Final U.N. Address 1577 http://www.teaparty.org/11-times-obama-talked-u-s-final-u-n-address-188171/?utm_source=rss&utm_medium=rss&utm_campaign=11-times-obama-talked-u-s-final-u-n-address
# teaparty.org 2016-09-20T16:08:01+0000 Email Shows Blumenthal Pushing Obama-Kenya Stories 3924 http://www.teaparty.org/email-shows-blumenthal-pushing-obama-kenya-stories-188150/?utm_source=rss&utm_medium=rss&utm_campaign=email-shows-blumenthal-pushing-obama-kenya-stories
# teaparty.org 2016-09-20T16:02:02+0000 GOP Mostly Powerless in Stopping Obama 'Midnight' Regulations 5400 http://www.teaparty.org/gop-mostly-powerless-stopping-obama-midnight-regulations-188153/?utm_source=rss&utm_medium=rss&utm_campaign=gop-mostly-powerless-stopping-obama-midnight-regulations
# teaparty.org 2016-09-20T14:55:03+0000 Wow. Eagles Players Raise Black Power Fist During National Anthem 927 http://www.teaparty.org/wow-eagles-players-raise-black-power-fist-national-anthem-188132/?utm_source=rss&utm_medium=rss&utm_campaign=wow-eagles-players-raise-black-power-fist-national-anthem
# teaparty.org 2016-09-20T14:46:01+0000 ANDREW SULLIVAN: Technology Almost Killed Me! 40848 http://www.teaparty.org/andrew-sullivan-technology-almost-killed-188130/?utm_source=rss&utm_medium=rss&utm_campaign=andrew-sullivan-technology-almost-killed
# teaparty.org 2016-09-19T20:51:01+0000 1-in-5 Syrian Refugees Settled in New York Area, Obama Wants More 1586 http://www.teaparty.org/1-5-syrian-refugees-settled-new-york-area-obama-wants-188041/?utm_source=rss&utm_medium=rss&utm_campaign=1-5-syrian-refugees-settled-new-york-area-obama-wants
# teaparty.org 2016-09-19T20:35:02+0000 Almost 100,000 Somali Refugees Admitted to US Since 9/11; 99.6% Muslim 5328 http://www.teaparty.org/almost-100000-somali-refugees-admitted-to-us-since-911-99-6-muslim-188033/?utm_source=rss&utm_medium=rss&utm_campaign=almost-100000-somali-refugees-admitted-to-us-since-911-99-6-muslim
# teaparty.org 2016-09-19T17:48:01+0000 Feds Mistakenly Grant Citizenship to 800 Immigrants with Security Concerns 4411 http://www.teaparty.org/feds-mistakenly-grant-citizenship-800-immigrants-security-concerns-188000/?utm_source=rss&utm_medium=rss&utm_campaign=feds-mistakenly-grant-citizenship-800-immigrants-security-concerns
# teaparty.org 2016-09-19T00:14:02+0000 1st Birther Made Public, and it's NOT Hillary 3795 http://www.teaparty.org/1st-birther-made-public-hillary-187918/?utm_source=rss&utm_medium=rss&utm_campaign=1st-birther-made-public-hillary
# teaparty.org 2016-09-18T22:57:02+0000 2 Clinton Supporters in ’08 Reportedly Shared Obama ‘Birther’ Story 4595 http://www.teaparty.org/2-clinton-supporters-08-reportedly-shared-obama-birther-story-187890/?utm_source=rss&utm_medium=rss&utm_campaign=2-clinton-supporters-08-reportedly-shared-obama-birther-story
# teaparty.org 2016-09-19T13:57:01+0000 Obama Blames Fox, Limbaugh for Hillary Clinton’s Struggling Campaign Against Trump 1384 http://www.teaparty.org/obama-blames-fox-limbaugh-hillary-clintons-struggling-campaign-trump-187946/?utm_source=rss&utm_medium=rss&utm_campaign=obama-blames-fox-limbaugh-hillary-clintons-struggling-campaign-trump
# teaparty.org 2016-09-18T23:29:01+0000 Report: US Bombed Syrian Army in Support of ISIS 5321 http://www.teaparty.org/report-us-bombed-syrian-army-support-isis-187905/?utm_source=rss&utm_medium=rss&utm_campaign=report-us-bombed-syrian-army-support-isis
# teaparty.org 2016-09-18T23:13:07+0000 USA Made 2 Wire Payments to Iran Before Sending $1.7 Billion in Cash 6230 http://www.teaparty.org/usa-made-2-wire-payments-iran-sending-1-7-billion-cash-187903/?utm_source=rss&utm_medium=rss&utm_campaign=usa-made-2-wire-payments-iran-sending-1-7-billion-cash
# teaparty.org 2016-09-18T15:29:01+0000 PHOTO: Fox Reports Second Device in New York City is Likely Pressure Cooker Bomb 2716 http://www.teaparty.org/photo-fox-reports-second-device-new-york-city-likely-pressure-cooker-bomb-187829/?utm_source=rss&utm_medium=rss&utm_campaign=photo-fox-reports-second-device-new-york-city-likely-pressure-cooker-bomb
# teaparty.org 2016-09-18T05:07:05+0000 Americans Reject Feds' Global-Warming Psyops 13465 http://www.teaparty.org/americans-reject-feds-global-warming-psyops-187777/?utm_source=rss&utm_medium=rss&utm_campaign=americans-reject-feds-global-warming-psyops
# teaparty.org 2016-09-18T10:16:01+0000 MSNBC, Politico, Bloomberg, CNN, McClatchy and More Confirm: Hillary Clinton’s 2008 Campaign Spread ‘Birtherism’ About Barack Obama 11749 http://www.teaparty.org/msnbc-politico-bloomberg-cnn-mcclatchy-confirm-hillary-clintons-2008-campaign-spread-birtherism-barack-obama-187642/?utm_source=rss&utm_medium=rss&utm_campaign=msnbc-politico-bloomberg-cnn-mcclatchy-confirm-hillary-clintons-2008-campaign-spread-birtherism-barack-obama
# teaparty.org 2016-09-18T05:09:04+0000 Obama AWOL on Child Porn, Sex Trafficking, Bestiality 4837 http://www.teaparty.org/obama-awol-child-porn-sex-trafficking-bestiality-187779/?utm_source=rss&utm_medium=rss&utm_campaign=obama-awol-child-porn-sex-trafficking-bestiality
# teaparty.org 2016-09-17T23:33:02+0000 Obama to Rally Globalists One Last Time 4884 http://www.teaparty.org/obama-rally-globalists-one-last-time-187753/?utm_source=rss&utm_medium=rss&utm_campaign=obama-rally-globalists-one-last-time
# ...
# teaparty.org 2016-04-20T00:08:01+0000 Obamacare Meltdown: Health Insurers Suffer Massive Losses 7496 http://www.teaparty.org/obamacare-meltdown-health-insurers-suffer-massive-losses-159364/?utm_source=rss&utm_medium=rss&utm_campaign=obamacare-meltdown-health-insurers-suffer-massive-losses
# teaparty.org 2016-04-19T21:15:03+0000 #TrumpTrain Video Highlights Trump’s Minority Support – Includes Hilarious Clip of Obama 1520 http://www.teaparty.org/trumptrain-video-highlights-trumps-minority-support-includes-hilarious-clip-obama-159355/?utm_source=rss&utm_medium=rss&utm_campaign=trumptrain-video-highlights-trumps-minority-support-includes-hilarious-clip-obama
# teaparty.org 2016-04-19T20:29:02+0000 Republicans Stand Firm Against SCOTUS Nominee 1949 http://www.teaparty.org/republicans-stand-firm-scotus-nominee-159350/?utm_source=rss&utm_medium=rss&utm_campaign=republicans-stand-firm-scotus-nominee
# teaparty.org 2016-04-19T13:28:02+0000 Bill O'Reilly: 'Race Hustlers' Accusing Me of Racism 1771 http://www.teaparty.org/bill-oreilly-race-hustlers-accusing-racism-159257/?utm_source=rss&utm_medium=rss&utm_campaign=bill-oreilly-race-hustlers-accusing-racism
# teaparty.org 2016-04-19T12:33:04+0000 White House: Obama Talks to Putin, Did Not Discuss Russian Warplanes Buzzing U.S. Ship 1670 http://www.teaparty.org/white-house-obama-talks-putin-discuss-russian-warplanes-buzzing-u-s-ship-159246/?utm_source=rss&utm_medium=rss&utm_campaign=white-house-obama-talks-putin-discuss-russian-warplanes-buzzing-u-s-ship
# teaparty.org 2016-04-19T11:28:03+0000 Illegal Alien Released by Obama Busted Breaking Into Border Patrol Agent’s Personal Car 2218 http://www.teaparty.org/illegal-alien-released-obama-busted-breaking-border-patrol-agents-personal-car-159228/?utm_source=rss&utm_medium=rss&utm_campaign=illegal-alien-released-obama-busted-breaking-border-patrol-agents-personal-car
# teaparty.org 2016-04-19T04:42:01+0000 EPA Chief: Obama, EPA, Won’t ‘Slow Down’ on Climate Change Agenda 1423 http://www.teaparty.org/epa-chief-obama-epa-wont-slow-climate-change-agenda-159203/?utm_source=rss&utm_medium=rss&utm_campaign=epa-chief-obama-epa-wont-slow-climate-change-agenda
# teaparty.org 2016-04-19T02:23:14+0000 Obama's First Farewell Tour Starts with Damage Control 5713 http://www.teaparty.org/obamas-first-farewell-tour-starts-damage-control-159177/?utm_source=rss&utm_medium=rss&utm_campaign=obamas-first-farewell-tour-starts-damage-control
# teaparty.org 2016-04-19T00:51:01+0000 Rep. Mike Pompeo: An Obama Able to Ban Deportations Would Be a 'King' 1503 http://www.teaparty.org/rep-mike-pompeo-obama-able-ban-deportations-king-159150/?utm_source=rss&utm_medium=rss&utm_campaign=rep-mike-pompeo-obama-able-ban-deportations-king
# teaparty.org 2016-04-19T00:30:03+0000 Anderson Cooper: Reporters Shouldn't Vote 1788 http://www.teaparty.org/anderson-cooper-reporters-shouldnt-vote-159146/?utm_source=rss&utm_medium=rss&utm_campaign=anderson-cooper-reporters-shouldnt-vote
# teaparty.org 2016-04-18T23:49:02+0000 White House Signals Veto on Saudi 9/11 Bill 4202 http://www.teaparty.org/white-house-signals-veto-saudi-911-bill-159126/?utm_source=rss&utm_medium=rss&utm_campaign=white-house-signals-veto-saudi-911-bill
# teaparty.org 2016-04-16T20:16:04+0000 Texas Gov. Calls For ALL States To REVOLT Against Obama 7296 http://www.teaparty.org/texas-gov-calls-states-revolt-obama-3-158786/?utm_source=rss&utm_medium=rss&utm_campaign=texas-gov-calls-states-revolt-obama-3
# teaparty.org 2016-04-13T14:48:02+0000 Limbaugh: Obama to be 'president' even when term ends 7296 http://www.teaparty.org/limbaugh-obama-president-even-term-ends-2-156019/?utm_source=rss&utm_medium=rss&utm_campaign=limbaugh-obama-president-even-term-ends-2
# teaparty.org 2016-04-12T10:10:03+0000 White House Warns: 'Stop Criticizing Obama' 13078 http://www.teaparty.org/white-house-warns-stop-criticizing-obama-6-154163/?utm_source=rss&utm_medium=rss&utm_campaign=white-house-warns-stop-criticizing-obama-6
# teaparty.org 2016-04-11T19:20:03+0000 Limbaugh Issues Dire Warning: Obama's Final Year Will Shock You 7296 http://www.teaparty.org/limbaugh-issues-dire-warning-obamas-final-year-will-shock-2-154057/?utm_source=rss&utm_medium=rss&utm_campaign=limbaugh-issues-dire-warning-obamas-final-year-will-shock-2
# teaparty.org 2016-04-09T17:41:03+0000 Conservative Rock Star Calls for Obama Impeachment 7296 http://www.teaparty.org/conservative-rock-star-calls-obama-impeachment-4-153718/?utm_source=rss&utm_medium=rss&utm_campaign=conservative-rock-star-calls-obama-impeachment-4
# teaparty.org 2016-04-07T23:51:01+0000 Franklin Graham Slams 'Hypocrite of the Year' 3301 http://www.teaparty.org/franklin-graham-slams-hypocrite-year-153428/?utm_source=rss&utm_medium=rss&utm_campaign=franklin-graham-slams-hypocrite-year
# teaparty.org 2016-04-07T22:34:01+0000 Obama Appointees Must Repay Salaries After Enabling Fraud 5802 http://www.teaparty.org/obama-appointees-must-repay-salaries-enabling-fraud-153416/?utm_source=rss&utm_medium=rss&utm_campaign=obama-appointees-must-repay-salaries-enabling-fraud
# teaparty.org 2016-04-07T18:40:02+0000 EU May Require Visas from Americans and Canadians 2273 http://www.teaparty.org/eu-may-require-visas-americans-canadians-153355/?utm_source=rss&utm_medium=rss&utm_campaign=eu-may-require-visas-americans-canadians
# teaparty.org 2016-04-06T18:13:05+0000 GOOGLE Eyes Political Polling 5800 http://www.teaparty.org/google-eyes-political-polling-153174/?utm_source=rss&utm_medium=rss&utm_campaign=google-eyes-political-polling
# teaparty.org 2016-04-04T18:03:02+0000 Panama Papers: Putin 'Main Target' in Bombshell Document Leak 5629 http://www.teaparty.org/panama-papers-putin-main-target-in-bombshell-document-leak-152773/?utm_source=rss&utm_medium=rss&utm_campaign=panama-papers-putin-main-target-in-bombshell-document-leak
# teaparty.org 2016-04-04T03:38:02+0000 Navy SEALs Split Over Members Flaunting Service to Cash in on Brand 10717 http://www.teaparty.org/navy-seals-split-members-flaunting-service-cash-brand-152736/?utm_source=rss&utm_medium=rss&utm_campaign=navy-seals-split-members-flaunting-service-cash-brand
# teaparty.org 2016-04-03T19:21:01+0000 Obama, the Man Who Brought Us ISIS, says Trump Doesn't Know Much About "The World Generally" 1017 http://www.teaparty.org/obama-man-brought-us-isis-says-trump-doesnt-know-much-world-generally-152672/?utm_source=rss&utm_medium=rss&utm_campaign=obama-man-brought-us-isis-says-trump-doesnt-know-much-world-generally
# teaparty.org 2016-04-03T16:13:23+0000 Allen West Predicts ‘Obama Will Carry Out This Particularly Treasonous Action’ Before Leaving Office 13078 http://www.teaparty.org/allen-west-predicts-obama-will-carry-particularly-treasonous-action-leaving-office-2-152630/?utm_source=rss&utm_medium=rss&utm_campaign=allen-west-predicts-obama-will-carry-particularly-treasonous-action-leaving-office-2
# teaparty.org 2016-03-31T00:17:02+0000 Obama Has Commuted Sentences of More Prisoners Than Last 6 Presidents Combined 2828 http://www.teaparty.org/obama-commuted-sentences-prisoners-last-6-presidents-combined-152085/?utm_source=rss&utm_medium=rss&utm_campaign=obama-commuted-sentences-prisoners-last-6-presidents-combined
# teaparty.org 2016-04-03T00:49:02+0000 Top Clinton Aide Abedin: 'Terrifying' to Have Emails Released 1859 http://www.teaparty.org/top-clinton-aide-abedin-terrifying-emails-released-152570/?utm_source=rss&utm_medium=rss&utm_campaign=top-clinton-aide-abedin-terrifying-emails-released
# teaparty.org 2016-04-02T18:33:01+0000 Police to Tap Into Private Surveillance Cameras 2087 http://www.teaparty.org/police-tap-private-surveillance-cameras-152494/?utm_source=rss&utm_medium=rss&utm_campaign=police-tap-private-surveillance-cameras
# teaparty.org 2016-04-01T17:56:03+0000 Record 25,741,000 Foreign-Born People Employed in the U.S. 2126 http://www.teaparty.org/record-25741000-foreign-born-people-employed-u-s-152347/?utm_source=rss&utm_medium=rss&utm_campaign=record-25741000-foreign-born-people-employed-u-s
# teaparty.org 2016-04-01T03:12:05+0000 Cuban State Media: 'Negro' Obama 'Incited Rebellion and Disorder' 4948 http://www.teaparty.org/cuban-state-media-negro-obama-incited-rebellion-disorder-152290/?utm_source=rss&utm_medium=rss&utm_campaign=cuban-state-media-negro-obama-incited-rebellion-disorder
# teaparty.org 2016-04-01T02:59:05+0000 Watchdog: Release FBI Interview with OBAMA in Corruption Case 4330 http://www.teaparty.org/watchdog-release-fbi-interview-obama-corruption-case-152285/?utm_source=rss&utm_medium=rss&utm_campaign=watchdog-release-fbi-interview-obama-corruption-case
# teaparty.org 2016-03-30T03:42:06+0000 After Taxpayer Bailout, General Motors Plans Rollout Of Chinese-Built Buicks In America 3629 http://www.teaparty.org/taxpayer-bailout-general-motors-plans-rollout-chinese-built-buicks-america-151927/?utm_source=rss&utm_medium=rss&utm_campaign=taxpayer-bailout-general-motors-plans-rollout-chinese-built-buicks-america
# teaparty.org 2016-04-01T00:15:02+0000 Allen West Predicts ‘Obama Will Carry Out This Particularly Treasonous Action’ Before Leaving Office 3840 http://www.teaparty.org/allen-west-predicts-obama-will-carry-particularly-treasonous-action-leaving-office-152268/?utm_source=rss&utm_medium=rss&utm_campaign=allen-west-predicts-obama-will-carry-particularly-treasonous-action-leaving-office
# teaparty.org 2016-03-31T22:26:01+0000 Secretive Islamic Movement Behind New Push to Establish Schools on U.S. Military Bases 6346 http://www.teaparty.org/secretive-islamic-movement-behind-new-push-establish-schools-u-s-military-bases-152244/?utm_source=rss&utm_medium=rss&utm_campaign=secretive-islamic-movement-behind-new-push-establish-schools-u-s-military-bases
# teaparty.org 2016-03-31T21:02:01+0000 Black Lives Matter Protestors Burn American Flag Over Minneapolis Shooting Decision 5792 http://www.teaparty.org/black-lives-matter-protestors-burn-american-flag-minneapolis-shooting-decision-152219/?utm_source=rss&utm_medium=rss&utm_campaign=black-lives-matter-protestors-burn-american-flag-minneapolis-shooting-decision
# teaparty.org 2016-03-31T20:28:05+0000 Obama's CHICAGOLAND: City Off to Deadliest Start in Two Decades 6920 http://www.teaparty.org/obamas-chicagoland-city-deadliest-start-two-decades-152210/?utm_source=rss&utm_medium=rss&utm_campaign=obamas-chicagoland-city-deadliest-start-two-decades
# teaparty.org 2016-03-31T19:27:02+0000 ALERT: Obama to Release 'Worst of the Worst' GITMO Terrorists 1748 http://www.teaparty.org/alert-obama-release-worst-worst-gitmo-terrorists-152197/?utm_source=rss&utm_medium=rss&utm_campaign=alert-obama-release-worst-worst-gitmo-terrorists
# teaparty.org 2016-03-31T17:09:01+0000 Sharpton: 'I Fear for the Streets After Obama' 50265 http://www.teaparty.org/sharpton-fear-streets-obama-152168/?utm_source=rss&utm_medium=rss&utm_campaign=sharpton-fear-streets-obama
# teaparty.org 2016-03-31T04:41:03+0000 Nuclear Terrorism Fears Loom over Obama's Final Atomic Summit 5505 http://www.teaparty.org/nuclear-terrorism-fears-loom-obamas-final-atomic-summit-152145/?utm_source=rss&utm_medium=rss&utm_campaign=nuclear-terrorism-fears-loom-obamas-final-atomic-summit
# teaparty.org 2016-03-31T04:15:02+0000 Hillary Clinton Campaigns With Scandal Plagued ‘Friend’ Charlie Rangel In Harlem 3083 http://www.teaparty.org/hillary-clinton-campaigns-scandal-plagued-friend-charlie-rangel-harlem-152139/?utm_source=rss&utm_medium=rss&utm_campaign=hillary-clinton-campaigns-scandal-plagued-friend-charlie-rangel-harlem
# teaparty.org 2016-03-31T01:41:04+0000 Judge Rips Thug: ‘Black Lives Don’t Matter to Black People with Guns’ 2274 http://www.teaparty.org/judge-rips-thug-black-lives-dont-matter-black-people-guns-152104/?utm_source=rss&utm_medium=rss&utm_campaign=judge-rips-thug-black-lives-dont-matter-black-people-guns
# teaparty.org 2016-03-31T01:23:04+0000 White House Weighs In: Obama, Bush Would Fire Lewandowski 2398 http://www.teaparty.org/white-house-weighs-obama-bush-fire-lewandowski-152100/?utm_source=rss&utm_medium=rss&utm_campaign=white-house-weighs-obama-bush-fire-lewandowski
# teaparty.org 2016-03-30T22:29:02+0000 Border Fence Down: Border Patrol Union Says Breach Brings Terrorist Concerns 5226 http://www.teaparty.org/border-fence-border-patrol-union-says-breach-brings-terrorist-concerns-152065/?utm_source=rss&utm_medium=rss&utm_campaign=border-fence-border-patrol-union-says-breach-brings-terrorist-concerns
# teaparty.org 2016-03-30T22:09:44+0000 Obama: Terror Fight Not 'A Civilizational Conflict between West and Islam' 2033 http://www.teaparty.org/obama-terror-fight-civilizational-conflict-west-islam-152058/?utm_source=rss&utm_medium=rss&utm_campaign=obama-terror-fight-civilizational-conflict-west-islam
# teaparty.org 2016-03-30T21:26:01+0000 Turkish President BLASTS Obama in Closed-Door Meeting 5722 http://www.teaparty.org/turkish-president-blasts-obama-closed-door-meeting-152052/?utm_source=rss&utm_medium=rss&utm_campaign=turkish-president-blasts-obama-closed-door-meeting
# teaparty.org 2016-03-30T19:45:02+0000 Obama and Biden Use Easter Prayer Breakfast to Condemn Donald Trump 1821 http://www.teaparty.org/obama-biden-use-easter-prayer-breakfast-condemn-donald-trump-152029/?utm_source=rss&utm_medium=rss&utm_campaign=obama-biden-use-easter-prayer-breakfast-condemn-donald-trump
# teaparty.org 2016-03-30T19:23:02+0000 North Korea Threatens 'Preemptive Nuclear Strike' on U.S. 4494 http://www.teaparty.org/north-korea-threatens-preemptive-nuclear-strike-u-s-152020/?utm_source=rss&utm_medium=rss&utm_campaign=north-korea-threatens-preemptive-nuclear-strike-u-s
# teaparty.org 2016-03-30T19:07:02+0000 Pentagon Concerned by Chinese Anti-Ship Missile Firing 5303 http://www.teaparty.org/pentagon-concerned-chinese-anti-ship-missile-firing-152012/?utm_source=rss&utm_medium=rss&utm_campaign=pentagon-concerned-chinese-anti-ship-missile-firing
# teaparty.org 2016-03-30T17:45:02+0000 Genocide: Christian Population in Iraq Drops by 80% in Just Over a Decade 3874 http://www.teaparty.org/genocide-christian-population-iraq-drops-80-just-decade-151983/?utm_source=rss&utm_medium=rss&utm_campaign=genocide-christian-population-iraq-drops-80-just-decade
# teaparty.org 2016-03-27T05:32:01+0000 Secret Service Agent: Obama Is Worse Than You Know 13078 http://www.teaparty.org/secret-service-agent-obama-worse-know-4-151367/?utm_source=rss&utm_medium=rss&utm_campaign=secret-service-agent-obama-worse-know-4
# teaparty.org 2016-03-22T15:26:28+0000 Congress Grants Obama 'Free Rein for Martial Law' 13078 http://www.teaparty.org/congress-grants-obama-free-rein-for-martial-law-2-150389/
# teaparty.org 2016-03-23T04:19:42+0000 Top General: 'Islamists Embedded in White House?' 7296 http://www.teaparty.org/top-general-islamists-embedded-white-house-3-150601/?utm_source=rss&utm_medium=rss&utm_campaign=top-general-islamists-embedded-white-house-3
# teaparty.org 2016-03-22T16:07:57+0000 Congress Grants Obama 'Free Rein for Martial Law' 13078 http://www.teaparty.org/congress-grants-obama-free-rein-for-martial-law-2-150389/?utm_source=rss&utm_medium=rss&utm_campaign=congress-grants-obama-free-rein-for-martial-law-2
# teaparty.org 2016-03-21T22:40:01+0000 Obama to bypass Congress on 'New World Order' 13078 http://www.teaparty.org/obama-bypass-congress-new-world-order-2-150255/?utm_source=rss&utm_medium=rss&utm_campaign=obama-bypass-congress-new-world-order-2
# teaparty.org 2016-06-04T00:49:02+0000 Is the CIA Getting Ready to Dump the Clintons? 7286 http://www.teaparty.org/cia-getting-ready-dump-clintons-168797/?utm_source=rss&utm_medium=rss&utm_campaign=cia-getting-ready-dump-clintons
# teaparty.org 2016-04-28T03:25:14+0000 Is this Obama's Monica Lewinsky? 13078 http://www.teaparty.org/obamas-monica-lewinsky-9-160819/?utm_source=rss&utm_medium=rss&utm_campaign=obamas-monica-lewinsky-9

# %%
TODO:::
make america great again, mexican rapists, has come to mean something very different
remove repeating articles, certain 'bad' articles like teaparty's treatise at the botom of their videos

# %%
# get set of all page urls
sql_uarl = 'postgres://postgres:postgres@localhost/articles'
url_query = """
            SELECT base_url, count(*) as num_posts
            FROM articles
            GROUP BY base_url
            """
results = create_engine(sql_url).execute(url_query).fetchall()
base_urls = [row.base_url for row in results]

# %%
def generate_source_tdm(base_url, sqldb):
    """Create and save a document-term matrix for a given source"""
    query = """
            SELECT article_text FROM articles
            WHERE word_count > 200
            """.format(base_url)
    stream = QueryStream(sqldb, query)
    
    #only keep n-grams that appear in over 10% of articles
    vectorizer = CountVectorizer(ngram_range=(1, 6), min_df=0.10)
    tdm = vectorizer.fit_transform(stream)
    
    #save
    
    
    return

# %%
import pandas as pd
qry = """SELECT article_text, base_url FROM articles
         WHERE lower(article_text) like
         '%%congress%%must%%investigate%%planned%%parenthood%%'"""
test = pd.read_sql(qry, create_engine(sql_url))

# %%
# word count:
#array_length(regexp_split_to_array(article_text, E'\\W+'), 1) > 200
query = """
        SELECT article_text FROM articles
        WHERE base_url like '%%breitbart%%' and
              array_length(regexp_split_to_array(trim(article_text), E'\\\W+'), 1) > 200
        LIMIT 5
        """
stream = QueryStream(sqldb = 'postgres://postgres:postgres@localhost/articles',
                     query=query)
vectorizer = CountVectorizer(ngram_range=(1, 6), min_df=0.10)
tdm = vectorizer.fit_transform(stream)

# %%
tdm.shape
# Out:
# (5, 12046)

# %%
from sklearn.feature_extraction.text import CountVectorizer
vec = CountVectorizer(analyzer='word', preprocessor=None, lowercase=False, tokenizer=lambda x: x, ngram_range=(1,2))
vec.fit_transform([['my','friend','is','bob'],['eat','my','lunch','puppy'],['my','friend','is','joe']])
vec.vocabulary_
# Out:
# {u'bob': 0,
#  u'eat': 1,
#  u'eat my': 2,
#  u'friend': 3,
#  u'friend is': 4,
#  u'is': 5,
#  u'is bob': 6,
#  u'is joe': 7,
#  u'joe': 8,
#  u'lunch': 9,
#  u'lunch puppy': 10,
#  u'my': 11,
#  u'my friend': 12,
#  u'my lunch': 13,
#  u'puppy': 14}

# %%
vectorizer = CountVectorizer(analyzer='word', ngram_range=(1,2))
x = vectorizer.fit_transform(['my friend is a joe', 'my joe is a friend',
                              'i am not a crook','my friend is a friend'])
vectorizer.vocabulary_
# Out:
# {u'am': 0,
#  u'am not': 1,
#  u'crook': 2,
#  u'friend': 3,
#  u'is': 4,
#  u'is friend': 5,
#  u'is joe': 6,
#  u'joe': 7,
#  u'joe is': 8,
#  u'my': 9,
#  u'my joe': 10,
#  u'my_friend': 11,
#  u'my_friend is': 12,
#  u'not': 13,
#  u'not crook': 14}

# %%
y = vectorizer.fit_transform(['justin is a boy', 'justin is a girl'])

# %%
from sklearn.feature_extraction.text import TfidfTransformer
transformer = TfidfTransformer()
transformer.fit_transform(X)

#TODO:
    #DO SIMPLE SUMMARY STATS ON RETRIEVED DOCS (word lengths, etc)
    #TREAT EACH SOURCE AS A DOCUMENT
    #RUN TF-IDF TO GET EACH SOURCE'S MOST UNIQUE N-GRAMS
    #PLOT N-GRAMS on alignment axis, perhaps indicating which n-grams come from where
# Out:
# <100x363874 sparse matrix of type '<class 'numpy.float64'>'
# 	with 413662 stored elements in Compressed Sparse Row format>

# %%
sentence = "Nobody has more respect for women than me"
def gen_n_gram(sentence, n):
    words = sentence.split()
    return [tuple(words[i:i+n]) for i in range(len(words) - n + 1)]

print(gen_n_gram(sentence, 1))
print(gen_n_gram(sentence, 2))

sample_query = """
             SELECT setseed(0.5); 
             SELECT post_id, article_text
             FROM articles
             WHERE num_words > 100
             ORDER BY random()
             LIMIT 50000
             """

# %%
from itertools import groupby, imap
import cPickle as pickle

import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, TfidfTransformer

from stream import SentenceStream #from the prior post

sql_url = 'postgres://postgres:Pluto2015!@localhost/articles'

# ordering is a necessity, else groupby won't work
query = """
        SELECT base_url, article_text
        FROM articles
        WHERE num_words > 100
        ORDER BY base_url
        """

class SourceStream(SentenceStream):
    """
    Stream tokens from each source
    """
    def __iter__(self):
        rows = super(SourceStream, self).__iter__()
        source_sentences = groupby(rows, lambda x: x[0])
        
        for source, sentences in source_sentences:
            yield [word for id, sentence in sentences for word in sentence]
            
            import cPickle as pickle
            
with open('../intermediate/phrasegrams_all.pkl', 'rb') as infile:
    ngrams = pickle.load(infile)
    
# the n-grams we've located will now be identified in the stream of text
# using the MWETokenizer from nltk
src_stream = SourceStream(sqldb=sql_url, query=query,
                          ngrams=ngrams.keys(), idcol='base_url')

# %%
# dummy tokenizer since nltk is doing the tokenizing in the stream
# we can't do lambda x: x because it is unpicklable
def no_tokenizer(x):
    return x

# in fact, all processing is done, and we just need to place it
# in the appropriate data structure and count out n-grams 
# we'll insist that we only get words that appear across
# at least two sources
vectorizer = CountVectorizer(analyzer='word', preprocessor=None,
                             lowercase=False, tokenizer=no_tokenizer,
                             min_df=2)
dtm_source = vectorizer.fit_transform(src_stream)

# %%
with open('../intermediate/vec_source_phrasegram.pkl', 'wb') as vecf,\
     open('../intermediate/dtm_source_phrasegram.pkl', 'wb') as dtmf:
    pickle.dump(vectorizer, vecf)
    pickle.dump(dtm_source, dtmf, pickle.HIGHEST_PROTOCOL)

# %%
# Out:
# <84x410248 sparse matrix of type '<type 'numpy.int64'>'
# 	with 5563489 stored elements in Compressed Sparse Row format>
